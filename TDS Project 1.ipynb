# %% [markdown]
# # GET USERS DATA

# %%
import requests

# %%
token = ''
headers = {'Authorization': f'token {token}'}

# %%
base_url = 'https://api.github.com'
end_point = '/search/users'
query_parameter = '?q=location:Chicago+followers:>100'
page = 1
per_page = 100

# %% [markdown]
# ### get users using github api and paging

# %%
chicago_users = []

while True:
    paging = f'&page={page}&per_page={per_page}'
    url = base_url+end_point+query_parameter+paging
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        chicago_users.extend(data.get('items', []))
        if 'Link' not in response.headers:
            break
        else:
            links = response.headers['Link']
            if 'rel="next"' not in links:
                break
        page += 1
    else:
        print("Error:", response.status_code, response.json())
        break

# %%
chicago_users
# Out:
# [{'login': 'cassidoo',
#   'id': 1454517,
#   'node_id': 'MDQ6VXNlcjE0NTQ1MTc=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1454517?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/cassidoo',
#   'html_url': 'https://github.com/cassidoo',
#   'followers_url': 'https://api.github.com/users/cassidoo/followers',
#   'following_url': 'https://api.github.com/users/cassidoo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/cassidoo/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/cassidoo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/cassidoo/subscriptions',
#   'organizations_url': 'https://api.github.com/users/cassidoo/orgs',
#   'repos_url': 'https://api.github.com/users/cassidoo/repos',
#   'events_url': 'https://api.github.com/users/cassidoo/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/cassidoo/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': True,
#   'score': 1.0},
#  {'login': 'felangel',
#   'id': 8855632,
#   'node_id': 'MDQ6VXNlcjg4NTU2MzI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8855632?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/felangel',
#   'html_url': 'https://github.com/felangel',
#   'followers_url': 'https://api.github.com/users/felangel/followers',
#   'following_url': 'https://api.github.com/users/felangel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/felangel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/felangel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/felangel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/felangel/orgs',
#   'repos_url': 'https://api.github.com/users/felangel/repos',
#   'events_url': 'https://api.github.com/users/felangel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/felangel/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'dabeaz',
#   'id': 350836,
#   'node_id': 'MDQ6VXNlcjM1MDgzNg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/350836?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dabeaz',
#   'html_url': 'https://github.com/dabeaz',
#   'followers_url': 'https://api.github.com/users/dabeaz/followers',
#   'following_url': 'https://api.github.com/users/dabeaz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dabeaz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dabeaz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dabeaz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dabeaz/orgs',
#   'repos_url': 'https://api.github.com/users/dabeaz/repos',
#   'events_url': 'https://api.github.com/users/dabeaz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dabeaz/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'sstephenson',
#   'id': 2603,
#   'node_id': 'MDQ6VXNlcjI2MDM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2603?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sstephenson',
#   'html_url': 'https://github.com/sstephenson',
#   'followers_url': 'https://api.github.com/users/sstephenson/followers',
#   'following_url': 'https://api.github.com/users/sstephenson/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sstephenson/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sstephenson/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sstephenson/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sstephenson/orgs',
#   'repos_url': 'https://api.github.com/users/sstephenson/repos',
#   'events_url': 'https://api.github.com/users/sstephenson/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sstephenson/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'mattgodbolt',
#   'id': 633973,
#   'node_id': 'MDQ6VXNlcjYzMzk3Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/633973?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mattgodbolt',
#   'html_url': 'https://github.com/mattgodbolt',
#   'followers_url': 'https://api.github.com/users/mattgodbolt/followers',
#   'following_url': 'https://api.github.com/users/mattgodbolt/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mattgodbolt/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mattgodbolt/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mattgodbolt/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mattgodbolt/orgs',
#   'repos_url': 'https://api.github.com/users/mattgodbolt/repos',
#   'events_url': 'https://api.github.com/users/mattgodbolt/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mattgodbolt/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'logankilpatrick',
#   'id': 35577566,
#   'node_id': 'MDQ6VXNlcjM1NTc3NTY2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/35577566?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/logankilpatrick',
#   'html_url': 'https://github.com/logankilpatrick',
#   'followers_url': 'https://api.github.com/users/logankilpatrick/followers',
#   'following_url': 'https://api.github.com/users/logankilpatrick/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/logankilpatrick/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/logankilpatrick/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/logankilpatrick/subscriptions',
#   'organizations_url': 'https://api.github.com/users/logankilpatrick/orgs',
#   'repos_url': 'https://api.github.com/users/logankilpatrick/repos',
#   'events_url': 'https://api.github.com/users/logankilpatrick/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/logankilpatrick/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'khan4019',
#   'id': 1848375,
#   'node_id': 'MDQ6VXNlcjE4NDgzNzU=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1848375?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/khan4019',
#   'html_url': 'https://github.com/khan4019',
#   'followers_url': 'https://api.github.com/users/khan4019/followers',
#   'following_url': 'https://api.github.com/users/khan4019/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/khan4019/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/khan4019/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/khan4019/subscriptions',
#   'organizations_url': 'https://api.github.com/users/khan4019/orgs',
#   'repos_url': 'https://api.github.com/users/khan4019/repos',
#   'events_url': 'https://api.github.com/users/khan4019/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/khan4019/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'adashofdata',
#   'id': 30323348,
#   'node_id': 'MDQ6VXNlcjMwMzIzMzQ4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/30323348?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/adashofdata',
#   'html_url': 'https://github.com/adashofdata',
#   'followers_url': 'https://api.github.com/users/adashofdata/followers',
#   'following_url': 'https://api.github.com/users/adashofdata/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/adashofdata/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/adashofdata/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/adashofdata/subscriptions',
#   'organizations_url': 'https://api.github.com/users/adashofdata/orgs',
#   'repos_url': 'https://api.github.com/users/adashofdata/repos',
#   'events_url': 'https://api.github.com/users/adashofdata/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/adashofdata/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'djspiewak',
#   'id': 752,
#   'node_id': 'MDQ6VXNlcjc1Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/752?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/djspiewak',
#   'html_url': 'https://github.com/djspiewak',
#   'followers_url': 'https://api.github.com/users/djspiewak/followers',
#   'following_url': 'https://api.github.com/users/djspiewak/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/djspiewak/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/djspiewak/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/djspiewak/subscriptions',
#   'organizations_url': 'https://api.github.com/users/djspiewak/orgs',
#   'repos_url': 'https://api.github.com/users/djspiewak/repos',
#   'events_url': 'https://api.github.com/users/djspiewak/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/djspiewak/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'eddelbuettel',
#   'id': 673121,
#   'node_id': 'MDQ6VXNlcjY3MzEyMQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/673121?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/eddelbuettel',
#   'html_url': 'https://github.com/eddelbuettel',
#   'followers_url': 'https://api.github.com/users/eddelbuettel/followers',
#   'following_url': 'https://api.github.com/users/eddelbuettel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/eddelbuettel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/eddelbuettel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/eddelbuettel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/eddelbuettel/orgs',
#   'repos_url': 'https://api.github.com/users/eddelbuettel/repos',
#   'events_url': 'https://api.github.com/users/eddelbuettel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/eddelbuettel/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'natemoo-re',
#   'id': 7118177,
#   'node_id': 'MDQ6VXNlcjcxMTgxNzc=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7118177?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/natemoo-re',
#   'html_url': 'https://github.com/natemoo-re',
#   'followers_url': 'https://api.github.com/users/natemoo-re/followers',
#   'following_url': 'https://api.github.com/users/natemoo-re/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/natemoo-re/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/natemoo-re/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/natemoo-re/subscriptions',
#   'organizations_url': 'https://api.github.com/users/natemoo-re/orgs',
#   'repos_url': 'https://api.github.com/users/natemoo-re/repos',
#   'events_url': 'https://api.github.com/users/natemoo-re/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/natemoo-re/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'lexi-lambda',
#   'id': 759911,
#   'node_id': 'MDQ6VXNlcjc1OTkxMQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/759911?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lexi-lambda',
#   'html_url': 'https://github.com/lexi-lambda',
#   'followers_url': 'https://api.github.com/users/lexi-lambda/followers',
#   'following_url': 'https://api.github.com/users/lexi-lambda/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lexi-lambda/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lexi-lambda/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lexi-lambda/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lexi-lambda/orgs',
#   'repos_url': 'https://api.github.com/users/lexi-lambda/repos',
#   'events_url': 'https://api.github.com/users/lexi-lambda/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lexi-lambda/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'neodigm',
#   'id': 3151842,
#   'node_id': 'MDQ6VXNlcjMxNTE4NDI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3151842?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/neodigm',
#   'html_url': 'https://github.com/neodigm',
#   'followers_url': 'https://api.github.com/users/neodigm/followers',
#   'following_url': 'https://api.github.com/users/neodigm/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/neodigm/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/neodigm/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/neodigm/subscriptions',
#   'organizations_url': 'https://api.github.com/users/neodigm/orgs',
#   'repos_url': 'https://api.github.com/users/neodigm/repos',
#   'events_url': 'https://api.github.com/users/neodigm/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/neodigm/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'rentzsch',
#   'id': 2971,
#   'node_id': 'MDQ6VXNlcjI5NzE=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2971?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rentzsch',
#   'html_url': 'https://github.com/rentzsch',
#   'followers_url': 'https://api.github.com/users/rentzsch/followers',
#   'following_url': 'https://api.github.com/users/rentzsch/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rentzsch/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rentzsch/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rentzsch/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rentzsch/orgs',
#   'repos_url': 'https://api.github.com/users/rentzsch/repos',
#   'events_url': 'https://api.github.com/users/rentzsch/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rentzsch/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'HFTrader',
#   'id': 11621271,
#   'node_id': 'MDQ6VXNlcjExNjIxMjcx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/11621271?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/HFTrader',
#   'html_url': 'https://github.com/HFTrader',
#   'followers_url': 'https://api.github.com/users/HFTrader/followers',
#   'following_url': 'https://api.github.com/users/HFTrader/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/HFTrader/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/HFTrader/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/HFTrader/subscriptions',
#   'organizations_url': 'https://api.github.com/users/HFTrader/orgs',
#   'repos_url': 'https://api.github.com/users/HFTrader/repos',
#   'events_url': 'https://api.github.com/users/HFTrader/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/HFTrader/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'JimLiu',
#   'id': 648674,
#   'node_id': 'MDQ6VXNlcjY0ODY3NA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/648674?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JimLiu',
#   'html_url': 'https://github.com/JimLiu',
#   'followers_url': 'https://api.github.com/users/JimLiu/followers',
#   'following_url': 'https://api.github.com/users/JimLiu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/JimLiu/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/JimLiu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/JimLiu/subscriptions',
#   'organizations_url': 'https://api.github.com/users/JimLiu/orgs',
#   'repos_url': 'https://api.github.com/users/JimLiu/repos',
#   'events_url': 'https://api.github.com/users/JimLiu/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/JimLiu/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jcs',
#   'id': 9888,
#   'node_id': 'MDQ6VXNlcjk4ODg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9888?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jcs',
#   'html_url': 'https://github.com/jcs',
#   'followers_url': 'https://api.github.com/users/jcs/followers',
#   'following_url': 'https://api.github.com/users/jcs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jcs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jcs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jcs/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jcs/orgs',
#   'repos_url': 'https://api.github.com/users/jcs/repos',
#   'events_url': 'https://api.github.com/users/jcs/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jcs/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jbranchaud',
#   'id': 694063,
#   'node_id': 'MDQ6VXNlcjY5NDA2Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/694063?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbranchaud',
#   'html_url': 'https://github.com/jbranchaud',
#   'followers_url': 'https://api.github.com/users/jbranchaud/followers',
#   'following_url': 'https://api.github.com/users/jbranchaud/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jbranchaud/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jbranchaud/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jbranchaud/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jbranchaud/orgs',
#   'repos_url': 'https://api.github.com/users/jbranchaud/repos',
#   'events_url': 'https://api.github.com/users/jbranchaud/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jbranchaud/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'basecamp',
#   'id': 13131,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzMTMx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/13131?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/basecamp',
#   'html_url': 'https://github.com/basecamp',
#   'followers_url': 'https://api.github.com/users/basecamp/followers',
#   'following_url': 'https://api.github.com/users/basecamp/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/basecamp/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/basecamp/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/basecamp/subscriptions',
#   'organizations_url': 'https://api.github.com/users/basecamp/orgs',
#   'repos_url': 'https://api.github.com/users/basecamp/repos',
#   'events_url': 'https://api.github.com/users/basecamp/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/basecamp/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'SciSharp',
#   'id': 44989469,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0OTg5NDY5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44989469?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SciSharp',
#   'html_url': 'https://github.com/SciSharp',
#   'followers_url': 'https://api.github.com/users/SciSharp/followers',
#   'following_url': 'https://api.github.com/users/SciSharp/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/SciSharp/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/SciSharp/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/SciSharp/subscriptions',
#   'organizations_url': 'https://api.github.com/users/SciSharp/orgs',
#   'repos_url': 'https://api.github.com/users/SciSharp/repos',
#   'events_url': 'https://api.github.com/users/SciSharp/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/SciSharp/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'joshdholtz',
#   'id': 401294,
#   'node_id': 'MDQ6VXNlcjQwMTI5NA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/401294?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/joshdholtz',
#   'html_url': 'https://github.com/joshdholtz',
#   'followers_url': 'https://api.github.com/users/joshdholtz/followers',
#   'following_url': 'https://api.github.com/users/joshdholtz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/joshdholtz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/joshdholtz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/joshdholtz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/joshdholtz/orgs',
#   'repos_url': 'https://api.github.com/users/joshdholtz/repos',
#   'events_url': 'https://api.github.com/users/joshdholtz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/joshdholtz/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'johnpolacek',
#   'id': 179482,
#   'node_id': 'MDQ6VXNlcjE3OTQ4Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/179482?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/johnpolacek',
#   'html_url': 'https://github.com/johnpolacek',
#   'followers_url': 'https://api.github.com/users/johnpolacek/followers',
#   'following_url': 'https://api.github.com/users/johnpolacek/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/johnpolacek/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/johnpolacek/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/johnpolacek/subscriptions',
#   'organizations_url': 'https://api.github.com/users/johnpolacek/orgs',
#   'repos_url': 'https://api.github.com/users/johnpolacek/repos',
#   'events_url': 'https://api.github.com/users/johnpolacek/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/johnpolacek/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'davidteather',
#   'id': 34144122,
#   'node_id': 'MDQ6VXNlcjM0MTQ0MTIy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/34144122?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/davidteather',
#   'html_url': 'https://github.com/davidteather',
#   'followers_url': 'https://api.github.com/users/davidteather/followers',
#   'following_url': 'https://api.github.com/users/davidteather/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/davidteather/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/davidteather/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/davidteather/subscriptions',
#   'organizations_url': 'https://api.github.com/users/davidteather/orgs',
#   'repos_url': 'https://api.github.com/users/davidteather/repos',
#   'events_url': 'https://api.github.com/users/davidteather/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/davidteather/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jeremyckahn',
#   'id': 366330,
#   'node_id': 'MDQ6VXNlcjM2NjMzMA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/366330?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jeremyckahn',
#   'html_url': 'https://github.com/jeremyckahn',
#   'followers_url': 'https://api.github.com/users/jeremyckahn/followers',
#   'following_url': 'https://api.github.com/users/jeremyckahn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jeremyckahn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jeremyckahn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jeremyckahn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jeremyckahn/orgs',
#   'repos_url': 'https://api.github.com/users/jeremyckahn/repos',
#   'events_url': 'https://api.github.com/users/jeremyckahn/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jeremyckahn/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'dchelimsky',
#   'id': 1075,
#   'node_id': 'MDQ6VXNlcjEwNzU=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1075?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dchelimsky',
#   'html_url': 'https://github.com/dchelimsky',
#   'followers_url': 'https://api.github.com/users/dchelimsky/followers',
#   'following_url': 'https://api.github.com/users/dchelimsky/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dchelimsky/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dchelimsky/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dchelimsky/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dchelimsky/orgs',
#   'repos_url': 'https://api.github.com/users/dchelimsky/repos',
#   'events_url': 'https://api.github.com/users/dchelimsky/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dchelimsky/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'coreyhaines',
#   'id': 3962,
#   'node_id': 'MDQ6VXNlcjM5NjI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3962?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/coreyhaines',
#   'html_url': 'https://github.com/coreyhaines',
#   'followers_url': 'https://api.github.com/users/coreyhaines/followers',
#   'following_url': 'https://api.github.com/users/coreyhaines/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/coreyhaines/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/coreyhaines/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/coreyhaines/subscriptions',
#   'organizations_url': 'https://api.github.com/users/coreyhaines/orgs',
#   'repos_url': 'https://api.github.com/users/coreyhaines/repos',
#   'events_url': 'https://api.github.com/users/coreyhaines/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/coreyhaines/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'rharter',
#   'id': 1296750,
#   'node_id': 'MDQ6VXNlcjEyOTY3NTA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1296750?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rharter',
#   'html_url': 'https://github.com/rharter',
#   'followers_url': 'https://api.github.com/users/rharter/followers',
#   'following_url': 'https://api.github.com/users/rharter/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rharter/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rharter/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rharter/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rharter/orgs',
#   'repos_url': 'https://api.github.com/users/rharter/repos',
#   'events_url': 'https://api.github.com/users/rharter/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rharter/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'harperreed',
#   'id': 18504,
#   'node_id': 'MDQ6VXNlcjE4NTA0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/18504?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/harperreed',
#   'html_url': 'https://github.com/harperreed',
#   'followers_url': 'https://api.github.com/users/harperreed/followers',
#   'following_url': 'https://api.github.com/users/harperreed/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/harperreed/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/harperreed/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/harperreed/subscriptions',
#   'organizations_url': 'https://api.github.com/users/harperreed/orgs',
#   'repos_url': 'https://api.github.com/users/harperreed/repos',
#   'events_url': 'https://api.github.com/users/harperreed/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/harperreed/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'sksamuel',
#   'id': 743706,
#   'node_id': 'MDQ6VXNlcjc0MzcwNg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/743706?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sksamuel',
#   'html_url': 'https://github.com/sksamuel',
#   'followers_url': 'https://api.github.com/users/sksamuel/followers',
#   'following_url': 'https://api.github.com/users/sksamuel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sksamuel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sksamuel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sksamuel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sksamuel/orgs',
#   'repos_url': 'https://api.github.com/users/sksamuel/repos',
#   'events_url': 'https://api.github.com/users/sksamuel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sksamuel/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'leeoniya',
#   'id': 43234,
#   'node_id': 'MDQ6VXNlcjQzMjM0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43234?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/leeoniya',
#   'html_url': 'https://github.com/leeoniya',
#   'followers_url': 'https://api.github.com/users/leeoniya/followers',
#   'following_url': 'https://api.github.com/users/leeoniya/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/leeoniya/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/leeoniya/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/leeoniya/subscriptions',
#   'organizations_url': 'https://api.github.com/users/leeoniya/orgs',
#   'repos_url': 'https://api.github.com/users/leeoniya/repos',
#   'events_url': 'https://api.github.com/users/leeoniya/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/leeoniya/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'hwayne',
#   'id': 2660212,
#   'node_id': 'MDQ6VXNlcjI2NjAyMTI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2660212?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/hwayne',
#   'html_url': 'https://github.com/hwayne',
#   'followers_url': 'https://api.github.com/users/hwayne/followers',
#   'following_url': 'https://api.github.com/users/hwayne/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/hwayne/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/hwayne/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/hwayne/subscriptions',
#   'organizations_url': 'https://api.github.com/users/hwayne/orgs',
#   'repos_url': 'https://api.github.com/users/hwayne/repos',
#   'events_url': 'https://api.github.com/users/hwayne/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/hwayne/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'CoralineAda',
#   'id': 22284,
#   'node_id': 'MDQ6VXNlcjIyMjg0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22284?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/CoralineAda',
#   'html_url': 'https://github.com/CoralineAda',
#   'followers_url': 'https://api.github.com/users/CoralineAda/followers',
#   'following_url': 'https://api.github.com/users/CoralineAda/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/CoralineAda/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/CoralineAda/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/CoralineAda/subscriptions',
#   'organizations_url': 'https://api.github.com/users/CoralineAda/orgs',
#   'repos_url': 'https://api.github.com/users/CoralineAda/repos',
#   'events_url': 'https://api.github.com/users/CoralineAda/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/CoralineAda/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'sean-codes',
#   'id': 21677355,
#   'node_id': 'MDQ6VXNlcjIxNjc3MzU1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/21677355?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sean-codes',
#   'html_url': 'https://github.com/sean-codes',
#   'followers_url': 'https://api.github.com/users/sean-codes/followers',
#   'following_url': 'https://api.github.com/users/sean-codes/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sean-codes/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sean-codes/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sean-codes/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sean-codes/orgs',
#   'repos_url': 'https://api.github.com/users/sean-codes/repos',
#   'events_url': 'https://api.github.com/users/sean-codes/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sean-codes/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'gjreda',
#   'id': 921995,
#   'node_id': 'MDQ6VXNlcjkyMTk5NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/921995?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gjreda',
#   'html_url': 'https://github.com/gjreda',
#   'followers_url': 'https://api.github.com/users/gjreda/followers',
#   'following_url': 'https://api.github.com/users/gjreda/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gjreda/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/gjreda/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gjreda/subscriptions',
#   'organizations_url': 'https://api.github.com/users/gjreda/orgs',
#   'repos_url': 'https://api.github.com/users/gjreda/repos',
#   'events_url': 'https://api.github.com/users/gjreda/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/gjreda/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jameslamb',
#   'id': 7608904,
#   'node_id': 'MDQ6VXNlcjc2MDg5MDQ=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7608904?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jameslamb',
#   'html_url': 'https://github.com/jameslamb',
#   'followers_url': 'https://api.github.com/users/jameslamb/followers',
#   'following_url': 'https://api.github.com/users/jameslamb/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jameslamb/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jameslamb/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jameslamb/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jameslamb/orgs',
#   'repos_url': 'https://api.github.com/users/jameslamb/repos',
#   'events_url': 'https://api.github.com/users/jameslamb/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jameslamb/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'djsime1',
#   'id': 8518150,
#   'node_id': 'MDQ6VXNlcjg1MTgxNTA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8518150?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/djsime1',
#   'html_url': 'https://github.com/djsime1',
#   'followers_url': 'https://api.github.com/users/djsime1/followers',
#   'following_url': 'https://api.github.com/users/djsime1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/djsime1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/djsime1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/djsime1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/djsime1/orgs',
#   'repos_url': 'https://api.github.com/users/djsime1/repos',
#   'events_url': 'https://api.github.com/users/djsime1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/djsime1/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'dabeaz-course',
#   'id': 65303367,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY1MzAzMzY3',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/65303367?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dabeaz-course',
#   'html_url': 'https://github.com/dabeaz-course',
#   'followers_url': 'https://api.github.com/users/dabeaz-course/followers',
#   'following_url': 'https://api.github.com/users/dabeaz-course/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dabeaz-course/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dabeaz-course/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dabeaz-course/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dabeaz-course/orgs',
#   'repos_url': 'https://api.github.com/users/dabeaz-course/repos',
#   'events_url': 'https://api.github.com/users/dabeaz-course/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dabeaz-course/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'lorenanicole',
#   'id': 4573607,
#   'node_id': 'MDQ6VXNlcjQ1NzM2MDc=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4573607?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lorenanicole',
#   'html_url': 'https://github.com/lorenanicole',
#   'followers_url': 'https://api.github.com/users/lorenanicole/followers',
#   'following_url': 'https://api.github.com/users/lorenanicole/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lorenanicole/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lorenanicole/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lorenanicole/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lorenanicole/orgs',
#   'repos_url': 'https://api.github.com/users/lorenanicole/repos',
#   'events_url': 'https://api.github.com/users/lorenanicole/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lorenanicole/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'LadyKerr',
#   'id': 47188731,
#   'node_id': 'MDQ6VXNlcjQ3MTg4NzMx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/47188731?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LadyKerr',
#   'html_url': 'https://github.com/LadyKerr',
#   'followers_url': 'https://api.github.com/users/LadyKerr/followers',
#   'following_url': 'https://api.github.com/users/LadyKerr/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/LadyKerr/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/LadyKerr/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/LadyKerr/subscriptions',
#   'organizations_url': 'https://api.github.com/users/LadyKerr/orgs',
#   'repos_url': 'https://api.github.com/users/LadyKerr/repos',
#   'events_url': 'https://api.github.com/users/LadyKerr/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/LadyKerr/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': True,
#   'score': 1.0},
#  {'login': 'dannguyen',
#   'id': 121520,
#   'node_id': 'MDQ6VXNlcjEyMTUyMA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/121520?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dannguyen',
#   'html_url': 'https://github.com/dannguyen',
#   'followers_url': 'https://api.github.com/users/dannguyen/followers',
#   'following_url': 'https://api.github.com/users/dannguyen/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dannguyen/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dannguyen/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dannguyen/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dannguyen/orgs',
#   'repos_url': 'https://api.github.com/users/dannguyen/repos',
#   'events_url': 'https://api.github.com/users/dannguyen/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dannguyen/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'awatson1978',
#   'id': 675910,
#   'node_id': 'MDQ6VXNlcjY3NTkxMA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/675910?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/awatson1978',
#   'html_url': 'https://github.com/awatson1978',
#   'followers_url': 'https://api.github.com/users/awatson1978/followers',
#   'following_url': 'https://api.github.com/users/awatson1978/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/awatson1978/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/awatson1978/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/awatson1978/subscriptions',
#   'organizations_url': 'https://api.github.com/users/awatson1978/orgs',
#   'repos_url': 'https://api.github.com/users/awatson1978/repos',
#   'events_url': 'https://api.github.com/users/awatson1978/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/awatson1978/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'trek',
#   'id': 9736,
#   'node_id': 'MDQ6VXNlcjk3MzY=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9736?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/trek',
#   'html_url': 'https://github.com/trek',
#   'followers_url': 'https://api.github.com/users/trek/followers',
#   'following_url': 'https://api.github.com/users/trek/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/trek/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/trek/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/trek/subscriptions',
#   'organizations_url': 'https://api.github.com/users/trek/orgs',
#   'repos_url': 'https://api.github.com/users/trek/repos',
#   'events_url': 'https://api.github.com/users/trek/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/trek/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'Valve',
#   'id': 27387,
#   'node_id': 'MDQ6VXNlcjI3Mzg3',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/27387?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Valve',
#   'html_url': 'https://github.com/Valve',
#   'followers_url': 'https://api.github.com/users/Valve/followers',
#   'following_url': 'https://api.github.com/users/Valve/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Valve/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Valve/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Valve/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Valve/orgs',
#   'repos_url': 'https://api.github.com/users/Valve/repos',
#   'events_url': 'https://api.github.com/users/Valve/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Valve/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'catarak',
#   'id': 6063380,
#   'node_id': 'MDQ6VXNlcjYwNjMzODA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6063380?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/catarak',
#   'html_url': 'https://github.com/catarak',
#   'followers_url': 'https://api.github.com/users/catarak/followers',
#   'following_url': 'https://api.github.com/users/catarak/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/catarak/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/catarak/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/catarak/subscriptions',
#   'organizations_url': 'https://api.github.com/users/catarak/orgs',
#   'repos_url': 'https://api.github.com/users/catarak/repos',
#   'events_url': 'https://api.github.com/users/catarak/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/catarak/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'scopatz',
#   'id': 320553,
#   'node_id': 'MDQ6VXNlcjMyMDU1Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/320553?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/scopatz',
#   'html_url': 'https://github.com/scopatz',
#   'followers_url': 'https://api.github.com/users/scopatz/followers',
#   'following_url': 'https://api.github.com/users/scopatz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/scopatz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/scopatz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/scopatz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/scopatz/orgs',
#   'repos_url': 'https://api.github.com/users/scopatz/repos',
#   'events_url': 'https://api.github.com/users/scopatz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/scopatz/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'ZeweiChu',
#   'id': 2027005,
#   'node_id': 'MDQ6VXNlcjIwMjcwMDU=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2027005?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ZeweiChu',
#   'html_url': 'https://github.com/ZeweiChu',
#   'followers_url': 'https://api.github.com/users/ZeweiChu/followers',
#   'following_url': 'https://api.github.com/users/ZeweiChu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ZeweiChu/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ZeweiChu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ZeweiChu/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ZeweiChu/orgs',
#   'repos_url': 'https://api.github.com/users/ZeweiChu/repos',
#   'events_url': 'https://api.github.com/users/ZeweiChu/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ZeweiChu/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'peterpme',
#   'id': 1211905,
#   'node_id': 'MDQ6VXNlcjEyMTE5MDU=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1211905?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/peterpme',
#   'html_url': 'https://github.com/peterpme',
#   'followers_url': 'https://api.github.com/users/peterpme/followers',
#   'following_url': 'https://api.github.com/users/peterpme/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/peterpme/gists{/gist_id}',
# ...
#   'repos_url': 'https://api.github.com/users/csantiago132/repos',
#   'events_url': 'https://api.github.com/users/csantiago132/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/csantiago132/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jaku',
#   'id': 102187,
#   'node_id': 'MDQ6VXNlcjEwMjE4Nw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/102187?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jaku',
#   'html_url': 'https://github.com/jaku',
#   'followers_url': 'https://api.github.com/users/jaku/followers',
#   'following_url': 'https://api.github.com/users/jaku/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jaku/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jaku/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jaku/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jaku/orgs',
#   'repos_url': 'https://api.github.com/users/jaku/repos',
#   'events_url': 'https://api.github.com/users/jaku/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jaku/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'AbrarSyed',
#   'id': 523593,
#   'node_id': 'MDQ6VXNlcjUyMzU5Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/523593?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/AbrarSyed',
#   'html_url': 'https://github.com/AbrarSyed',
#   'followers_url': 'https://api.github.com/users/AbrarSyed/followers',
#   'following_url': 'https://api.github.com/users/AbrarSyed/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/AbrarSyed/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/AbrarSyed/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/AbrarSyed/subscriptions',
#   'organizations_url': 'https://api.github.com/users/AbrarSyed/orgs',
#   'repos_url': 'https://api.github.com/users/AbrarSyed/repos',
#   'events_url': 'https://api.github.com/users/AbrarSyed/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/AbrarSyed/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'juneau001',
#   'id': 121002,
#   'node_id': 'MDQ6VXNlcjEyMTAwMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/121002?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/juneau001',
#   'html_url': 'https://github.com/juneau001',
#   'followers_url': 'https://api.github.com/users/juneau001/followers',
#   'following_url': 'https://api.github.com/users/juneau001/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/juneau001/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/juneau001/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/juneau001/subscriptions',
#   'organizations_url': 'https://api.github.com/users/juneau001/orgs',
#   'repos_url': 'https://api.github.com/users/juneau001/repos',
#   'events_url': 'https://api.github.com/users/juneau001/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/juneau001/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'alycit',
#   'id': 439941,
#   'node_id': 'MDQ6VXNlcjQzOTk0MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/439941?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alycit',
#   'html_url': 'https://github.com/alycit',
#   'followers_url': 'https://api.github.com/users/alycit/followers',
#   'following_url': 'https://api.github.com/users/alycit/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/alycit/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/alycit/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/alycit/subscriptions',
#   'organizations_url': 'https://api.github.com/users/alycit/orgs',
#   'repos_url': 'https://api.github.com/users/alycit/repos',
#   'events_url': 'https://api.github.com/users/alycit/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/alycit/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'mstratman',
#   'id': 317598,
#   'node_id': 'MDQ6VXNlcjMxNzU5OA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/317598?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mstratman',
#   'html_url': 'https://github.com/mstratman',
#   'followers_url': 'https://api.github.com/users/mstratman/followers',
#   'following_url': 'https://api.github.com/users/mstratman/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mstratman/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mstratman/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mstratman/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mstratman/orgs',
#   'repos_url': 'https://api.github.com/users/mstratman/repos',
#   'events_url': 'https://api.github.com/users/mstratman/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mstratman/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'CaryLandholt',
#   'id': 833972,
#   'node_id': 'MDQ6VXNlcjgzMzk3Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/833972?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/CaryLandholt',
#   'html_url': 'https://github.com/CaryLandholt',
#   'followers_url': 'https://api.github.com/users/CaryLandholt/followers',
#   'following_url': 'https://api.github.com/users/CaryLandholt/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/CaryLandholt/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/CaryLandholt/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/CaryLandholt/subscriptions',
#   'organizations_url': 'https://api.github.com/users/CaryLandholt/orgs',
#   'repos_url': 'https://api.github.com/users/CaryLandholt/repos',
#   'events_url': 'https://api.github.com/users/CaryLandholt/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/CaryLandholt/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'knagaitsev',
#   'id': 22580625,
#   'node_id': 'MDQ6VXNlcjIyNTgwNjI1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22580625?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/knagaitsev',
#   'html_url': 'https://github.com/knagaitsev',
#   'followers_url': 'https://api.github.com/users/knagaitsev/followers',
#   'following_url': 'https://api.github.com/users/knagaitsev/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/knagaitsev/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/knagaitsev/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/knagaitsev/subscriptions',
#   'organizations_url': 'https://api.github.com/users/knagaitsev/orgs',
#   'repos_url': 'https://api.github.com/users/knagaitsev/repos',
#   'events_url': 'https://api.github.com/users/knagaitsev/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/knagaitsev/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'omargfh',
#   'id': 51462341,
#   'node_id': 'MDQ6VXNlcjUxNDYyMzQx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/51462341?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/omargfh',
#   'html_url': 'https://github.com/omargfh',
#   'followers_url': 'https://api.github.com/users/omargfh/followers',
#   'following_url': 'https://api.github.com/users/omargfh/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/omargfh/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/omargfh/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/omargfh/subscriptions',
#   'organizations_url': 'https://api.github.com/users/omargfh/orgs',
#   'repos_url': 'https://api.github.com/users/omargfh/repos',
#   'events_url': 'https://api.github.com/users/omargfh/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/omargfh/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'RonaldColyar',
#   'id': 35206353,
#   'node_id': 'MDQ6VXNlcjM1MjA2MzUz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/35206353?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/RonaldColyar',
#   'html_url': 'https://github.com/RonaldColyar',
#   'followers_url': 'https://api.github.com/users/RonaldColyar/followers',
#   'following_url': 'https://api.github.com/users/RonaldColyar/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/RonaldColyar/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/RonaldColyar/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/RonaldColyar/subscriptions',
#   'organizations_url': 'https://api.github.com/users/RonaldColyar/orgs',
#   'repos_url': 'https://api.github.com/users/RonaldColyar/repos',
#   'events_url': 'https://api.github.com/users/RonaldColyar/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/RonaldColyar/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'erichilarysmithsr',
#   'id': 5528838,
#   'node_id': 'MDQ6VXNlcjU1Mjg4Mzg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5528838?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/erichilarysmithsr',
#   'html_url': 'https://github.com/erichilarysmithsr',
#   'followers_url': 'https://api.github.com/users/erichilarysmithsr/followers',
#   'following_url': 'https://api.github.com/users/erichilarysmithsr/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/erichilarysmithsr/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/erichilarysmithsr/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/erichilarysmithsr/subscriptions',
#   'organizations_url': 'https://api.github.com/users/erichilarysmithsr/orgs',
#   'repos_url': 'https://api.github.com/users/erichilarysmithsr/repos',
#   'events_url': 'https://api.github.com/users/erichilarysmithsr/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/erichilarysmithsr/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'luoyuanlab',
#   'id': 888898,
#   'node_id': 'MDQ6VXNlcjg4ODg5OA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/888898?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/luoyuanlab',
#   'html_url': 'https://github.com/luoyuanlab',
#   'followers_url': 'https://api.github.com/users/luoyuanlab/followers',
#   'following_url': 'https://api.github.com/users/luoyuanlab/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/luoyuanlab/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/luoyuanlab/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/luoyuanlab/subscriptions',
#   'organizations_url': 'https://api.github.com/users/luoyuanlab/orgs',
#   'repos_url': 'https://api.github.com/users/luoyuanlab/repos',
#   'events_url': 'https://api.github.com/users/luoyuanlab/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/luoyuanlab/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'jfnavarro21',
#   'id': 16669497,
#   'node_id': 'MDQ6VXNlcjE2NjY5NDk3',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/16669497?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jfnavarro21',
#   'html_url': 'https://github.com/jfnavarro21',
#   'followers_url': 'https://api.github.com/users/jfnavarro21/followers',
#   'following_url': 'https://api.github.com/users/jfnavarro21/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jfnavarro21/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jfnavarro21/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jfnavarro21/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jfnavarro21/orgs',
#   'repos_url': 'https://api.github.com/users/jfnavarro21/repos',
#   'events_url': 'https://api.github.com/users/jfnavarro21/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jfnavarro21/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'rlk',
#   'id': 88741,
#   'node_id': 'MDQ6VXNlcjg4NzQx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/88741?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rlk',
#   'html_url': 'https://github.com/rlk',
#   'followers_url': 'https://api.github.com/users/rlk/followers',
#   'following_url': 'https://api.github.com/users/rlk/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rlk/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rlk/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rlk/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rlk/orgs',
#   'repos_url': 'https://api.github.com/users/rlk/repos',
#   'events_url': 'https://api.github.com/users/rlk/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rlk/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': '3CloudSolutions',
#   'id': 26262170,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI2MjYyMTcw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/26262170?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/3CloudSolutions',
#   'html_url': 'https://github.com/3CloudSolutions',
#   'followers_url': 'https://api.github.com/users/3CloudSolutions/followers',
#   'following_url': 'https://api.github.com/users/3CloudSolutions/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/3CloudSolutions/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/3CloudSolutions/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/3CloudSolutions/subscriptions',
#   'organizations_url': 'https://api.github.com/users/3CloudSolutions/orgs',
#   'repos_url': 'https://api.github.com/users/3CloudSolutions/repos',
#   'events_url': 'https://api.github.com/users/3CloudSolutions/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/3CloudSolutions/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0},
#  {'login': 'scottferg',
#   'id': 74309,
#   'node_id': 'MDQ6VXNlcjc0MzA5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/74309?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/scottferg',
#   'html_url': 'https://github.com/scottferg',
#   'followers_url': 'https://api.github.com/users/scottferg/followers',
#   'following_url': 'https://api.github.com/users/scottferg/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/scottferg/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/scottferg/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/scottferg/subscriptions',
#   'organizations_url': 'https://api.github.com/users/scottferg/orgs',
#   'repos_url': 'https://api.github.com/users/scottferg/repos',
#   'events_url': 'https://api.github.com/users/scottferg/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/scottferg/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False,
#   'score': 1.0}]

# %% [markdown]
# ### get users details in given format

# %%
users = []

for user in chicago_users:
    response = requests.get(user["url"], headers=headers)
    if response.status_code == 200:
        user_info = response.json()
        users.append({
            "login": user_info["login"],
            "name": user_info.get("name") or "",
            "company": user_info.get("company") or "",
            "location": user_info.get("location")  or "",
            "email": user_info.get("email")  or "",
            "hireable": user_info.get("hireable") or "",
            "bio": user_info.get("bio") or "",
            "public_repos": user_info["public_repos"]  or "",
            "followers": user_info["followers"]  or "",
            "following": user_info["following"]  or "",
            "created_at": user_info["created_at"]  or "",
        })
    else:
        print("Error:", response.status_code, response.json())
        break

# %%
users
# Out:
# [{'login': 'cassidoo',
#   'name': 'Cassidy Williams',
#   'company': 'GitHub',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Making memes and dreams... and software',
#   'public_repos': 165,
#   'followers': 13383,
#   'following': 102,
#   'created_at': '2012-02-20T16:36:23Z'},
#  {'login': 'felangel',
#   'name': 'Felix Angelov',
#   'company': '@shorebirdtech',
#   'location': 'Chicago',
#   'email': 'felangelov@gmail.com',
#   'hireable': '',
#   'bio': 'software engineer by day, software engineer by night.',
#   'public_repos': 125,
#   'followers': 8680,
#   'following': 67,
#   'created_at': '2014-09-22T02:35:58Z'},
#  {'login': 'dabeaz',
#   'name': 'David Beazley',
#   'company': 'Dabeaz, LLC',
#   'location': 'Chicago',
#   'email': 'dave@dabeaz.com',
#   'hireable': '',
#   'bio': "Author of the Python Essential Reference (Addison-Wesley), Python Cookbook (O'Reilly), and former computer science professor. Come take a class! ",
#   'public_repos': 34,
#   'followers': 5181,
#   'following': '',
#   'created_at': '2010-08-01T15:22:48Z'},
#  {'login': 'sstephenson',
#   'name': 'Sam Stephenson',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'sam@sls.name',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 24,
#   'followers': 3761,
#   'following': '',
#   'created_at': '2008-03-08T22:17:24Z'},
#  {'login': 'mattgodbolt',
#   'name': 'Matt Godbolt',
#   'company': 'Aquatic Capital Management',
#   'location': 'Chicago, IL',
#   'email': 'matt@godbolt.org',
#   'hireable': '',
#   'bio': 'Compiler Explorer and jsbeeb creator, ex-Google, ex-games, now trading chap.',
#   'public_repos': 84,
#   'followers': 3398,
#   'following': 97,
#   'created_at': '2011-02-23T13:46:48Z'},
#  {'login': 'logankilpatrick',
#   'name': 'Logan Kilpatrick ',
#   'company': 'Google',
#   'location': 'Chicago | SF Bay',
#   'email': '',
#   'hireable': '',
#   'bio': '@Google AI Studio & the Gemini API, President @NumFOCUS',
#   'public_repos': 229,
#   'followers': 2732,
#   'following': 259,
#   'created_at': '2018-01-18T19:36:30Z'},
#  {'login': 'khan4019',
#   'name': 'That JS Dude',
#   'company': 'Nielsen',
#   'location': 'Chicago',
#   'email': 'khan4019@gmail.com',
#   'hireable': True,
#   'bio': 'A curious JavaScript developer, a frequent speaker and a tube light. On his enjoyable day he eats cauliflower and pulls his hair to solve programming problem.',
#   'public_repos': 104,
#   'followers': 2668,
#   'following': '',
#   'created_at': '2012-06-13T23:23:23Z'},
#  {'login': 'adashofdata',
#   'name': 'Alice Zhao',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "Data Scientist. Author of SQL Pocket Guide, 4th Edition (O'Reilly). Instructor at Northwestern University, O'Reilly and Maven Analytics / Udemy.",
#   'public_repos': 6,
#   'followers': 2452,
#   'following': '',
#   'created_at': '2017-07-20T16:27:23Z'},
#  {'login': 'djspiewak',
#   'name': 'Daniel Spiewak',
#   'company': '@nvidia',
#   'location': 'Chicago, IL',
#   'email': 'djspiewak@gmail.com',
#   'hireable': '',
#   'bio': "I write code, read papers, and think thoughts. Broadly, I'm interested in: type theory, parser theory, functional abstractions, data structures, performance.",
#   'public_repos': 143,
#   'followers': 2303,
#   'following': '',
#   'created_at': '2008-02-24T18:54:37Z'},
#  {'login': 'eddelbuettel',
#   'name': 'Dirk Eddelbuettel',
#   'company': '',
#   'location': 'Chicago, IL, USA',
#   'email': 'edd@debian.org',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 471,
#   'followers': 1848,
#   'following': 44,
#   'created_at': '2011-03-16T13:44:54Z'},
#  {'login': 'natemoo-re',
#   'name': 'Nate Moore',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Designer-turned-developer building open source tooling to empower fellow creatives',
#   'public_repos': 242,
#   'followers': 1742,
#   'following': 87,
#   'created_at': '2014-03-31T17:15:24Z'},
#  {'login': 'lexi-lambda',
#   'name': 'Alexis King',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 147,
#   'followers': 1680,
#   'following': 1,
#   'created_at': '2011-04-29T23:25:59Z'},
#  {'login': 'neodigm',
#   'name': 'Scott C. Krause',
#   'company': 'Independent',
#   'location': 'Chicago ✈️ the Future',
#   'email': '',
#   'hireable': True,
#   'bio': 'I design high-fidelity prototypes then build interactive experiences. I craft self-documenting and future-proof JavaScript ⚡ Web Components ⚡ WASM',
#   'public_repos': 411,
#   'followers': 1448,
#   'following': 5927,
#   'created_at': '2012-12-30T05:22:47Z'},
#  {'login': 'rentzsch',
#   'name': 'Wolf Rentzsch',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 148,
#   'followers': 1212,
#   'following': 2,
#   'created_at': '2008-03-13T04:23:19Z'},
#  {'login': 'HFTrader',
#   'name': 'Henrique Bucher',
#   'company': 'Vitorian LLC',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'Consulting and development C++/FPGA/GPU. Focus on Ultra Low Latency Trading. Crypto. Ex-Citadel, ex-JP Morgan. Brazilian, BSc/MSc/PhD in Engineering.',
#   'public_repos': 113,
#   'followers': 1209,
#   'following': 6,
#   'created_at': '2015-03-23T22:47:11Z'},
#  {'login': 'JimLiu',
#   'name': 'Jim Liu 宝玉',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'junminliu@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 205,
#   'followers': 1196,
#   'following': 134,
#   'created_at': '2011-03-03T09:18:48Z'},
#  {'login': 'jcs',
#   'name': 'joshua stein',
#   'company': '@pushoverapp ',
#   'location': 'chicago, illinois',
#   'email': 'jcs@jcs.org',
#   'hireable': '',
#   'bio': 'Hello, cyberpals',
#   'public_repos': 98,
#   'followers': 1084,
#   'following': 16,
#   'created_at': '2008-05-10T17:03:32Z'},
#  {'login': 'jbranchaud',
#   'name': 'Josh Branchaud',
#   'company': 'Independent, work with me --> visualmode.dev',
#   'location': 'Chicago, IL',
#   'email': 'jbranchaud@gmail.com',
#   'hireable': True,
#   'bio': 'Independent Software Consultant and Developer at VisualMode. TS • React • Rails • Postgres',
#   'public_repos': 171,
#   'followers': 1080,
#   'following': 115,
#   'created_at': '2011-03-28T00:17:53Z'},
#  {'login': 'basecamp',
#   'name': 'Basecamp',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'support@basecamp.com',
#   'hireable': '',
#   'bio': "HEY! It's in Basecamp!",
#   'public_repos': 193,
#   'followers': 989,
#   'following': '',
#   'created_at': '2008-06-09T20:00:38Z'},
#  {'login': 'SciSharp',
#   'name': 'SciSharp STACK',
#   'company': '',
#   'location': 'Chicago, US',
#   'email': 'scisharpstack@gmail.com',
#   'hireable': '',
#   'bio': 'A .NET based Open Source Ecosystem for Data Science, Machine Learning and AI.',
#   'public_repos': 66,
#   'followers': 961,
#   'following': '',
#   'created_at': '2018-11-13T02:23:44Z'},
#  {'login': 'joshdholtz',
#   'name': 'Josh Holtz',
#   'company': '@RevenueCat ',
#   'location': 'Chicago, IL (Previously Milwaukee, WI)',
#   'email': 'me@joshholtz.com',
#   'hireable': '',
#   'bio': 'Lead maintainer of @fastlane 🚀 SDKs at RevenueCat 💵😻',
#   'public_repos': 214,
#   'followers': 928,
#   'following': 6,
#   'created_at': '2010-09-16T01:26:03Z'},
#  {'login': 'johnpolacek',
#   'name': 'John Polacek',
#   'company': 'Howl',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Senior Software Engineer at VEG. Based in Chicago. johnpolacek.com',
#   'public_repos': 127,
#   'followers': 862,
#   'following': 1,
#   'created_at': '2010-01-10T14:41:10Z'},
#  {'login': 'davidteather',
#   'name': 'David Teather',
#   'company': '@CrowdStrike',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'I like open source projects and making educational content | SWE @CrowdStrike ',
#   'public_repos': 59,
#   'followers': 847,
#   'following': 107,
#   'created_at': '2017-11-30T22:36:19Z'},
#  {'login': 'jeremyckahn',
#   'name': 'Jeremy Kahn',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'me@jeremyckahn.com',
#   'hireable': '',
#   'bio': 'I fight for the users! 💪',
#   'public_repos': 155,
#   'followers': 837,
#   'following': 536,
#   'created_at': '2010-08-16T19:18:08Z'},
#  {'login': 'dchelimsky',
#   'name': 'David Chelimsky',
#   'company': 'Retired',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 107,
#   'followers': 813,
#   'following': 7,
#   'created_at': '2008-02-27T14:51:22Z'},
#  {'login': 'coreyhaines',
#   'name': 'Corey Haines',
#   'company': '',
#   'location': 'chicago, il',
#   'email': 'coreyhaines@gmail.com',
#   'hireable': True,
#   'bio': 'Magical!',
#   'public_repos': 155,
#   'followers': 812,
#   'following': 16,
#   'created_at': '2008-03-27T13:12:53Z'},
#  {'login': 'rharter',
#   'name': 'Ryan Harter',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 215,
#   'followers': 786,
#   'following': 4,
#   'created_at': '2011-12-31T18:08:39Z'},
#  {'login': 'harperreed',
#   'name': 'Harper Reed',
#   'company': 'Harper Rules, LLC',
#   'location': 'Chicago, Il',
#   'email': 'harper@modest.com',
#   'hireable': '',
#   'bio': 'A normal person doing normal things.',
#   'public_repos': 182,
#   'followers': 783,
#   'following': 148,
#   'created_at': '2008-07-26T18:45:02Z'},
#  {'login': 'sksamuel',
#   'name': 'Sam',
#   'company': 'Grindr',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Bit of this, bit of that.',
#   'public_repos': 22,
#   'followers': 782,
#   'following': 21,
#   'created_at': '2011-04-21T12:31:28Z'},
#  {'login': 'leeoniya',
#   'name': 'Leon Sorokin',
#   'company': '@grafana',
#   'location': 'Chicago, IL',
#   'email': 'leeoniya@gmail.com',
#   'hireable': '',
#   'bio': '"All problems in computer science can be solved by another level of abstraction ...except for the problem of too many levels of abstraction."',
#   'public_repos': 175,
#   'followers': 776,
#   'following': 348,
#   'created_at': '2008-12-30T00:27:29Z'},
#  {'login': 'hwayne',
#   'name': 'Hillel Wayne',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 47,
#   'followers': 762,
#   'following': 21,
#   'created_at': '2012-10-26T21:51:04Z'},
#  {'login': 'CoralineAda',
#   'name': 'Coraline Ada Ehmke',
#   'company': '@EthicalSource ',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Internationally recognized tech ethicist, activist, & software engineer. Creator of Contributor Covenant & Hippocratic License. Ruby Hero. FOSS troublemaker.',
#   'public_repos': 136,
#   'followers': 756,
#   'following': 5,
#   'created_at': '2008-08-28T02:37:32Z'},
#  {'login': 'sean-codes',
#   'name': 'Sean Codes',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'sean_codes@outlook.com',
#   'hireable': '',
#   'bio': 'Hi! Web Apps and 2D Games :]',
#   'public_repos': 36,
#   'followers': 708,
#   'following': 25,
#   'created_at': '2016-09-01T13:41:42Z'},
#  {'login': 'gjreda',
#   'name': 'Greg Reda',
#   'company': '@instacart',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 42,
#   'followers': 684,
#   'following': 118,
#   'created_at': '2011-07-18T03:57:34Z'},
#  {'login': 'jameslamb',
#   'name': 'James Lamb',
#   'company': 'NVIDIA',
#   'location': 'Chicago, IL',
#   'email': 'jaylamb20@gmail.com',
#   'hireable': '',
#   'bio': '(he/him) RAPIDS packaging at NVIDIA. LightGBM maintainer. Economist at heart. ',
#   'public_repos': 88,
#   'followers': 669,
#   'following': 255,
#   'created_at': '2014-05-17T05:32:21Z'},
#  {'login': 'djsime1',
#   'name': 'David',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "Fluent in Lua, Java, and Python; certified nerd.\r\nI put too much effort into README's and frequently overdose on colorful yet useless badges.",
#   'public_repos': 41,
#   'followers': 666,
#   'following': 13,
#   'created_at': '2014-08-21T22:15:54Z'},
#  {'login': 'dabeaz-course',
#   'name': 'Dabeaz LLC',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'dabeaz@dabeaz.com',
#   'hireable': '',
#   'bio': 'Courses by David Beazley',
#   'public_repos': 2,
#   'followers': 638,
#   'following': '',
#   'created_at': '2020-05-13T16:47:19Z'},
#  {'login': 'lorenanicole',
#   'name': 'Lorena Mesa',
#   'company': '@github ',
#   'location': 'Chicago, Illinois',
#   'email': 'me@lorenamesa.com',
#   'hireable': '',
#   'bio': 'Political analyst turned coder, Lorena Mesa is a #Latinx data engineer, ex-@github, Former Chair of the @python Software Foundation, @PyLadiesChicago organizer.',
#   'public_repos': 256,
#   'followers': 618,
#   'following': 11,
#   'created_at': '2013-05-30T19:15:17Z'},
#  {'login': 'LadyKerr',
#   'name': 'Kedasha Kerr',
#   'company': 'Developer Advocate',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Developer Advocate @github and Technical Content Creator 🎥 Catch my next video on IG @itsthatladydev ✨',
#   'public_repos': 181,
#   'followers': 616,
#   'following': 69,
#   'created_at': '2019-01-30T17:25:04Z'},
#  {'login': 'dannguyen',
#   'name': 'Dan Nguyen',
#   'company': 'Freelancer, data wrangler/engineer',
#   'location': 'Chicago',
#   'email': 'dansonguyen@gmail.com',
#   'hireable': True,
#   'bio': 'My name is Dan Nguyen and you can find me on Github as dannguyen & @dancow on Twitter. My interests are investigative journalism, data wrangling, and naming thi',
#   'public_repos': 374,
#   'followers': 612,
#   'following': 329,
#   'created_at': '2009-08-31T15:34:59Z'},
#  {'login': 'awatson1978',
#   'name': 'Abigail Watson',
#   'company': 'Symptomatic, LLC',
#   'location': 'Chicago - Evansville',
#   'email': 'awatson1978@gmail.com',
#   'hireable': '',
#   'bio': 'Bioinformaticist.  Venture Altruist.  Biohacker.   Burner.  Xinnial.  Healthcare worker.  \r\n',
#   'public_repos': 219,
#   'followers': 590,
#   'following': 7,
#   'created_at': '2011-03-17T20:50:48Z'},
#  {'login': 'trek',
#   'name': 'Trek Glowacki',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'I helped start @workantile, couponed at @groupon, usually helping some startup get acquired. @emberjs core team emeritus. @paulirish once called me a hero',
#   'public_repos': 26,
#   'followers': 581,
#   'following': '',
#   'created_at': '2008-05-08T22:08:55Z'},
#  {'login': 'Valve',
#   'name': '',
#   'company': 'Fingerprint.com',
#   'location': 'Chicago, USA',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm a Ruby on Rails developer but also like golang. Love cycling and reading.",
#   'public_repos': 61,
#   'followers': 575,
#   'following': 30,
#   'created_at': '2008-10-03T08:52:38Z'},
#  {'login': 'catarak',
#   'name': 'Cassie Tarakajian',
#   'company': 'prev @Cycling74, @processing ',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'all technology is political',
#   'public_repos': 72,
#   'followers': 562,
#   'following': 14,
#   'created_at': '2013-11-29T03:02:52Z'},
#  {'login': 'scopatz',
#   'name': 'Anthony Scopatz',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'scopatz@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 396,
#   'followers': 550,
#   'following': 269,
#   'created_at': '2010-07-01T22:20:46Z'},
#  {'login': 'ZeweiChu',
#   'name': 'Zewei Chu',
#   'company': 'Google',
#   'location': 'Chicago',
#   'email': 'zeweichu@gmail.com',
#   'hireable': True,
#   'bio': 'Metaverse, Blockchain, AI, NLP',
#   'public_repos': 68,
#   'followers': 550,
#   'following': 287,
#   'created_at': '2012-07-23T12:43:49Z'},
#  {'login': 'peterpme',
#   'name': 'Peter Piekarczyk',
#   'company': '@coral-xyz',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Building Backpack 🎒 ',
#   'public_repos': 217,
#   'followers': 545,
#   'following': 253,
#   'created_at': '2011-11-22T02:54:04Z'},
#  {'login': 'bitsondatadev',
#   'name': 'Brian "bits" Olsen',
#   'company': '@trinodb @apache',
#   'location': 'Chicago, United States',
#   'email': 'bits@bitsondata.dev',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 46,
#   'followers': 542,
#   'following': 11909,
#   'created_at': '2014-08-25T16:49:19Z'},
#  {'login': 'estrattonbailey',
#   'name': 'Eric Bailey',
#   'company': '@bluesky-social',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Internet person',
#   'public_repos': 179,
#   'followers': 518,
#   'following': 452,
#   'created_at': '2013-06-18T21:05:38Z'},
#  {'login': 'phinze',
#   'name': 'Paul Hinze',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 155,
#   'followers': 517,
#   'following': 35,
#   'created_at': '2008-12-01T14:28:06Z'},
#  {'login': 'lvh',
#   'name': 'lvh',
#   'company': '@Latacora',
#   'location': 'Chicago, IL',
#   'email': '_@lvh.io',
#   'hireable': '',
#   'bio': 'Principal, Latacora. We build security teams.',
#   'public_repos': 188,
#   'followers': 515,
#   'following': '',
#   'created_at': '2009-06-22T14:36:57Z'},
#  {'login': 'jorgecoca',
#   'name': 'Jorge Coca',
#   'company': '@VGVentures',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Head of Engineering - @VGVentures. \r\nGoogle Developer Experter - Flutter\r\nEx core mobile @bmw-tech. \r\nOrganizer of @ChicagoFlutter. ',
#   'public_repos': 9,
#   'followers': 512,
#   'following': 225,
#   'created_at': '2013-01-10T18:05:45Z'},
#  {'login': 'bgardner',
#   'name': 'Brian Gardner',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'brian.gardner@wpengine.com',
#   'hireable': '',
#   'bio': 'Designer. #WordPress expert.',
#   'public_repos': 2,
#   'followers': 494,
#   'following': 262,
#   'created_at': '2010-11-17T23:06:34Z'},
#  {'login': 'adriangb',
#   'name': 'Adrian Garcia Badaracco',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 177,
#   'followers': 493,
#   'following': 330,
#   'created_at': '2012-05-19T15:47:00Z'},
#  {'login': 'Templarian',
#   'name': 'Austin Andrews',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Maintainer of Material Design Icons',
#   'public_repos': 69,
#   'followers': 492,
#   'following': 8,
#   'created_at': '2010-07-20T18:37:13Z'},
#  {'login': 'jamesturk',
#   'name': 'James Turk',
#   'company': 'University of Chicago',
#   'location': 'Chicago, IL',
#   'email': 'dev@jpt.sh',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 31,
#   'followers': 482,
#   'following': 83,
#   'created_at': '2008-04-21T04:48:06Z'},
#  {'login': 'an0',
#   'name': 'Ling Wang',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 27,
#   'followers': 481,
#   'following': 3,
#   'created_at': '2009-07-02T09:33:10Z'},
#  {'login': 'kierisi',
#   'name': 'Jesse Mostipak',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 18,
#   'followers': 469,
#   'following': 56,
#   'created_at': '2016-10-26T19:58:51Z'},
#  {'login': 'derekeder',
#   'name': 'Derek Eder',
#   'company': 'DataMade, Chi Hack Night',
#   'location': 'Chicago, IL',
#   'email': 'derek@derekeder.com',
#   'hireable': '',
#   'bio': 'Partner at @datamade. Organizer of @chihacknight. I use data, build tools, and organize people in Chicago to democratize power.',
#   'public_repos': 45,
#   'followers': 467,
#   'following': 137,
#   'created_at': '2011-07-16T14:15:04Z'},
#  {'login': 'rachelbaker',
#   'name': 'Rachel Baker',
#   'company': 'Stitch Fix',
#   'location': 'Chicago, IL',
#   'email': 'rachel@rachelbaker.me',
#   'hireable': '',
#   'bio': 'Director of Engineering @stitchfix. Prev. Head of Engineering + Data Wirecutter (part of @nytimes). @WordPress Core Committer. \r\nShe/her',
#   'public_repos': 29,
#   'followers': 462,
#   'following': 230,
#   'created_at': '2011-08-14T21:30:31Z'},
#  {'login': 'iSoron',
#   'name': 'Alinson S. Xavier',
#   'company': 'Argonne National Laboratory',
#   'location': 'Chicago, IL',
#   'email': 'git@axavier.org',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 14,
#   'followers': 462,
#   'following': '',
#   'created_at': '2013-06-14T16:39:48Z'},
#  {'login': 'kpdecker',
#   'name': 'Kevin Decker',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kpdecker@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 130,
#   'followers': 460,
#   'following': 38,
#   'created_at': '2010-02-04T06:54:41Z'},
#  {'login': 'themeteorchef',
#   'name': 'The Meteor Chef',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'business@themeteorchef.com',
#   'hireable': True,
#   'bio': 'Sandwiches, Meteor, magic.',
#   'public_repos': 98,
#   'followers': 460,
#   'following': 33,
#   'created_at': '2014-07-16T18:16:31Z'},
#  {'login': 'gk5885',
#   'name': 'Gregory Kick',
#   'company': 'Google',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 7,
#   'followers': 449,
#   'following': 2,
#   'created_at': '2012-09-04T17:55:09Z'},
#  {'login': 'austinsonger',
#   'name': 'Austin Songer,MIS,CEH,ESCA,Project+ (Navy Veteran)',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': 'a.songer@protonmail.com',
#   'hireable': True,
#   'bio': 'Governance, Risk, and Compliance Lead\r\n\r\n',
#   'public_repos': 840,
#   'followers': 448,
#   'following': 1409,
#   'created_at': '2017-03-24T14:43:10Z'},
#  {'login': 'bwya77',
#   'name': 'Bradley Wyatt',
#   'company': 'Ntiva',
#   'location': 'Chicago',
#   'email': 'brad@thelazyadministrator.com',
#   'hireable': True,
#   'bio': 'Microsoft MVP | The Lazy Administrator | DevOps Automation Engineer at Ntiva',
#   'public_repos': 34,
#   'followers': 444,
#   'following': 28,
#   'created_at': '2014-01-02T03:41:12Z'},
#  {'login': 'ELLIOTTCABLE',
#   'name': '',
#   'company': '@Ahrefs',
#   'location': 'Chicago, IL',
#   'email': 'github-public@from.ec',
#   'hireable': True,
#   'bio': '{PL,Q}T. Accidental creator of @Paws.',
#   'public_repos': 243,
#   'followers': 442,
#   'following': 826,
#   'created_at': '2008-02-13T03:27:01Z'},
#  {'login': 'tqbf',
#   'name': 'Thomas <b>H. Ptacek"',
#   'company': 'Ketchup Salt',
#   'location': 'Chicago, IL',
#   'email': 'thomas@sockpuppet.org',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 30,
#   'followers': 439,
#   'following': 1,
#   'created_at': '2008-06-11T23:59:12Z'},
#  {'login': 'vehbiu',
#   'name': 'Vehbi',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 10,
#   'followers': 435,
#   'following': '',
#   'created_at': '2023-02-22T15:56:12Z'},
#  {'login': 'mjskay',
#   'name': 'Matthew Kay',
#   'company': 'Northwestern University',
#   'location': 'Chicago',
#   'email': 'mjskay@northwestern.edu',
#   'hireable': '',
#   'bio': 'Associate Professor at Northwestern; works on human-computer interaction, information visualization, communicating uncertainty',
#   'public_repos': 59,
#   'followers': 434,
#   'following': 1,
#   'created_at': '2014-01-08T01:48:16Z'},
#  {'login': 'mapmeld',
#   'name': 'Nick Doiron',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ndoiron@mapmeld.com',
#   'hireable': True,
#   'bio': 'Full-stack engineer and open source in ML / NLP',
#   'public_repos': 274,
#   'followers': 428,
#   'following': 11,
#   'created_at': '2011-03-01T03:09:47Z'},
#  {'login': 'carolynvs',
#   'name': 'Carolyn Van Slyck',
#   'company': '@Azure ',
#   'location': 'Chicago, IL',
#   'email': 'me@carolynvanslyck.com',
#   'hireable': '',
#   'bio': 'Professional Yak Shaver',
#   'public_repos': 273,
#   'followers': 412,
#   'following': 2,
#   'created_at': '2012-01-22T21:34:25Z'},
#  {'login': 'DashBarkHuss',
#   'name': 'Dashiell Bark-Huss',
#   'company': 'WishTender',
#   'location': 'Chicago',
#   'email': 'dangerousdashie@gmail.com',
#   'hireable': '',
#   'bio': 'Self taught programmer. Building WishTender. Lucid dream enthusiast.',
#   'public_repos': 76,
#   'followers': 408,
#   'following': 12,
#   'created_at': '2015-06-19T16:10:41Z'},
#  {'login': 'zigurous',
#   'name': 'Zigurous',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'support@zigurous.com',
#   'hireable': '',
#   'bio': 'Zigurous is an indie game developer.',
#   'public_repos': 36,
#   'followers': 405,
#   'following': '',
#   'created_at': '2016-01-17T01:13:04Z'},
#  {'login': 'brandonleegit',
#   'name': 'Brandon Lee',
#   'company': 'VirtualizationHowto',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Prolific Virtualization blogger and IT Technologist specializing in virtualization and cloud',
#   'public_repos': 16,
#   'followers': 400,
#   'following': '',
#   'created_at': '2016-09-12T16:55:01Z'},
#  {'login': 'rsese',
#   'name': 'Robert Sese',
#   'company': 'GitHub',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': ':horse: :pizza:',
#   'public_repos': 44,
#   'followers': 395,
#   'following': 144,
#   'created_at': '2011-04-17T01:44:30Z'},
#  {'login': 'boonebgorges',
#   'name': 'Boone Gorges',
#   'company': 'https://hardg.com',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Emeritus committer for @WordPress; Emeritus lead for @buddypress; WordPress consultant',
#   'public_repos': 131,
#   'followers': 393,
#   'following': 30,
#   'created_at': '2010-04-18T13:36:23Z'},
#  {'login': 'jarry-xiao',
#   'name': 'Jarry Xiao',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'blockchain x quant finance',
#   'public_repos': 23,
#   'followers': 387,
#   'following': 10,
#   'created_at': '2020-02-15T18:05:16Z'},
#  {'login': 'the-raspberry-pi-guy',
#   'name': 'Matt Timmons-Brown (Raspberry Pi Guy)',
#   'company': 'Jump Trading',
#   'location': 'Chicago',
#   'email': 'theraspberrypiguy@gmail.com',
#   'hireable': True,
#   'bio': 'SWE @ Jump Trading | CS Masters @ UPenn | Thouron Scholar | Ex-Amazon | Ex-CompSci @ Edinburgh | Author of "Learn Robotics w. Raspberry Pi", link ↓↓↓',
#   'public_repos': 31,
#   'followers': 384,
#   'following': 95,
#   'created_at': '2013-09-29T15:30:39Z'},
#  {'login': 'saforem2',
#   'name': 'Sam Foreman',
#   'company': '@argonne-lcf ',
#   'location': 'Chicago, IL',
#   'email': 'saforem2@gmail.com',
#   'hireable': True,
#   'bio': 'AI 4 Science @argonne-lcf \r\nhttps://samforeman.me\r\n',
#   'public_repos': 188,
#   'followers': 377,
#   'following': 685,
#   'created_at': '2013-08-15T02:33:02Z'},
#  {'login': 'ZWMiller',
#   'name': 'Zach Miller',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Machine Learning Engineer. Nuclear Physics Ph.D. fluent with Python, SQL, and C++.',
#   'public_repos': 43,
#   'followers': 376,
#   'following': 5,
#   'created_at': '2015-07-24T18:13:27Z'},
#  {'login': 'matagus',
#   'name': 'Matías Agustín Méndez',
#   'company': '',
#   'location': 'Chicago, IL ',
#   'email': '',
#   'hireable': True,
#   'bio': 'I miss the old Github feed / activity stream. @matorral-project | @django-planet #django #python #rust',
#   'public_repos': 48,
#   'followers': 371,
#   'following': 3468,
#   'created_at': '2009-02-27T10:45:55Z'},
#  {'login': 'skwp',
#   'name': 'Yan Pritzker',
#   'company': 'SwanBitcoin.com',
#   'location': 'Chicago',
#   'email': 'yan@pritzker.ws',
#   'hireable': '',
#   'bio': 'Co-founder swan.com @swan-bitcoin, author inventingbitcoin.com, Former CTO @reverbdotcom. Contact at https://twitter.com/skwp',
#   'public_repos': 60,
#   'followers': 362,
#   'following': 53,
#   'created_at': '2008-02-29T17:02:06Z'},
#  {'login': 'stevespringett',
#   'name': 'Steve Springett',
#   'company': '@ServiceNow',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'I build stuff, I break stuff, I develop stuff to protect stuff.\r\n\r\nCreator of @DependencyTrack. Chair of @CycloneDX and @Ecma-TC54. Core team of @package-url',
#   'public_repos': 30,
#   'followers': 361,
#   'following': 2,
#   'created_at': '2013-03-15T22:01:22Z'},
#  {'login': 'braverock',
#   'name': 'Brian G. Peterson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'brian@braverock.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 12,
#   'followers': 360,
#   'following': 6,
#   'created_at': '2012-04-22T17:32:42Z'},
#  {'login': 'jenmyers',
#   'name': 'Jen Myers',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm a swell gal.",
#   'public_repos': 18,
#   'followers': 360,
#   'following': '',
#   'created_at': '2011-03-10T16:05:12Z'},
#  {'login': 'gar1t',
#   'name': 'Garrett Smith',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 213,
#   'followers': 360,
#   'following': 4,
#   'created_at': '2010-01-18T21:49:39Z'},
#  {'login': 'MarkTechson',
#   'name': 'Mark Thompson',
#   'company': '@angular ',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'A developer who loves coding, teaching and pancakes.',
#   'public_repos': 97,
#   'followers': 360,
#   'following': 1,
#   'created_at': '2012-10-14T01:17:42Z'},
#  {'login': 'Tedko',
#   'name': 'Suji Yan',
#   'company': '@DimensionDev',
#   'location': 'Tokyo/SF/Chicago/NYC/Shanghai',
#   'email': 'suji.yan@dimension.im',
#   'hireable': '',
#   'bio': 'Founder/CEO of Dimension.im/Mask Network\r\n',
#   'public_repos': 56,
#   'followers': 357,
#   'following': 84,
#   'created_at': '2014-02-15T03:06:40Z'},
#  {'login': 'sabre1041',
#   'name': 'Andrew Block',
#   'company': 'Red Hat',
#   'location': 'Chicago',
#   'email': 'andy.block@gmail.com',
#   'hireable': '',
#   'bio': 'Distinguished Architect at Red Hat',
#   'public_repos': 463,
#   'followers': 352,
#   'following': 24,
#   'created_at': '2011-11-13T04:27:23Z'},
#  {'login': 'loganmartintran',
#   'name': 'Logan Tran',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 14,
#   'followers': 350,
#   'following': 14,
#   'created_at': '2016-08-17T00:08:46Z'},
#  {'login': 'abedra',
#   'name': 'Aaron Bedra',
#   'company': 'DRW',
#   'location': 'Chicago, IL',
#   'email': 'aaron@aaronbedra.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 77,
#   'followers': 349,
#   'following': 2,
#   'created_at': '2008-03-03T23:46:03Z'},
#  {'login': 'trevorturk',
#   'name': 'Trevor Turk',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'trevorturk@gmail.com',
#   'hireable': True,
#   'bio': 'Programming Hello Weather. Previously Impactive, IFTTT, Clearbit, and Basecamp.',
#   'public_repos': 79,
#   'followers': 345,
#   'following': 189,
#   'created_at': '2008-02-19T03:23:56Z'},
#  {'login': 'justinbmeyer',
#   'name': 'Justin Meyer',
#   'company': 'Bitovi',
#   'location': 'Chicago',
#   'email': 'justinbmeyer@gmail.com',
#   'hireable': '',
#   'bio': 'Co-founder @bitovi.  Contributor to @donejs, @canjs, @stealjs and others.',
#   'public_repos': 26,
#   'followers': 342,
#   'following': 29,
#   'created_at': '2009-04-28T03:33:52Z'},
#  {'login': 'RandomFractals',
#   'name': 'Taras Novak',
#   'company': 'Random Fractals, Inc.',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': True,
#   'bio': 'We map 🗺️ & graph 📈 data  🈸',
#   'public_repos': 110,
#   'followers': 341,
#   'following': '',
#   'created_at': '2011-03-08T02:39:42Z'},
#  {'login': 'srobbin',
#   'name': 'Scott Robbin',
#   'company': 'Robbin & Co.',
#   'location': 'Chicago',
#   'email': 'scott@robbin.co',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 46,
#   'followers': 339,
#   'following': 22,
#   'created_at': '2009-01-07T01:44:50Z'},
#  {'login': 'coolbeet',
#   'name': 'Suyu Zhang',
#   'company': 'Chowbus',
#   'location': 'Chicago',
#   'email': 'suyu_zhang@hotmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 8,
#   'followers': 338,
#   'following': 2,
#   'created_at': '2012-07-30T02:43:33Z'},
#  {'login': 'timrwood',
#   'name': 'Tim Wood',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 42,
#   'followers': 337,
#   'following': 13,
#   'created_at': '2011-03-01T02:45:07Z'},
#  {'login': 'shayhowe',
#   'name': 'Shay Howe',
#   'company': '@leadhonestly ',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'CMO at @ActiveCampaign, Co-founder at @leadhonestly, Partner at @ProtaVentures, Co-Founder of @ChicagoCamps, Product Designer, Engineer',
#   'public_repos': 14,
#   'followers': 334,
#   'following': 1,
#   'created_at': '2010-12-07T17:10:24Z'},
#  {'login': 'ksobon',
#   'name': 'Konrad Sobon',
#   'company': 'Archi-lab',
#   'location': 'Chicago',
#   'email': 'sobon.konrad@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 49,
#   'followers': 332,
#   'following': 5,
#   'created_at': '2010-12-19T20:57:22Z'},
#  {'login': 'hugs',
#   'name': 'Jason Huggins',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': 'jrhuggins@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 74,
#   'followers': 327,
#   'following': 1,
#   'created_at': '2008-04-26T04:40:50Z'},
#  {'login': 'karllhughes',
#   'name': 'Karl L. Hughes',
#   'company': '@draftdev',
#   'location': 'Chicago, IL',
#   'email': 'khughes.me@gmail.com',
#   'hireable': '',
#   'bio': 'Former startup CTO turned writer. Creating technical marketing content as the founder of Draft.dev.',
#   'public_repos': 72,
#   'followers': 326,
#   'following': 35,
#   'created_at': '2011-10-05T02:11:06Z'},
#  {'login': 'Oceania2018',
#   'name': 'Haiping',
#   'company': '',
#   'location': 'Chicago, US',
#   'email': 'haiping008@gmail.com',
#   'hireable': True,
#   'bio': 'Bug fixing...',
#   'public_repos': 60,
#   'followers': 326,
#   'following': 118,
#   'created_at': '2012-05-04T09:54:33Z'},
#  {'login': 'emilyriederer',
#   'name': 'Emily Riederer',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'emilyriederer@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 26,
#   'followers': 321,
#   'following': 19,
#   'created_at': '2016-06-07T11:48:36Z'},
#  {'login': 'reiddraper',
#   'name': 'Reid Draper',
#   'company': '@figma ',
#   'location': 'Chicago, IL',
#   'email': 'reiddraper@gmail.com',
#   'hireable': '',
#   'bio': 'mayonnaise connoisseur',
#   'public_repos': 86,
#   'followers': 315,
#   'following': 62,
#   'created_at': '2010-02-09T16:04:56Z'},
#  {'login': 'sorentwo',
#   'name': 'Parker Selbert',
#   'company': 'Soren',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 55,
#   'followers': 314,
#   'following': 3,
#   'created_at': '2010-05-07T22:41:11Z'},
#  {'login': 'nickvourd',
#   'name': 'Nikos Vourdas',
#   'company': 'EY US',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Just your friendly neighborhood red Power Ranger:~# OSWE | OSEP | OSCP | OSWP | CRTL | CRTO | OASP',
#   'public_repos': 16,
#   'followers': 312,
#   'following': 153,
#   'created_at': '2017-10-17T10:45:01Z'},
#  {'login': 'jjhelmus',
#   'name': 'Jonathan J. Helmus',
#   'company': 'Anaconda',
#   'location': 'Chicago, IL',
#   'email': 'jjhelmus@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 424,
#   'followers': 310,
#   'following': 22,
#   'created_at': '2011-09-14T13:32:35Z'},
#  {'login': 'ahinchman1',
#   'name': 'Amanda Hinchman-Dominguez',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'Kotlin GDE and Android engineer. Co-organizer for CKUG.\r\n\r\nCo-author of "Programming Android with Kotlin: Achieving Structured Concurrency with Coroutines"',
#   'public_repos': 56,
#   'followers': 306,
#   'following': 26,
#   'created_at': '2014-03-11T10:10:24Z'},
#  {'login': 'XavierXiao',
#   'name': 'Xavier',
#   'company': 'University of Chicago',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 16,
#   'followers': 303,
#   'following': 1,
#   'created_at': '2015-09-15T23:43:17Z'},
#  {'login': 'coddingtonbear',
#   'name': 'Adam Coddington',
#   'company': 'Airship',
#   'location': 'Chicago, Illinois, USA',
#   'email': 'me@adamcoddington.net',
#   'hireable': '',
#   'bio': 'Not affiliated with non-🏳️\u200d🌈 types of bears.',
#   'public_repos': 218,
#   'followers': 301,
#   'following': 199,
#   'created_at': '2010-12-17T19:09:29Z'},
#  {'login': 'stevenwanderski',
#   'name': 'Steven Wanderski',
#   'company': 'Contractor',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 79,
#   'followers': 300,
#   'following': 2,
#   'created_at': '2010-11-09T00:32:00Z'},
#  {'login': 'JoeGermuska',
#   'name': 'Joe Germuska',
#   'company': 'Northwestern University Knight Lab',
#   'location': 'Chicago, IL',
#   'email': 'joe@germuska.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 101,
#   'followers': 298,
#   'following': 19,
#   'created_at': '2009-01-13T18:28:43Z'},
#  {'login': 'tswast',
#   'name': 'Tim Sweña (Swast)',
#   'company': 'Google',
#   'location': 'Chicago, IL',
#   'email': 'swast@google.com',
#   'hireable': '',
#   'bio': 'Data Engineer in Professional Services @GoogleCloudPlatform. I also hack on personal projects, mostly related to math & pixels.',
#   'public_repos': 154,
#   'followers': 295,
#   'following': 75,
#   'created_at': '2010-04-19T18:53:47Z'},
#  {'login': 'MelSumner',
#   'name': 'Melanie Sumner',
#   'company': '@hashicorp',
#   'location': 'Chicago, IL',
#   'email': 'melaniersumner@gmail.com',
#   'hireable': '',
#   'bio': 'Likes: continuous accessibility, building for the web, strategic planning, empowering others to succeed.',
#   'public_repos': 310,
#   'followers': 293,
#   'following': 168,
#   'created_at': '2013-06-01T13:42:33Z'},
#  {'login': 'greensock',
#   'name': 'GreenSock',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 4,
#   'followers': 289,
#   'following': '',
#   'created_at': '2012-09-20T14:57:30Z'},
#  {'login': 'ExplorerFreda',
#   'name': 'Freda Shi',
#   'company': 'Toyota Technological Institute at Chicago; University of Waterloo',
#   'location': 'Chicago, IL',
#   'email': 'freda@ttic.edu',
#   'hireable': '',
#   'bio': 'Assistant Professor at the University of Waterloo with @compling-wat & @waterloo-nlp.',
#   'public_repos': 31,
#   'followers': 288,
#   'following': 37,
#   'created_at': '2016-01-17T13:44:19Z'},
#  {'login': 'alysivji',
#   'name': 'Aly Sivji',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Python. HealthIT. Data.',
#   'public_repos': 134,
#   'followers': 287,
#   'following': 163,
#   'created_at': '2013-05-07T21:04:31Z'},
#  {'login': 'paulromano',
#   'name': 'Paul Romano',
#   'company': 'Argonne National Laboratory',
#   'location': 'Chicago, IL',
#   'email': 'promano@anl.gov',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 89,
#   'followers': 287,
#   'following': 113,
#   'created_at': '2011-04-21T05:43:12Z'},
#  {'login': 'tedivm',
#   'name': 'Robert Hafner',
#   'company': '@Comcast',
#   'location': 'Chicago, IL',
#   'email': 'tedivm@tedivm.com',
#   'hireable': '',
#   'bio': 'Lots of personal projects as well as @gitconsensus, @tedious, @LeagueOfAutomatedNations, and @screepers.',
#   'public_repos': 176,
#   'followers': 284,
#   'following': 162,
#   'created_at': '2009-09-01T00:56:22Z'},
#  {'login': 'rguthrie3',
#   'name': 'Robert',
#   'company': 'Citadel LLC',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software engineer at Citadel LLC and Georgia Tech grad.  Primarily interested in natural language processing, finance, and high-performance computing.',
#   'public_repos': 12,
#   'followers': 281,
#   'following': 8,
#   'created_at': '2014-03-05T14:11:26Z'},
#  {'login': 'FreedomWriter',
#   'name': 'Natalie Davis',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': "Frontend Engineer, share your screen (or I'll share mine), let's figure it out!",
#   'public_repos': 143,
#   'followers': 280,
#   'following': 54,
#   'created_at': '2019-05-08T03:30:46Z'},
#  {'login': 'nbriz',
#   'name': 'Nick Briz',
#   'company': 'https://netizen.org',
#   'location': 'Chicago, IL',
#   'email': 'nickbriz@protonmail.com',
#   'hireable': '',
#   'bio': 'new-media artist/educator/organizer >> focused on digital culture + digital literacy',
#   'public_repos': 65,
#   'followers': 279,
#   'following': 42,
#   'created_at': '2012-10-07T18:39:07Z'},
#  {'login': 'CodePlatoon',
#   'name': 'Code Platoon',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Turning veterans and military spouses into software developers.',
#   'public_repos': 14,
#   'followers': 278,
#   'following': '',
#   'created_at': '2015-10-30T18:39:53Z'},
#  {'login': 'mrkurt',
#   'name': 'Kurt Mackey',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'mrkurt@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 89,
#   'followers': 278,
#   'following': 17,
#   'created_at': '2008-04-17T18:10:49Z'},
#  {'login': 'kadamwhite',
#   'name': 'K Adam White',
#   'company': '@humanmade ',
#   'location': 'NYC, Raleigh, Chicago, Osaka',
#   'email': '',
#   'hireable': '',
#   'bio': 'Principal Engineer at Human Made, WordPress committer and former REST API maintainer, artist, DJ, and artist technician / spouse of Emily Garfield',
#   'public_repos': 101,
#   'followers': 273,
#   'following': 23,
#   'created_at': '2010-10-16T18:38:43Z'},
#  {'login': 'conorpp',
#   'name': 'Conor Patrick',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 124,
#   'followers': 273,
#   'following': 64,
#   'created_at': '2013-03-22T14:50:11Z'},
#  {'login': 'Daniel-McCarthy',
#   'name': 'Dan McCarthy',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 42,
#   'followers': 272,
#   'following': 129,
#   'created_at': '2013-07-07T05:17:39Z'},
#  {'login': 'msfrisbie',
#   'name': ' Matt Frisbie',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'classvsoftware@gmail.com',
#   'hireable': True,
#   'bio': 'Software engineer, bestselling author',
#   'public_repos': 56,
#   'followers': 270,
#   'following': '',
#   'created_at': '2011-12-04T17:42:52Z'},
#  {'login': 'bartosz-lipinski',
#   'name': 'B',
#   'company': '@cubexch',
#   'location': 'Chicago, US',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 33,
#   'followers': 270,
#   'following': 13,
#   'created_at': '2010-05-04T09:43:38Z'},
#  {'login': 'ivelasq',
#   'name': 'Isabella Velásquez',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ivelasq@gmail.com',
#   'hireable': '',
#   'bio': '%>% dreams',
#   'public_repos': 58,
#   'followers': 262,
#   'following': 51,
#   'created_at': '2015-05-04T14:40:14Z'},
#  {'login': 'joshbirk',
#   'name': 'Joshua Birk',
#   'company': 'salesforce.com',
#   'location': 'Chicago, IL',
#   'email': 'joshua.birk@salesforce.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 74,
#   'followers': 259,
#   'following': 54,
#   'created_at': '2010-11-24T18:43:03Z'},
#  {'login': 'pushcx',
#   'name': 'Peter Bhat Harkins',
#   'company': '@lobsters ',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': 'Programmer by day, programmer by night.',
#   'public_repos': 66,
#   'followers': 254,
#   'following': 8,
#   'created_at': '2008-04-10T20:13:29Z'},
#  {'login': 'jackdoyle',
#   'name': 'Jack Doyle',
#   'company': '@greensock ',
#   'location': 'Chicago',
#   'email': 'jack@greensock.com',
#   'hireable': '',
#   'bio': 'Author of GSAP, owner of @greensock, lover of animation',
#   'public_repos': 3,
#   'followers': 251,
#   'following': '',
#   'created_at': '2012-09-21T00:08:41Z'},
#  {'login': 'brandonwillard',
#   'name': 'Brandon T. Willard',
#   'company': '.txt',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'applied math/stats person',
#   'public_repos': 154,
#   'followers': 251,
#   'following': 93,
#   'created_at': '2011-08-10T14:19:12Z'},
#  {'login': 'rrag',
#   'name': 'Ragu Ramaswamy',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ragunath.ramaswamy@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 21,
#   'followers': 250,
#   'following': 38,
#   'created_at': '2015-01-25T03:05:43Z'},
#  {'login': 'drewolson',
#   'name': 'Drew Olson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'software is fun',
#   'public_repos': 38,
#   'followers': 249,
#   'following': 21,
#   'created_at': '2008-03-21T16:01:37Z'},
#  {'login': 'ionelabrinza',
#   'name': 'Nicole Brinza',
#   'company': '',
#   'location': 'Chicago, USA',
#   'email': '',
#   'hireable': '',
#   'bio': ':)',
#   'public_repos': 45,
#   'followers': 247,
#   'following': 384,
#   'created_at': '2021-10-28T16:05:46Z'},
#  {'login': 'joemaddalone',
#   'name': 'Joe Maddalone',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software Engineer, Instructor at egghead.io, mentor/mentee, geekfest organizer',
#   'public_repos': 68,
#   'followers': 246,
#   'following': 1,
#   'created_at': '2010-12-01T16:22:57Z'},
#  {'login': 'jamigibbs',
#   'name': 'Jami Gibbs',
#   'company': '@adhocteam',
#   'location': 'Chicago',
#   'email': 'jami.gibbs@adhocteam.us',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 73,
#   'followers': 240,
#   'following': 40,
#   'created_at': '2011-06-24T04:17:20Z'},
#  {'login': 'mager',
#   'name': 'Mager',
#   'company': 'Uber',
#   'location': 'Chicago',
#   'email': 'andrew.mager@gmail.com',
#   'hireable': True,
#   'bio': 'Developer Experience @Uber. Lover of open source, web3, Go, React, databases, systems. Building Geotory on the weekend.',
#   'public_repos': 90,
#   'followers': 239,
#   'following': 463,
#   'created_at': '2008-07-21T21:49:48Z'},
#  {'login': 'mikehostetler',
#   'name': 'Mike Hostetler',
#   'company': 'Epic Creative',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'VP of Eng @carsdotcom, Leader, Entrepreneur, Technologist. Passionate about #RemoteWork #WorkOps #OSS #JavaScript #Crypto',
#   'public_repos': 157,
#   'followers': 238,
#   'following': 68,
#   'created_at': '2009-05-13T19:03:35Z'},
#  {'login': 'mstruve',
#   'name': 'Molly Struve',
#   'company': '@netflix',
#   'location': 'Chicago, IL',
#   'email': 'mollylbs@gmail.com',
#   'hireable': '',
#   'bio': 'Staff Site Reliability Engineer at Netflix',
#   'public_repos': 44,
#   'followers': 237,
#   'following': 3,
#   'created_at': '2012-06-04T00:17:32Z'},
#  {'login': 'jberger',
#   'name': 'Joel Berger',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Ph.D. in Physics, polyglot programmer (Perl, Python, Node, etc), @mojolicious core developer',
#   'public_repos': 187,
#   'followers': 234,
#   'following': 66,
#   'created_at': '2011-04-18T03:42:17Z'},
#  {'login': 'brianboyer',
#   'name': 'Brian Boyer',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 12,
#   'followers': 233,
#   'following': 17,
#   'created_at': '2009-03-30T15:09:05Z'},
#  {'login': 'mikewesthad',
#   'name': 'Michael Hadley',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Developer, Artist & Educator\r\n–––\r\nSoftware Engineer at Replit',
#   'public_repos': 147,
#   'followers': 233,
#   'following': 28,
#   'created_at': '2011-10-16T19:28:53Z'},
#  {'login': 'brasic',
#   'name': 'Carl Brasic',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 61,
#   'followers': 232,
#   'following': 13,
#   'created_at': '2011-03-18T14:39:19Z'},
#  {'login': 'braintreeps',
#   'name': 'Braintree Open Source',
#   'company': '@braintree ',
#   'location': 'Chicago, IL',
#   'email': 'code@getbraintree.com',
#   'hireable': '',
#   'bio': 'Tools for use by Braintree employees. These repositories receive no official support from Braintree.',
#   'public_repos': 47,
#   'followers': 232,
#   'following': 7,
#   'created_at': '2010-02-09T17:22:24Z'},
#  {'login': 'k4rtik',
#   'name': 'Kartik Singhal',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kartiksinghal@gmail.com',
#   'hireable': True,
#   'bio': 'Programming Languages, Quantum Computing, Systems, and more. In superposition with @qartik.',
#   'public_repos': 79,
#   'followers': 231,
#   'following': 190,
#   'created_at': '2010-08-24T07:50:15Z'},
#  {'login': 'MarcosX',
#   'name': 'Marcos Brizeno',
#   'company': 'ThoughtWorks',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 65,
#   'followers': 230,
#   'following': 18,
#   'created_at': '2011-06-17T12:17:24Z'},
#  {'login': 'jordanorelli',
#   'name': 'Jordan Orelli',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'infra engineer on the discovery team at Whatnot.  \r\n\r\nMy public git repos are now here:\r\nhttps://git.orel.li/jordan',
#   'public_repos': 84,
#   'followers': 229,
#   'following': 132,
#   'created_at': '2010-09-15T13:14:47Z'},
#  {'login': 'FormerLurker',
#   'name': 'FormerLurker',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm the creator of Octolapse, and hoping to create even more open source tools!  If you like what you see, consider becoming a sponsor.",
#   'public_repos': 13,
# ...
#   'followers': 114,
#   'following': 9,
#   'created_at': '2014-06-09T17:32:45Z'},
#  {'login': 'noelrappin',
#   'name': 'Noel Rappin',
#   'company': '@1debit ',
#   'location': 'Chicago',
#   'email': 'noelrap@noelrappin.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 58,
#   'followers': 114,
#   'following': '',
#   'created_at': '2008-04-07T20:19:01Z'},
#  {'login': 'kvnkho',
#   'name': 'Kevin Kho',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kdykho@gmail.com',
#   'hireable': '',
#   'bio': 'Fugue Maintainer\r\n@fugue-project @datakind @orlmlds @Nixtla \r\nPrev @PrefectHQ',
#   'public_repos': 25,
#   'followers': 114,
#   'following': 3,
#   'created_at': '2017-10-04T02:56:14Z'},
#  {'login': 'ivanfemia',
#   'name': 'Ivan',
#   'company': 'Google',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 22,
#   'followers': 114,
#   'following': 19,
#   'created_at': '2013-01-05T16:37:51Z'},
#  {'login': 'SarahMAmann',
#   'name': 'Sarah Benson',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'software engineer ✌️',
#   'public_repos': 24,
#   'followers': 113,
#   'following': 5,
#   'created_at': '2018-04-22T00:30:19Z'},
#  {'login': 'zircote',
#   'name': 'Robert Allen',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'zircote@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 83,
#   'followers': 112,
#   'following': 1,
#   'created_at': '2010-06-17T19:19:32Z'},
#  {'login': 'sonamoo',
#   'name': 'Seho Lim',
#   'company': 'MongoDB',
#   'location': 'Chicago',
#   'email': 'limseho657424@gmail.com',
#   'hireable': True,
#   'bio': 'Software Developer at MongoDB\r\n',
#   'public_repos': 49,
#   'followers': 112,
#   'following': 34,
#   'created_at': '2015-10-24T18:09:06Z'},
#  {'login': 'sleventyeleven',
#   'name': 'Michael Contino',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Dad of Tinny Humans, Tech Nerd, CCDC/NCL/OSCP Mentor, Linux Security SME, Kubernetes Security, Random Project Starter: Linuxprivchecker, Kubernetes-Harvester',
#   'public_repos': 22,
#   'followers': 112,
#   'following': 5,
#   'created_at': '2013-06-05T19:21:14Z'},
#  {'login': 'loucyx',
#   'name': 'Lou ✨',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': True,
#   'bio': '⛧ Code Witch ⛧',
#   'public_repos': 5,
#   'followers': 111,
#   'following': 129,
#   'created_at': '2013-03-26T22:07:08Z'},
#  {'login': 'mgrygles',
#   'name': 'Mary Grygleski',
#   'company': 'Callibrity',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'AI Practice Lead🤖@callibrity ::::::::::::\r\nTech Advocate🥑👩\u200d💻@tech-portico ::::\r\nJava Champion🏆https://javachampions.org',
#   'public_repos': 65,
#   'followers': 111,
#   'following': 46,
#   'created_at': '2014-03-11T18:50:55Z'},
#  {'login': 'rossb34',
#   'name': 'Ross Bennett',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 38,
#   'followers': 111,
#   'following': '',
#   'created_at': '2013-10-28T19:37:21Z'},
#  {'login': 'stamourv',
#   'name': 'Vincent St-Amour',
#   'company': 'PLT',
#   'location': 'Chicago, IL, USA',
#   'email': 'stamourv@racket-lang.org',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 112,
#   'followers': 111,
#   'following': '',
#   'created_at': '2011-06-16T15:59:34Z'},
#  {'login': 'alexlyp',
#   'name': 'Alex Yocom-Piatt',
#   'company': '@companyzero',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 48,
#   'followers': 110,
#   'following': '',
#   'created_at': '2013-05-09T16:01:09Z'},
#  {'login': 'deanrad',
#   'name': 'Dean Radcliffe',
#   'company': 'United Healthcare',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'Engineering Manager and Senior Full-Stack Engineer',
#   'public_repos': 248,
#   'followers': 110,
#   'following': 15,
#   'created_at': '2008-09-13T04:17:00Z'},
#  {'login': 'brianray',
#   'name': 'Brian Ray',
#   'company': 'Maven Wave Partners',
#   'location': 'Los Angeles | Chicago',
#   'email': 'brianhray@gmail.com',
#   'hireable': True,
#   'bio': 'Global Data Science Lead @brianray',
#   'public_repos': 59,
#   'followers': 110,
#   'following': 102,
#   'created_at': '2011-03-18T01:48:46Z'},
#  {'login': 'skirmer',
#   'name': 'Stephanie Kirmer',
#   'company': 'DataGrail',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Data scientist. Python. I talk a lot.',
#   'public_repos': 45,
#   'followers': 110,
#   'following': 8,
#   'created_at': '2015-03-23T20:22:21Z'},
#  {'login': 'barelyknown',
#   'name': 'Sean Devine',
#   'company': 'XBE LLC',
#   'location': 'Chicago, IL',
#   'email': 'sean-devine@x-b-e.com',
#   'hireable': '',
#   'bio': 'Founder and CEO of XBE LLC. Our construction logistics platform is built primarily with Ruby (Rails) and JavaScript (Ember).',
#   'public_repos': 100,
#   'followers': 109,
#   'following': 5,
#   'created_at': '2011-03-27T18:07:49Z'},
#  {'login': 'rsutphin',
#   'name': 'Rhett Sutphin',
#   'company': 'Human Practice, Inc.',
#   'location': 'Chicago, Illinois',
#   'email': 'rhett@detailedbalance.net',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 48,
#   'followers': 109,
#   'following': 47,
#   'created_at': '2008-03-07T15:24:26Z'},
#  {'login': 'agfor',
#   'name': 'Adam Forsyth',
#   'company': 'Braintree',
#   'location': 'Chicago, IL',
#   'email': 'adam@adamforsyth.net',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 35,
#   'followers': 109,
#   'following': 1,
#   'created_at': '2011-08-07T03:51:02Z'},
#  {'login': 'ksolo',
#   'name': 'Kevin Solorio',
#   'company': 'Provi',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 117,
#   'followers': 108,
#   'following': 73,
#   'created_at': '2009-07-11T05:17:10Z'},
#  {'login': 'snowgy',
#   'name': 'Yue Gong',
#   'company': '',
#   'location': 'Chicago, USA',
#   'email': 'yvetteyue1998@outlook.com',
#   'hireable': '',
#   'bio': 'PhD student @uchicago',
#   'public_repos': 30,
#   'followers': 108,
#   'following': 48,
#   'created_at': '2016-10-10T13:35:42Z'},
#  {'login': 'defaultxr',
#   'name': 'modula t.',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 78,
#   'followers': 108,
#   'following': 72,
#   'created_at': '2011-02-05T05:28:25Z'},
#  {'login': 'andymboyle',
#   'name': 'Andy Boyle',
#   'company': 'Engineering Leader @ Startups',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'I write code and words for fun and profit.',
#   'public_repos': 36,
#   'followers': 108,
#   'following': 7,
#   'created_at': '2010-12-04T01:17:13Z'},
#  {'login': 'jdoss',
#   'name': 'Joe Doss',
#   'company': 'https://www.smallstep.com/',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Fedora Linux user. Passionate about enabling others to improve their lives with FOSS. ',
#   'public_repos': 53,
#   'followers': 107,
#   'following': 86,
#   'created_at': '2008-04-22T18:11:24Z'},
#  {'login': 'SpezialK71',
#   'name': 'Kurt',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 21,
#   'followers': 107,
#   'following': 261,
#   'created_at': '2023-04-10T15:11:58Z'},
#  {'login': 'shonumi',
#   'name': 'D. S. Baxter',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'shonumi@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 10,
#   'followers': 107,
#   'following': 3,
#   'created_at': '2014-04-27T05:08:15Z'},
#  {'login': 'maggiewolff',
#   'name': 'Maggie Wolff',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Data Scientist Product Analytics',
#   'public_repos': 9,
#   'followers': 107,
#   'following': 29,
#   'created_at': '2018-06-07T21:41:28Z'},
#  {'login': 'stevepopovich',
#   'name': 'Steven Popovich',
#   'company': 'GitHub',
#   'location': 'Chicago, IL',
#   'email': 'stevepopovich8@gmail.com',
#   'hireable': '',
#   'bio': 'Hubber. Developer. Teammate. Bread Acquirer. ',
#   'public_repos': 26,
#   'followers': 107,
#   'following': 47,
#   'created_at': '2013-01-12T14:59:50Z'},
#  {'login': 'anthonyleezhang',
#   'name': 'Anthony Lee Zhang',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'anthonyzhang0@gmail.com',
#   'hireable': '',
#   'bio': 'I study markets',
#   'public_repos': 7,
#   'followers': 107,
#   'following': 6,
#   'created_at': '2014-08-20T13:42:50Z'},
#  {'login': 'daisyUniverse',
#   'name': 'Daisy Universe',
#   'company': 'Elgin Community College',
#   'location': 'Chicago, IL',
#   'email': 'mail@robinuniver.se',
#   'hireable': True,
#   'bio': '☆ Welcome to the department of fuck around and find out',
#   'public_repos': 58,
#   'followers': 107,
#   'following': 58,
#   'created_at': '2015-05-25T22:16:17Z'},
#  {'login': 'maxmiller413',
#   'name': 'Max Miller',
#   'company': 'Full-stack Software Engineering',
#   'location': 'Chicago, IL',
#   'email': 'maxmiller413@gmail.com',
#   'hireable': True,
#   'bio': 'Full-Stack Software Engineering',
#   'public_repos': 207,
#   'followers': 107,
#   'following': 547,
#   'created_at': '2020-11-21T17:15:31Z'},
#  {'login': 'glitchfur',
#   'name': 'Glitch',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 10,
#   'followers': 106,
#   'following': 85,
#   'created_at': '2015-09-06T08:57:40Z'},
#  {'login': 'meltingscales',
#   'name': 'meltingscales',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Grad of IIT, Chicagoan. Go buy @flexadecimal car parts.\r\nStrong self-taught/school prowess in Java, Python, SQL, Linux.',
#   'public_repos': 336,
#   'followers': 106,
#   'following': 301,
#   'created_at': '2013-01-10T15:39:20Z'},
#  {'login': 'wmurphyrd',
#   'name': 'Will Murphy',
#   'company': '@immers-space ',
#   'location': 'Chicago, IL',
#   'email': 'william@immers.space',
#   'hireable': '',
#   'bio': 'WebXR dev. Frame & Hubs contributor. A syndic of Immers Space, a co-op making free software for a federated metaverse. Available for freelance work.',
#   'public_repos': 63,
#   'followers': 106,
#   'following': 26,
#   'created_at': '2014-12-01T18:18:13Z'},
#  {'login': 'CodyNicholson',
#   'name': 'Cody Nicholson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'codynicholson96@gmail.com',
#   'hireable': True,
#   'bio': 'I am a Software Engineer and this is an encyclopedia of all my skills',
#   'public_repos': 158,
#   'followers': 106,
#   'following': 88,
#   'created_at': '2015-04-25T23:37:47Z'},
#  {'login': 'mgrover1',
#   'name': 'Max Grover',
#   'company': 'Argonne National Laboratory',
#   'location': 'Chicago, IL',
#   'email': 'mgroverwx@gmail.com',
#   'hireable': '',
#   'bio': 'Software Developer @ARM-DOE\r\n\r\nFormer @NCAR @Unidata',
#   'public_repos': 198,
#   'followers': 105,
#   'following': 74,
#   'created_at': '2017-03-24T20:10:53Z'},
#  {'login': 'KovasMcCann',
#   'name': 'Kovas McCann',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '31337 H4XØR',
#   'public_repos': 10,
#   'followers': 105,
#   'following': 9,
#   'created_at': '2018-10-18T23:03:38Z'},
#  {'login': 'csantiago132',
#   'name': 'Carlos Santiago',
#   'company': '@Kurocado-Studio ',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 23,
#   'followers': 104,
#   'following': 48,
#   'created_at': '2013-10-19T19:19:03Z'},
#  {'login': 'jaku',
#   'name': 'Matt Jakubowski',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'jaku@hax.by',
#   'hireable': '',
#   'bio': 'Neque dicas, quid neque.',
#   'public_repos': 49,
#   'followers': 104,
#   'following': '',
#   'created_at': '2009-07-06T16:21:59Z'},
#  {'login': 'AbrarSyed',
#   'name': 'Abrar Syed',
#   'company': '',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': 'Did lots of MineCraft mod development until around 2016',
#   'public_repos': 17,
#   'followers': 104,
#   'following': 3,
#   'created_at': '2010-12-15T01:32:02Z'},
#  {'login': 'juneau001',
#   'name': 'Josh Juneau',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 63,
#   'followers': 104,
#   'following': 12,
#   'created_at': '2009-08-30T01:37:46Z'},
#  {'login': 'alycit',
#   'name': 'Alyssa Diaz',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'alydiaz77@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 50,
#   'followers': 104,
#   'following': 25,
#   'created_at': '2010-10-14T21:09:28Z'},
#  {'login': 'mstratman',
#   'name': 'Mark A. Stratman',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'stratman@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 65,
#   'followers': 103,
#   'following': '',
#   'created_at': '2010-06-29T16:08:38Z'},
#  {'login': 'CaryLandholt',
#   'name': 'Cary Landholt',
#   'company': '@stridekick ',
#   'location': 'Chicago',
#   'email': 'cary@landholt.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 23,
#   'followers': 103,
#   'following': 7,
#   'created_at': '2011-06-07T00:26:37Z'},
#  {'login': 'knagaitsev',
#   'name': 'Kirill Nagaitsev',
#   'company': 'Northwestern University',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'PhD student at Northwestern. Previously worked on funcX @uchicago. GSoC 2019 @webpack graduate and past webpack-dev-server maintainer. Web game dev enthusiast',
#   'public_repos': 86,
#   'followers': 103,
#   'following': 9,
#   'created_at': '2016-10-02T21:37:35Z'},
#  {'login': 'omargfh',
#   'name': 'Omar Ibrahim',
#   'company': 'University of Chicago',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software developer, UI designer, and tech hobbyist currently studying computer science and economics at The University of Chicago',
#   'public_repos': 54,
#   'followers': 103,
#   'following': 73,
#   'created_at': '2019-06-06T20:50:19Z'},
#  {'login': 'RonaldColyar',
#   'name': 'Ronald Colyar',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': '',
#   'bio': "Passionate Engineer. It's art!!",
#   'public_repos': 51,
#   'followers': 103,
#   'following': 83,
#   'created_at': '2018-01-08T01:52:23Z'},
#  {'login': 'erichilarysmithsr',
#   'name': 'Eric Hilary Smith',
#   'company': 'Math 4 You By Us Group Illinois',
#   'location': 'Chicago',
#   'email': 'erichilarysmithsr@gmail.com',
#   'hireable': True,
#   'bio': 'Hello, everyone welcome to Github.',
#   'public_repos': 579,
#   'followers': 102,
#   'following': 757,
#   'created_at': '2013-09-24T15:40:42Z'},
#  {'login': 'luoyuanlab',
#   'name': 'Luo Lab at Northwestern University',
#   'company': 'Department of Preventive Medicine, Division of Health & Biomedical Informatics at Feinberg School of Medicine in Northwestern University',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Luo Lab at Northwestern University. Interests: machine learning, natural language processing, integrative genomics, computational phenotyping',
#   'public_repos': 21,
#   'followers': 102,
#   'following': '',
#   'created_at': '2011-07-01T15:09:05Z'},
#  {'login': 'jfnavarro21',
#   'name': 'John Navarro-DEN',
#   'company': 'McKinsey & Company',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'Data science consultant',
#   'public_repos': 26,
#   'followers': 102,
#   'following': 3,
#   'created_at': '2016-01-12T15:52:13Z'},
#  {'login': 'rlk',
#   'name': 'Robert Kooima',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 33,
#   'followers': 102,
#   'following': 10,
#   'created_at': '2009-05-26T14:10:05Z'},
#  {'login': '3CloudSolutions',
#   'name': '3Cloud',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Make the cloud work for you with our Azure consulting services. With a 100% focus on Azure, our experts deliver to you the ultimate Azure experience.',
#   'public_repos': 6,
#   'followers': 102,
#   'following': '',
#   'created_at': '2017-03-07T22:32:47Z'},
#  {'login': 'scottferg',
#   'name': 'Scott Ferguson',
#   'company': 'Numerator/InfoScout',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 66,
#   'followers': 101,
#   'following': 46,
#   'created_at': '2009-04-16T03:45:47Z'}]

# %% [markdown]
# ### clean company name

# %%
a = users

for user in a:
    company = user.get('company', '').strip().upper()
    if company.startswith('@'):
        company = company[1:]
    user['company'] = company

# %%
a
# Out:
# [{'login': 'cassidoo',
#   'name': 'Cassidy Williams',
#   'company': 'GITHUB',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Making memes and dreams... and software',
#   'public_repos': 165,
#   'followers': 13383,
#   'following': 102,
#   'created_at': '2012-02-20T16:36:23Z'},
#  {'login': 'felangel',
#   'name': 'Felix Angelov',
#   'company': 'SHOREBIRDTECH',
#   'location': 'Chicago',
#   'email': 'felangelov@gmail.com',
#   'hireable': '',
#   'bio': 'software engineer by day, software engineer by night.',
#   'public_repos': 125,
#   'followers': 8680,
#   'following': 67,
#   'created_at': '2014-09-22T02:35:58Z'},
#  {'login': 'dabeaz',
#   'name': 'David Beazley',
#   'company': 'DABEAZ, LLC',
#   'location': 'Chicago',
#   'email': 'dave@dabeaz.com',
#   'hireable': '',
#   'bio': "Author of the Python Essential Reference (Addison-Wesley), Python Cookbook (O'Reilly), and former computer science professor. Come take a class! ",
#   'public_repos': 34,
#   'followers': 5181,
#   'following': '',
#   'created_at': '2010-08-01T15:22:48Z'},
#  {'login': 'sstephenson',
#   'name': 'Sam Stephenson',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'sam@sls.name',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 24,
#   'followers': 3761,
#   'following': '',
#   'created_at': '2008-03-08T22:17:24Z'},
#  {'login': 'mattgodbolt',
#   'name': 'Matt Godbolt',
#   'company': 'AQUATIC CAPITAL MANAGEMENT',
#   'location': 'Chicago, IL',
#   'email': 'matt@godbolt.org',
#   'hireable': '',
#   'bio': 'Compiler Explorer and jsbeeb creator, ex-Google, ex-games, now trading chap.',
#   'public_repos': 84,
#   'followers': 3398,
#   'following': 97,
#   'created_at': '2011-02-23T13:46:48Z'},
#  {'login': 'logankilpatrick',
#   'name': 'Logan Kilpatrick ',
#   'company': 'GOOGLE',
#   'location': 'Chicago | SF Bay',
#   'email': '',
#   'hireable': '',
#   'bio': '@Google AI Studio & the Gemini API, President @NumFOCUS',
#   'public_repos': 229,
#   'followers': 2732,
#   'following': 259,
#   'created_at': '2018-01-18T19:36:30Z'},
#  {'login': 'khan4019',
#   'name': 'That JS Dude',
#   'company': 'NIELSEN',
#   'location': 'Chicago',
#   'email': 'khan4019@gmail.com',
#   'hireable': True,
#   'bio': 'A curious JavaScript developer, a frequent speaker and a tube light. On his enjoyable day he eats cauliflower and pulls his hair to solve programming problem.',
#   'public_repos': 104,
#   'followers': 2668,
#   'following': '',
#   'created_at': '2012-06-13T23:23:23Z'},
#  {'login': 'adashofdata',
#   'name': 'Alice Zhao',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "Data Scientist. Author of SQL Pocket Guide, 4th Edition (O'Reilly). Instructor at Northwestern University, O'Reilly and Maven Analytics / Udemy.",
#   'public_repos': 6,
#   'followers': 2452,
#   'following': '',
#   'created_at': '2017-07-20T16:27:23Z'},
#  {'login': 'djspiewak',
#   'name': 'Daniel Spiewak',
#   'company': 'NVIDIA',
#   'location': 'Chicago, IL',
#   'email': 'djspiewak@gmail.com',
#   'hireable': '',
#   'bio': "I write code, read papers, and think thoughts. Broadly, I'm interested in: type theory, parser theory, functional abstractions, data structures, performance.",
#   'public_repos': 143,
#   'followers': 2303,
#   'following': '',
#   'created_at': '2008-02-24T18:54:37Z'},
#  {'login': 'eddelbuettel',
#   'name': 'Dirk Eddelbuettel',
#   'company': '',
#   'location': 'Chicago, IL, USA',
#   'email': 'edd@debian.org',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 471,
#   'followers': 1848,
#   'following': 44,
#   'created_at': '2011-03-16T13:44:54Z'},
#  {'login': 'natemoo-re',
#   'name': 'Nate Moore',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Designer-turned-developer building open source tooling to empower fellow creatives',
#   'public_repos': 242,
#   'followers': 1742,
#   'following': 87,
#   'created_at': '2014-03-31T17:15:24Z'},
#  {'login': 'lexi-lambda',
#   'name': 'Alexis King',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 147,
#   'followers': 1680,
#   'following': 1,
#   'created_at': '2011-04-29T23:25:59Z'},
#  {'login': 'neodigm',
#   'name': 'Scott C. Krause',
#   'company': 'INDEPENDENT',
#   'location': 'Chicago ✈️ the Future',
#   'email': '',
#   'hireable': True,
#   'bio': 'I design high-fidelity prototypes then build interactive experiences. I craft self-documenting and future-proof JavaScript ⚡ Web Components ⚡ WASM',
#   'public_repos': 411,
#   'followers': 1448,
#   'following': 5927,
#   'created_at': '2012-12-30T05:22:47Z'},
#  {'login': 'rentzsch',
#   'name': 'Wolf Rentzsch',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 148,
#   'followers': 1212,
#   'following': 2,
#   'created_at': '2008-03-13T04:23:19Z'},
#  {'login': 'HFTrader',
#   'name': 'Henrique Bucher',
#   'company': 'VITORIAN LLC',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'Consulting and development C++/FPGA/GPU. Focus on Ultra Low Latency Trading. Crypto. Ex-Citadel, ex-JP Morgan. Brazilian, BSc/MSc/PhD in Engineering.',
#   'public_repos': 113,
#   'followers': 1209,
#   'following': 6,
#   'created_at': '2015-03-23T22:47:11Z'},
#  {'login': 'JimLiu',
#   'name': 'Jim Liu 宝玉',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'junminliu@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 205,
#   'followers': 1196,
#   'following': 134,
#   'created_at': '2011-03-03T09:18:48Z'},
#  {'login': 'jcs',
#   'name': 'joshua stein',
#   'company': 'PUSHOVERAPP',
#   'location': 'chicago, illinois',
#   'email': 'jcs@jcs.org',
#   'hireable': '',
#   'bio': 'Hello, cyberpals',
#   'public_repos': 98,
#   'followers': 1084,
#   'following': 16,
#   'created_at': '2008-05-10T17:03:32Z'},
#  {'login': 'jbranchaud',
#   'name': 'Josh Branchaud',
#   'company': 'INDEPENDENT, WORK WITH ME --> VISUALMODE.DEV',
#   'location': 'Chicago, IL',
#   'email': 'jbranchaud@gmail.com',
#   'hireable': True,
#   'bio': 'Independent Software Consultant and Developer at VisualMode. TS • React • Rails • Postgres',
#   'public_repos': 171,
#   'followers': 1080,
#   'following': 115,
#   'created_at': '2011-03-28T00:17:53Z'},
#  {'login': 'basecamp',
#   'name': 'Basecamp',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'support@basecamp.com',
#   'hireable': '',
#   'bio': "HEY! It's in Basecamp!",
#   'public_repos': 193,
#   'followers': 989,
#   'following': '',
#   'created_at': '2008-06-09T20:00:38Z'},
#  {'login': 'SciSharp',
#   'name': 'SciSharp STACK',
#   'company': '',
#   'location': 'Chicago, US',
#   'email': 'scisharpstack@gmail.com',
#   'hireable': '',
#   'bio': 'A .NET based Open Source Ecosystem for Data Science, Machine Learning and AI.',
#   'public_repos': 66,
#   'followers': 961,
#   'following': '',
#   'created_at': '2018-11-13T02:23:44Z'},
#  {'login': 'joshdholtz',
#   'name': 'Josh Holtz',
#   'company': 'REVENUECAT',
#   'location': 'Chicago, IL (Previously Milwaukee, WI)',
#   'email': 'me@joshholtz.com',
#   'hireable': '',
#   'bio': 'Lead maintainer of @fastlane 🚀 SDKs at RevenueCat 💵😻',
#   'public_repos': 214,
#   'followers': 928,
#   'following': 6,
#   'created_at': '2010-09-16T01:26:03Z'},
#  {'login': 'johnpolacek',
#   'name': 'John Polacek',
#   'company': 'HOWL',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Senior Software Engineer at VEG. Based in Chicago. johnpolacek.com',
#   'public_repos': 127,
#   'followers': 862,
#   'following': 1,
#   'created_at': '2010-01-10T14:41:10Z'},
#  {'login': 'davidteather',
#   'name': 'David Teather',
#   'company': 'CROWDSTRIKE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'I like open source projects and making educational content | SWE @CrowdStrike ',
#   'public_repos': 59,
#   'followers': 847,
#   'following': 107,
#   'created_at': '2017-11-30T22:36:19Z'},
#  {'login': 'jeremyckahn',
#   'name': 'Jeremy Kahn',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'me@jeremyckahn.com',
#   'hireable': '',
#   'bio': 'I fight for the users! 💪',
#   'public_repos': 155,
#   'followers': 837,
#   'following': 536,
#   'created_at': '2010-08-16T19:18:08Z'},
#  {'login': 'dchelimsky',
#   'name': 'David Chelimsky',
#   'company': 'RETIRED',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 107,
#   'followers': 813,
#   'following': 7,
#   'created_at': '2008-02-27T14:51:22Z'},
#  {'login': 'coreyhaines',
#   'name': 'Corey Haines',
#   'company': '',
#   'location': 'chicago, il',
#   'email': 'coreyhaines@gmail.com',
#   'hireable': True,
#   'bio': 'Magical!',
#   'public_repos': 155,
#   'followers': 812,
#   'following': 16,
#   'created_at': '2008-03-27T13:12:53Z'},
#  {'login': 'rharter',
#   'name': 'Ryan Harter',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 215,
#   'followers': 786,
#   'following': 4,
#   'created_at': '2011-12-31T18:08:39Z'},
#  {'login': 'harperreed',
#   'name': 'Harper Reed',
#   'company': 'HARPER RULES, LLC',
#   'location': 'Chicago, Il',
#   'email': 'harper@modest.com',
#   'hireable': '',
#   'bio': 'A normal person doing normal things.',
#   'public_repos': 182,
#   'followers': 783,
#   'following': 148,
#   'created_at': '2008-07-26T18:45:02Z'},
#  {'login': 'sksamuel',
#   'name': 'Sam',
#   'company': 'GRINDR',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Bit of this, bit of that.',
#   'public_repos': 22,
#   'followers': 782,
#   'following': 21,
#   'created_at': '2011-04-21T12:31:28Z'},
#  {'login': 'leeoniya',
#   'name': 'Leon Sorokin',
#   'company': 'GRAFANA',
#   'location': 'Chicago, IL',
#   'email': 'leeoniya@gmail.com',
#   'hireable': '',
#   'bio': '"All problems in computer science can be solved by another level of abstraction ...except for the problem of too many levels of abstraction."',
#   'public_repos': 175,
#   'followers': 776,
#   'following': 348,
#   'created_at': '2008-12-30T00:27:29Z'},
#  {'login': 'hwayne',
#   'name': 'Hillel Wayne',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 47,
#   'followers': 762,
#   'following': 21,
#   'created_at': '2012-10-26T21:51:04Z'},
#  {'login': 'CoralineAda',
#   'name': 'Coraline Ada Ehmke',
#   'company': 'ETHICALSOURCE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Internationally recognized tech ethicist, activist, & software engineer. Creator of Contributor Covenant & Hippocratic License. Ruby Hero. FOSS troublemaker.',
#   'public_repos': 136,
#   'followers': 756,
#   'following': 5,
#   'created_at': '2008-08-28T02:37:32Z'},
#  {'login': 'sean-codes',
#   'name': 'Sean Codes',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'sean_codes@outlook.com',
#   'hireable': '',
#   'bio': 'Hi! Web Apps and 2D Games :]',
#   'public_repos': 36,
#   'followers': 708,
#   'following': 25,
#   'created_at': '2016-09-01T13:41:42Z'},
#  {'login': 'gjreda',
#   'name': 'Greg Reda',
#   'company': 'INSTACART',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 42,
#   'followers': 684,
#   'following': 118,
#   'created_at': '2011-07-18T03:57:34Z'},
#  {'login': 'jameslamb',
#   'name': 'James Lamb',
#   'company': 'NVIDIA',
#   'location': 'Chicago, IL',
#   'email': 'jaylamb20@gmail.com',
#   'hireable': '',
#   'bio': '(he/him) RAPIDS packaging at NVIDIA. LightGBM maintainer. Economist at heart. ',
#   'public_repos': 88,
#   'followers': 669,
#   'following': 255,
#   'created_at': '2014-05-17T05:32:21Z'},
#  {'login': 'djsime1',
#   'name': 'David',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "Fluent in Lua, Java, and Python; certified nerd.\r\nI put too much effort into README's and frequently overdose on colorful yet useless badges.",
#   'public_repos': 41,
#   'followers': 666,
#   'following': 13,
#   'created_at': '2014-08-21T22:15:54Z'},
#  {'login': 'dabeaz-course',
#   'name': 'Dabeaz LLC',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'dabeaz@dabeaz.com',
#   'hireable': '',
#   'bio': 'Courses by David Beazley',
#   'public_repos': 2,
#   'followers': 638,
#   'following': '',
#   'created_at': '2020-05-13T16:47:19Z'},
#  {'login': 'lorenanicole',
#   'name': 'Lorena Mesa',
#   'company': 'GITHUB',
#   'location': 'Chicago, Illinois',
#   'email': 'me@lorenamesa.com',
#   'hireable': '',
#   'bio': 'Political analyst turned coder, Lorena Mesa is a #Latinx data engineer, ex-@github, Former Chair of the @python Software Foundation, @PyLadiesChicago organizer.',
#   'public_repos': 256,
#   'followers': 618,
#   'following': 11,
#   'created_at': '2013-05-30T19:15:17Z'},
#  {'login': 'LadyKerr',
#   'name': 'Kedasha Kerr',
#   'company': 'DEVELOPER ADVOCATE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Developer Advocate @github and Technical Content Creator 🎥 Catch my next video on IG @itsthatladydev ✨',
#   'public_repos': 181,
#   'followers': 616,
#   'following': 69,
#   'created_at': '2019-01-30T17:25:04Z'},
#  {'login': 'dannguyen',
#   'name': 'Dan Nguyen',
#   'company': 'FREELANCER, DATA WRANGLER/ENGINEER',
#   'location': 'Chicago',
#   'email': 'dansonguyen@gmail.com',
#   'hireable': True,
#   'bio': 'My name is Dan Nguyen and you can find me on Github as dannguyen & @dancow on Twitter. My interests are investigative journalism, data wrangling, and naming thi',
#   'public_repos': 374,
#   'followers': 612,
#   'following': 329,
#   'created_at': '2009-08-31T15:34:59Z'},
#  {'login': 'awatson1978',
#   'name': 'Abigail Watson',
#   'company': 'SYMPTOMATIC, LLC',
#   'location': 'Chicago - Evansville',
#   'email': 'awatson1978@gmail.com',
#   'hireable': '',
#   'bio': 'Bioinformaticist.  Venture Altruist.  Biohacker.   Burner.  Xinnial.  Healthcare worker.  \r\n',
#   'public_repos': 219,
#   'followers': 590,
#   'following': 7,
#   'created_at': '2011-03-17T20:50:48Z'},
#  {'login': 'trek',
#   'name': 'Trek Glowacki',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'I helped start @workantile, couponed at @groupon, usually helping some startup get acquired. @emberjs core team emeritus. @paulirish once called me a hero',
#   'public_repos': 26,
#   'followers': 581,
#   'following': '',
#   'created_at': '2008-05-08T22:08:55Z'},
#  {'login': 'Valve',
#   'name': '',
#   'company': 'FINGERPRINT.COM',
#   'location': 'Chicago, USA',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm a Ruby on Rails developer but also like golang. Love cycling and reading.",
#   'public_repos': 61,
#   'followers': 575,
#   'following': 30,
#   'created_at': '2008-10-03T08:52:38Z'},
#  {'login': 'catarak',
#   'name': 'Cassie Tarakajian',
#   'company': 'PREV @CYCLING74, @PROCESSING',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'all technology is political',
#   'public_repos': 72,
#   'followers': 562,
#   'following': 14,
#   'created_at': '2013-11-29T03:02:52Z'},
#  {'login': 'scopatz',
#   'name': 'Anthony Scopatz',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'scopatz@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 396,
#   'followers': 550,
#   'following': 269,
#   'created_at': '2010-07-01T22:20:46Z'},
#  {'login': 'ZeweiChu',
#   'name': 'Zewei Chu',
#   'company': 'GOOGLE',
#   'location': 'Chicago',
#   'email': 'zeweichu@gmail.com',
#   'hireable': True,
#   'bio': 'Metaverse, Blockchain, AI, NLP',
#   'public_repos': 68,
#   'followers': 550,
#   'following': 287,
#   'created_at': '2012-07-23T12:43:49Z'},
#  {'login': 'peterpme',
#   'name': 'Peter Piekarczyk',
#   'company': 'CORAL-XYZ',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Building Backpack 🎒 ',
#   'public_repos': 217,
#   'followers': 545,
#   'following': 253,
#   'created_at': '2011-11-22T02:54:04Z'},
#  {'login': 'bitsondatadev',
#   'name': 'Brian "bits" Olsen',
#   'company': 'TRINODB @APACHE',
#   'location': 'Chicago, United States',
#   'email': 'bits@bitsondata.dev',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 46,
#   'followers': 542,
#   'following': 11909,
#   'created_at': '2014-08-25T16:49:19Z'},
#  {'login': 'estrattonbailey',
#   'name': 'Eric Bailey',
#   'company': 'BLUESKY-SOCIAL',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Internet person',
#   'public_repos': 179,
#   'followers': 518,
#   'following': 452,
#   'created_at': '2013-06-18T21:05:38Z'},
#  {'login': 'phinze',
#   'name': 'Paul Hinze',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 155,
#   'followers': 517,
#   'following': 35,
#   'created_at': '2008-12-01T14:28:06Z'},
#  {'login': 'lvh',
#   'name': 'lvh',
#   'company': 'LATACORA',
#   'location': 'Chicago, IL',
#   'email': '_@lvh.io',
#   'hireable': '',
#   'bio': 'Principal, Latacora. We build security teams.',
#   'public_repos': 188,
#   'followers': 515,
#   'following': '',
#   'created_at': '2009-06-22T14:36:57Z'},
#  {'login': 'jorgecoca',
#   'name': 'Jorge Coca',
#   'company': 'VGVENTURES',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Head of Engineering - @VGVentures. \r\nGoogle Developer Experter - Flutter\r\nEx core mobile @bmw-tech. \r\nOrganizer of @ChicagoFlutter. ',
#   'public_repos': 9,
#   'followers': 512,
#   'following': 225,
#   'created_at': '2013-01-10T18:05:45Z'},
#  {'login': 'bgardner',
#   'name': 'Brian Gardner',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'brian.gardner@wpengine.com',
#   'hireable': '',
#   'bio': 'Designer. #WordPress expert.',
#   'public_repos': 2,
#   'followers': 494,
#   'following': 262,
#   'created_at': '2010-11-17T23:06:34Z'},
#  {'login': 'adriangb',
#   'name': 'Adrian Garcia Badaracco',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 177,
#   'followers': 493,
#   'following': 330,
#   'created_at': '2012-05-19T15:47:00Z'},
#  {'login': 'Templarian',
#   'name': 'Austin Andrews',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Maintainer of Material Design Icons',
#   'public_repos': 69,
#   'followers': 492,
#   'following': 8,
#   'created_at': '2010-07-20T18:37:13Z'},
#  {'login': 'jamesturk',
#   'name': 'James Turk',
#   'company': 'UNIVERSITY OF CHICAGO',
#   'location': 'Chicago, IL',
#   'email': 'dev@jpt.sh',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 31,
#   'followers': 482,
#   'following': 83,
#   'created_at': '2008-04-21T04:48:06Z'},
#  {'login': 'an0',
#   'name': 'Ling Wang',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 27,
#   'followers': 481,
#   'following': 3,
#   'created_at': '2009-07-02T09:33:10Z'},
#  {'login': 'kierisi',
#   'name': 'Jesse Mostipak',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 18,
#   'followers': 469,
#   'following': 56,
#   'created_at': '2016-10-26T19:58:51Z'},
#  {'login': 'derekeder',
#   'name': 'Derek Eder',
#   'company': 'DATAMADE, CHI HACK NIGHT',
#   'location': 'Chicago, IL',
#   'email': 'derek@derekeder.com',
#   'hireable': '',
#   'bio': 'Partner at @datamade. Organizer of @chihacknight. I use data, build tools, and organize people in Chicago to democratize power.',
#   'public_repos': 45,
#   'followers': 467,
#   'following': 137,
#   'created_at': '2011-07-16T14:15:04Z'},
#  {'login': 'rachelbaker',
#   'name': 'Rachel Baker',
#   'company': 'STITCH FIX',
#   'location': 'Chicago, IL',
#   'email': 'rachel@rachelbaker.me',
#   'hireable': '',
#   'bio': 'Director of Engineering @stitchfix. Prev. Head of Engineering + Data Wirecutter (part of @nytimes). @WordPress Core Committer. \r\nShe/her',
#   'public_repos': 29,
#   'followers': 462,
#   'following': 230,
#   'created_at': '2011-08-14T21:30:31Z'},
#  {'login': 'iSoron',
#   'name': 'Alinson S. Xavier',
#   'company': 'ARGONNE NATIONAL LABORATORY',
#   'location': 'Chicago, IL',
#   'email': 'git@axavier.org',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 14,
#   'followers': 462,
#   'following': '',
#   'created_at': '2013-06-14T16:39:48Z'},
#  {'login': 'kpdecker',
#   'name': 'Kevin Decker',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kpdecker@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 130,
#   'followers': 460,
#   'following': 38,
#   'created_at': '2010-02-04T06:54:41Z'},
#  {'login': 'themeteorchef',
#   'name': 'The Meteor Chef',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'business@themeteorchef.com',
#   'hireable': True,
#   'bio': 'Sandwiches, Meteor, magic.',
#   'public_repos': 98,
#   'followers': 460,
#   'following': 33,
#   'created_at': '2014-07-16T18:16:31Z'},
#  {'login': 'gk5885',
#   'name': 'Gregory Kick',
#   'company': 'GOOGLE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 7,
#   'followers': 449,
#   'following': 2,
#   'created_at': '2012-09-04T17:55:09Z'},
#  {'login': 'austinsonger',
#   'name': 'Austin Songer,MIS,CEH,ESCA,Project+ (Navy Veteran)',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': 'a.songer@protonmail.com',
#   'hireable': True,
#   'bio': 'Governance, Risk, and Compliance Lead\r\n\r\n',
#   'public_repos': 840,
#   'followers': 448,
#   'following': 1409,
#   'created_at': '2017-03-24T14:43:10Z'},
#  {'login': 'bwya77',
#   'name': 'Bradley Wyatt',
#   'company': 'NTIVA',
#   'location': 'Chicago',
#   'email': 'brad@thelazyadministrator.com',
#   'hireable': True,
#   'bio': 'Microsoft MVP | The Lazy Administrator | DevOps Automation Engineer at Ntiva',
#   'public_repos': 34,
#   'followers': 444,
#   'following': 28,
#   'created_at': '2014-01-02T03:41:12Z'},
#  {'login': 'ELLIOTTCABLE',
#   'name': '',
#   'company': 'AHREFS',
#   'location': 'Chicago, IL',
#   'email': 'github-public@from.ec',
#   'hireable': True,
#   'bio': '{PL,Q}T. Accidental creator of @Paws.',
#   'public_repos': 243,
#   'followers': 442,
#   'following': 826,
#   'created_at': '2008-02-13T03:27:01Z'},
#  {'login': 'tqbf',
#   'name': 'Thomas <b>H. Ptacek"',
#   'company': 'KETCHUP SALT',
#   'location': 'Chicago, IL',
#   'email': 'thomas@sockpuppet.org',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 30,
#   'followers': 439,
#   'following': 1,
#   'created_at': '2008-06-11T23:59:12Z'},
#  {'login': 'vehbiu',
#   'name': 'Vehbi',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 10,
#   'followers': 435,
#   'following': '',
#   'created_at': '2023-02-22T15:56:12Z'},
#  {'login': 'mjskay',
#   'name': 'Matthew Kay',
#   'company': 'NORTHWESTERN UNIVERSITY',
#   'location': 'Chicago',
#   'email': 'mjskay@northwestern.edu',
#   'hireable': '',
#   'bio': 'Associate Professor at Northwestern; works on human-computer interaction, information visualization, communicating uncertainty',
#   'public_repos': 59,
#   'followers': 434,
#   'following': 1,
#   'created_at': '2014-01-08T01:48:16Z'},
#  {'login': 'mapmeld',
#   'name': 'Nick Doiron',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ndoiron@mapmeld.com',
#   'hireable': True,
#   'bio': 'Full-stack engineer and open source in ML / NLP',
#   'public_repos': 274,
#   'followers': 428,
#   'following': 11,
#   'created_at': '2011-03-01T03:09:47Z'},
#  {'login': 'carolynvs',
#   'name': 'Carolyn Van Slyck',
#   'company': 'AZURE',
#   'location': 'Chicago, IL',
#   'email': 'me@carolynvanslyck.com',
#   'hireable': '',
#   'bio': 'Professional Yak Shaver',
#   'public_repos': 273,
#   'followers': 412,
#   'following': 2,
#   'created_at': '2012-01-22T21:34:25Z'},
#  {'login': 'DashBarkHuss',
#   'name': 'Dashiell Bark-Huss',
#   'company': 'WISHTENDER',
#   'location': 'Chicago',
#   'email': 'dangerousdashie@gmail.com',
#   'hireable': '',
#   'bio': 'Self taught programmer. Building WishTender. Lucid dream enthusiast.',
#   'public_repos': 76,
#   'followers': 408,
#   'following': 12,
#   'created_at': '2015-06-19T16:10:41Z'},
#  {'login': 'zigurous',
#   'name': 'Zigurous',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'support@zigurous.com',
#   'hireable': '',
#   'bio': 'Zigurous is an indie game developer.',
#   'public_repos': 36,
#   'followers': 405,
#   'following': '',
#   'created_at': '2016-01-17T01:13:04Z'},
#  {'login': 'brandonleegit',
#   'name': 'Brandon Lee',
#   'company': 'VIRTUALIZATIONHOWTO',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Prolific Virtualization blogger and IT Technologist specializing in virtualization and cloud',
#   'public_repos': 16,
#   'followers': 400,
#   'following': '',
#   'created_at': '2016-09-12T16:55:01Z'},
#  {'login': 'rsese',
#   'name': 'Robert Sese',
#   'company': 'GITHUB',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': ':horse: :pizza:',
#   'public_repos': 44,
#   'followers': 395,
#   'following': 144,
#   'created_at': '2011-04-17T01:44:30Z'},
#  {'login': 'boonebgorges',
#   'name': 'Boone Gorges',
#   'company': 'HTTPS://HARDG.COM',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Emeritus committer for @WordPress; Emeritus lead for @buddypress; WordPress consultant',
#   'public_repos': 131,
#   'followers': 393,
#   'following': 30,
#   'created_at': '2010-04-18T13:36:23Z'},
#  {'login': 'jarry-xiao',
#   'name': 'Jarry Xiao',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'blockchain x quant finance',
#   'public_repos': 23,
#   'followers': 387,
#   'following': 10,
#   'created_at': '2020-02-15T18:05:16Z'},
#  {'login': 'the-raspberry-pi-guy',
#   'name': 'Matt Timmons-Brown (Raspberry Pi Guy)',
#   'company': 'JUMP TRADING',
#   'location': 'Chicago',
#   'email': 'theraspberrypiguy@gmail.com',
#   'hireable': True,
#   'bio': 'SWE @ Jump Trading | CS Masters @ UPenn | Thouron Scholar | Ex-Amazon | Ex-CompSci @ Edinburgh | Author of "Learn Robotics w. Raspberry Pi", link ↓↓↓',
#   'public_repos': 31,
#   'followers': 384,
#   'following': 95,
#   'created_at': '2013-09-29T15:30:39Z'},
#  {'login': 'saforem2',
#   'name': 'Sam Foreman',
#   'company': 'ARGONNE-LCF',
#   'location': 'Chicago, IL',
#   'email': 'saforem2@gmail.com',
#   'hireable': True,
#   'bio': 'AI 4 Science @argonne-lcf \r\nhttps://samforeman.me\r\n',
#   'public_repos': 188,
#   'followers': 377,
#   'following': 685,
#   'created_at': '2013-08-15T02:33:02Z'},
#  {'login': 'ZWMiller',
#   'name': 'Zach Miller',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Machine Learning Engineer. Nuclear Physics Ph.D. fluent with Python, SQL, and C++.',
#   'public_repos': 43,
#   'followers': 376,
#   'following': 5,
#   'created_at': '2015-07-24T18:13:27Z'},
#  {'login': 'matagus',
#   'name': 'Matías Agustín Méndez',
#   'company': '',
#   'location': 'Chicago, IL ',
#   'email': '',
#   'hireable': True,
#   'bio': 'I miss the old Github feed / activity stream. @matorral-project | @django-planet #django #python #rust',
#   'public_repos': 48,
#   'followers': 371,
#   'following': 3468,
#   'created_at': '2009-02-27T10:45:55Z'},
#  {'login': 'skwp',
#   'name': 'Yan Pritzker',
#   'company': 'SWANBITCOIN.COM',
#   'location': 'Chicago',
#   'email': 'yan@pritzker.ws',
#   'hireable': '',
#   'bio': 'Co-founder swan.com @swan-bitcoin, author inventingbitcoin.com, Former CTO @reverbdotcom. Contact at https://twitter.com/skwp',
#   'public_repos': 60,
#   'followers': 362,
#   'following': 53,
#   'created_at': '2008-02-29T17:02:06Z'},
#  {'login': 'stevespringett',
#   'name': 'Steve Springett',
#   'company': 'SERVICENOW',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'I build stuff, I break stuff, I develop stuff to protect stuff.\r\n\r\nCreator of @DependencyTrack. Chair of @CycloneDX and @Ecma-TC54. Core team of @package-url',
#   'public_repos': 30,
#   'followers': 361,
#   'following': 2,
#   'created_at': '2013-03-15T22:01:22Z'},
#  {'login': 'braverock',
#   'name': 'Brian G. Peterson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'brian@braverock.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 12,
#   'followers': 360,
#   'following': 6,
#   'created_at': '2012-04-22T17:32:42Z'},
#  {'login': 'jenmyers',
#   'name': 'Jen Myers',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm a swell gal.",
#   'public_repos': 18,
#   'followers': 360,
#   'following': '',
#   'created_at': '2011-03-10T16:05:12Z'},
#  {'login': 'gar1t',
#   'name': 'Garrett Smith',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 213,
#   'followers': 360,
#   'following': 4,
#   'created_at': '2010-01-18T21:49:39Z'},
#  {'login': 'MarkTechson',
#   'name': 'Mark Thompson',
#   'company': 'ANGULAR',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'A developer who loves coding, teaching and pancakes.',
#   'public_repos': 97,
#   'followers': 360,
#   'following': 1,
#   'created_at': '2012-10-14T01:17:42Z'},
#  {'login': 'Tedko',
#   'name': 'Suji Yan',
#   'company': 'DIMENSIONDEV',
#   'location': 'Tokyo/SF/Chicago/NYC/Shanghai',
#   'email': 'suji.yan@dimension.im',
#   'hireable': '',
#   'bio': 'Founder/CEO of Dimension.im/Mask Network\r\n',
#   'public_repos': 56,
#   'followers': 357,
#   'following': 84,
#   'created_at': '2014-02-15T03:06:40Z'},
#  {'login': 'sabre1041',
#   'name': 'Andrew Block',
#   'company': 'RED HAT',
#   'location': 'Chicago',
#   'email': 'andy.block@gmail.com',
#   'hireable': '',
#   'bio': 'Distinguished Architect at Red Hat',
#   'public_repos': 463,
#   'followers': 352,
#   'following': 24,
#   'created_at': '2011-11-13T04:27:23Z'},
#  {'login': 'loganmartintran',
#   'name': 'Logan Tran',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 14,
#   'followers': 350,
#   'following': 14,
#   'created_at': '2016-08-17T00:08:46Z'},
#  {'login': 'abedra',
#   'name': 'Aaron Bedra',
#   'company': 'DRW',
#   'location': 'Chicago, IL',
#   'email': 'aaron@aaronbedra.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 77,
#   'followers': 349,
#   'following': 2,
#   'created_at': '2008-03-03T23:46:03Z'},
#  {'login': 'trevorturk',
#   'name': 'Trevor Turk',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'trevorturk@gmail.com',
#   'hireable': True,
#   'bio': 'Programming Hello Weather. Previously Impactive, IFTTT, Clearbit, and Basecamp.',
#   'public_repos': 79,
#   'followers': 345,
#   'following': 189,
#   'created_at': '2008-02-19T03:23:56Z'},
#  {'login': 'justinbmeyer',
#   'name': 'Justin Meyer',
#   'company': 'BITOVI',
#   'location': 'Chicago',
#   'email': 'justinbmeyer@gmail.com',
#   'hireable': '',
#   'bio': 'Co-founder @bitovi.  Contributor to @donejs, @canjs, @stealjs and others.',
#   'public_repos': 26,
#   'followers': 342,
#   'following': 29,
#   'created_at': '2009-04-28T03:33:52Z'},
#  {'login': 'RandomFractals',
#   'name': 'Taras Novak',
#   'company': 'RANDOM FRACTALS, INC.',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': True,
#   'bio': 'We map 🗺️ & graph 📈 data  🈸',
#   'public_repos': 110,
#   'followers': 341,
#   'following': '',
#   'created_at': '2011-03-08T02:39:42Z'},
#  {'login': 'srobbin',
#   'name': 'Scott Robbin',
#   'company': 'ROBBIN & CO.',
#   'location': 'Chicago',
#   'email': 'scott@robbin.co',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 46,
#   'followers': 339,
#   'following': 22,
#   'created_at': '2009-01-07T01:44:50Z'},
#  {'login': 'coolbeet',
#   'name': 'Suyu Zhang',
#   'company': 'CHOWBUS',
#   'location': 'Chicago',
#   'email': 'suyu_zhang@hotmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 8,
#   'followers': 338,
#   'following': 2,
#   'created_at': '2012-07-30T02:43:33Z'},
#  {'login': 'timrwood',
#   'name': 'Tim Wood',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 42,
#   'followers': 337,
#   'following': 13,
#   'created_at': '2011-03-01T02:45:07Z'},
#  {'login': 'shayhowe',
#   'name': 'Shay Howe',
#   'company': 'LEADHONESTLY',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'CMO at @ActiveCampaign, Co-founder at @leadhonestly, Partner at @ProtaVentures, Co-Founder of @ChicagoCamps, Product Designer, Engineer',
#   'public_repos': 14,
#   'followers': 334,
#   'following': 1,
#   'created_at': '2010-12-07T17:10:24Z'},
#  {'login': 'ksobon',
#   'name': 'Konrad Sobon',
#   'company': 'ARCHI-LAB',
#   'location': 'Chicago',
#   'email': 'sobon.konrad@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 49,
#   'followers': 332,
#   'following': 5,
#   'created_at': '2010-12-19T20:57:22Z'},
#  {'login': 'hugs',
#   'name': 'Jason Huggins',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': 'jrhuggins@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 74,
#   'followers': 327,
#   'following': 1,
#   'created_at': '2008-04-26T04:40:50Z'},
#  {'login': 'karllhughes',
#   'name': 'Karl L. Hughes',
#   'company': 'DRAFTDEV',
#   'location': 'Chicago, IL',
#   'email': 'khughes.me@gmail.com',
#   'hireable': '',
#   'bio': 'Former startup CTO turned writer. Creating technical marketing content as the founder of Draft.dev.',
#   'public_repos': 72,
#   'followers': 326,
#   'following': 35,
#   'created_at': '2011-10-05T02:11:06Z'},
#  {'login': 'Oceania2018',
#   'name': 'Haiping',
#   'company': '',
#   'location': 'Chicago, US',
#   'email': 'haiping008@gmail.com',
#   'hireable': True,
#   'bio': 'Bug fixing...',
#   'public_repos': 60,
#   'followers': 326,
#   'following': 118,
#   'created_at': '2012-05-04T09:54:33Z'},
#  {'login': 'emilyriederer',
#   'name': 'Emily Riederer',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'emilyriederer@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 26,
#   'followers': 321,
#   'following': 19,
#   'created_at': '2016-06-07T11:48:36Z'},
#  {'login': 'reiddraper',
#   'name': 'Reid Draper',
#   'company': 'FIGMA',
#   'location': 'Chicago, IL',
#   'email': 'reiddraper@gmail.com',
#   'hireable': '',
#   'bio': 'mayonnaise connoisseur',
#   'public_repos': 86,
#   'followers': 315,
#   'following': 62,
#   'created_at': '2010-02-09T16:04:56Z'},
#  {'login': 'sorentwo',
#   'name': 'Parker Selbert',
#   'company': 'SOREN',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 55,
#   'followers': 314,
#   'following': 3,
#   'created_at': '2010-05-07T22:41:11Z'},
#  {'login': 'nickvourd',
#   'name': 'Nikos Vourdas',
#   'company': 'EY US',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Just your friendly neighborhood red Power Ranger:~# OSWE | OSEP | OSCP | OSWP | CRTL | CRTO | OASP',
#   'public_repos': 16,
#   'followers': 312,
#   'following': 153,
#   'created_at': '2017-10-17T10:45:01Z'},
#  {'login': 'jjhelmus',
#   'name': 'Jonathan J. Helmus',
#   'company': 'ANACONDA',
#   'location': 'Chicago, IL',
#   'email': 'jjhelmus@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 424,
#   'followers': 310,
#   'following': 22,
#   'created_at': '2011-09-14T13:32:35Z'},
#  {'login': 'ahinchman1',
#   'name': 'Amanda Hinchman-Dominguez',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'Kotlin GDE and Android engineer. Co-organizer for CKUG.\r\n\r\nCo-author of "Programming Android with Kotlin: Achieving Structured Concurrency with Coroutines"',
#   'public_repos': 56,
#   'followers': 306,
#   'following': 26,
#   'created_at': '2014-03-11T10:10:24Z'},
#  {'login': 'XavierXiao',
#   'name': 'Xavier',
#   'company': 'UNIVERSITY OF CHICAGO',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 16,
#   'followers': 303,
#   'following': 1,
#   'created_at': '2015-09-15T23:43:17Z'},
#  {'login': 'coddingtonbear',
#   'name': 'Adam Coddington',
#   'company': 'AIRSHIP',
#   'location': 'Chicago, Illinois, USA',
#   'email': 'me@adamcoddington.net',
#   'hireable': '',
#   'bio': 'Not affiliated with non-🏳️\u200d🌈 types of bears.',
#   'public_repos': 218,
#   'followers': 301,
#   'following': 199,
#   'created_at': '2010-12-17T19:09:29Z'},
#  {'login': 'stevenwanderski',
#   'name': 'Steven Wanderski',
#   'company': 'CONTRACTOR',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 79,
#   'followers': 300,
#   'following': 2,
#   'created_at': '2010-11-09T00:32:00Z'},
#  {'login': 'JoeGermuska',
#   'name': 'Joe Germuska',
#   'company': 'NORTHWESTERN UNIVERSITY KNIGHT LAB',
#   'location': 'Chicago, IL',
#   'email': 'joe@germuska.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 101,
#   'followers': 298,
#   'following': 19,
#   'created_at': '2009-01-13T18:28:43Z'},
#  {'login': 'tswast',
#   'name': 'Tim Sweña (Swast)',
#   'company': 'GOOGLE',
#   'location': 'Chicago, IL',
#   'email': 'swast@google.com',
#   'hireable': '',
#   'bio': 'Data Engineer in Professional Services @GoogleCloudPlatform. I also hack on personal projects, mostly related to math & pixels.',
#   'public_repos': 154,
#   'followers': 295,
#   'following': 75,
#   'created_at': '2010-04-19T18:53:47Z'},
#  {'login': 'MelSumner',
#   'name': 'Melanie Sumner',
#   'company': 'HASHICORP',
#   'location': 'Chicago, IL',
#   'email': 'melaniersumner@gmail.com',
#   'hireable': '',
#   'bio': 'Likes: continuous accessibility, building for the web, strategic planning, empowering others to succeed.',
#   'public_repos': 310,
#   'followers': 293,
#   'following': 168,
#   'created_at': '2013-06-01T13:42:33Z'},
#  {'login': 'greensock',
#   'name': 'GreenSock',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 4,
#   'followers': 289,
#   'following': '',
#   'created_at': '2012-09-20T14:57:30Z'},
#  {'login': 'ExplorerFreda',
#   'name': 'Freda Shi',
#   'company': 'TOYOTA TECHNOLOGICAL INSTITUTE AT CHICAGO; UNIVERSITY OF WATERLOO',
#   'location': 'Chicago, IL',
#   'email': 'freda@ttic.edu',
#   'hireable': '',
#   'bio': 'Assistant Professor at the University of Waterloo with @compling-wat & @waterloo-nlp.',
#   'public_repos': 31,
#   'followers': 288,
#   'following': 37,
#   'created_at': '2016-01-17T13:44:19Z'},
#  {'login': 'alysivji',
#   'name': 'Aly Sivji',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Python. HealthIT. Data.',
#   'public_repos': 134,
#   'followers': 287,
#   'following': 163,
#   'created_at': '2013-05-07T21:04:31Z'},
#  {'login': 'paulromano',
#   'name': 'Paul Romano',
#   'company': 'ARGONNE NATIONAL LABORATORY',
#   'location': 'Chicago, IL',
#   'email': 'promano@anl.gov',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 89,
#   'followers': 287,
#   'following': 113,
#   'created_at': '2011-04-21T05:43:12Z'},
#  {'login': 'tedivm',
#   'name': 'Robert Hafner',
#   'company': 'COMCAST',
#   'location': 'Chicago, IL',
#   'email': 'tedivm@tedivm.com',
#   'hireable': '',
#   'bio': 'Lots of personal projects as well as @gitconsensus, @tedious, @LeagueOfAutomatedNations, and @screepers.',
#   'public_repos': 176,
#   'followers': 284,
#   'following': 162,
#   'created_at': '2009-09-01T00:56:22Z'},
#  {'login': 'rguthrie3',
#   'name': 'Robert',
#   'company': 'CITADEL LLC',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software engineer at Citadel LLC and Georgia Tech grad.  Primarily interested in natural language processing, finance, and high-performance computing.',
#   'public_repos': 12,
#   'followers': 281,
#   'following': 8,
#   'created_at': '2014-03-05T14:11:26Z'},
#  {'login': 'FreedomWriter',
#   'name': 'Natalie Davis',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': "Frontend Engineer, share your screen (or I'll share mine), let's figure it out!",
#   'public_repos': 143,
#   'followers': 280,
#   'following': 54,
#   'created_at': '2019-05-08T03:30:46Z'},
#  {'login': 'nbriz',
#   'name': 'Nick Briz',
#   'company': 'HTTPS://NETIZEN.ORG',
#   'location': 'Chicago, IL',
#   'email': 'nickbriz@protonmail.com',
#   'hireable': '',
#   'bio': 'new-media artist/educator/organizer >> focused on digital culture + digital literacy',
#   'public_repos': 65,
#   'followers': 279,
#   'following': 42,
#   'created_at': '2012-10-07T18:39:07Z'},
#  {'login': 'CodePlatoon',
#   'name': 'Code Platoon',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Turning veterans and military spouses into software developers.',
#   'public_repos': 14,
#   'followers': 278,
#   'following': '',
#   'created_at': '2015-10-30T18:39:53Z'},
#  {'login': 'mrkurt',
#   'name': 'Kurt Mackey',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'mrkurt@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 89,
#   'followers': 278,
#   'following': 17,
#   'created_at': '2008-04-17T18:10:49Z'},
#  {'login': 'kadamwhite',
#   'name': 'K Adam White',
#   'company': 'HUMANMADE',
#   'location': 'NYC, Raleigh, Chicago, Osaka',
#   'email': '',
#   'hireable': '',
#   'bio': 'Principal Engineer at Human Made, WordPress committer and former REST API maintainer, artist, DJ, and artist technician / spouse of Emily Garfield',
#   'public_repos': 101,
#   'followers': 273,
#   'following': 23,
#   'created_at': '2010-10-16T18:38:43Z'},
#  {'login': 'conorpp',
#   'name': 'Conor Patrick',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 124,
#   'followers': 273,
#   'following': 64,
#   'created_at': '2013-03-22T14:50:11Z'},
#  {'login': 'Daniel-McCarthy',
#   'name': 'Dan McCarthy',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 42,
#   'followers': 272,
#   'following': 129,
#   'created_at': '2013-07-07T05:17:39Z'},
#  {'login': 'msfrisbie',
#   'name': ' Matt Frisbie',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'classvsoftware@gmail.com',
#   'hireable': True,
#   'bio': 'Software engineer, bestselling author',
#   'public_repos': 56,
#   'followers': 270,
#   'following': '',
#   'created_at': '2011-12-04T17:42:52Z'},
#  {'login': 'bartosz-lipinski',
#   'name': 'B',
#   'company': 'CUBEXCH',
#   'location': 'Chicago, US',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 33,
#   'followers': 270,
#   'following': 13,
#   'created_at': '2010-05-04T09:43:38Z'},
#  {'login': 'ivelasq',
#   'name': 'Isabella Velásquez',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ivelasq@gmail.com',
#   'hireable': '',
#   'bio': '%>% dreams',
#   'public_repos': 58,
#   'followers': 262,
#   'following': 51,
#   'created_at': '2015-05-04T14:40:14Z'},
#  {'login': 'joshbirk',
#   'name': 'Joshua Birk',
#   'company': 'SALESFORCE.COM',
#   'location': 'Chicago, IL',
#   'email': 'joshua.birk@salesforce.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 74,
#   'followers': 259,
#   'following': 54,
#   'created_at': '2010-11-24T18:43:03Z'},
#  {'login': 'pushcx',
#   'name': 'Peter Bhat Harkins',
#   'company': 'LOBSTERS',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': 'Programmer by day, programmer by night.',
#   'public_repos': 66,
#   'followers': 254,
#   'following': 8,
#   'created_at': '2008-04-10T20:13:29Z'},
#  {'login': 'jackdoyle',
#   'name': 'Jack Doyle',
#   'company': 'GREENSOCK',
#   'location': 'Chicago',
#   'email': 'jack@greensock.com',
#   'hireable': '',
#   'bio': 'Author of GSAP, owner of @greensock, lover of animation',
#   'public_repos': 3,
#   'followers': 251,
#   'following': '',
#   'created_at': '2012-09-21T00:08:41Z'},
#  {'login': 'brandonwillard',
#   'name': 'Brandon T. Willard',
#   'company': '.TXT',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'applied math/stats person',
#   'public_repos': 154,
#   'followers': 251,
#   'following': 93,
#   'created_at': '2011-08-10T14:19:12Z'},
#  {'login': 'rrag',
#   'name': 'Ragu Ramaswamy',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'ragunath.ramaswamy@gmail.com',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 21,
#   'followers': 250,
#   'following': 38,
#   'created_at': '2015-01-25T03:05:43Z'},
#  {'login': 'drewolson',
#   'name': 'Drew Olson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'software is fun',
#   'public_repos': 38,
#   'followers': 249,
#   'following': 21,
#   'created_at': '2008-03-21T16:01:37Z'},
#  {'login': 'ionelabrinza',
#   'name': 'Nicole Brinza',
#   'company': '',
#   'location': 'Chicago, USA',
#   'email': '',
#   'hireable': '',
#   'bio': ':)',
#   'public_repos': 45,
#   'followers': 247,
#   'following': 384,
#   'created_at': '2021-10-28T16:05:46Z'},
#  {'login': 'joemaddalone',
#   'name': 'Joe Maddalone',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software Engineer, Instructor at egghead.io, mentor/mentee, geekfest organizer',
#   'public_repos': 68,
#   'followers': 246,
#   'following': 1,
#   'created_at': '2010-12-01T16:22:57Z'},
#  {'login': 'jamigibbs',
#   'name': 'Jami Gibbs',
#   'company': 'ADHOCTEAM',
#   'location': 'Chicago',
#   'email': 'jami.gibbs@adhocteam.us',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 73,
#   'followers': 240,
#   'following': 40,
#   'created_at': '2011-06-24T04:17:20Z'},
#  {'login': 'mager',
#   'name': 'Mager',
#   'company': 'UBER',
#   'location': 'Chicago',
#   'email': 'andrew.mager@gmail.com',
#   'hireable': True,
#   'bio': 'Developer Experience @Uber. Lover of open source, web3, Go, React, databases, systems. Building Geotory on the weekend.',
#   'public_repos': 90,
#   'followers': 239,
#   'following': 463,
#   'created_at': '2008-07-21T21:49:48Z'},
#  {'login': 'mikehostetler',
#   'name': 'Mike Hostetler',
#   'company': 'EPIC CREATIVE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'VP of Eng @carsdotcom, Leader, Entrepreneur, Technologist. Passionate about #RemoteWork #WorkOps #OSS #JavaScript #Crypto',
#   'public_repos': 157,
#   'followers': 238,
#   'following': 68,
#   'created_at': '2009-05-13T19:03:35Z'},
#  {'login': 'mstruve',
#   'name': 'Molly Struve',
#   'company': 'NETFLIX',
#   'location': 'Chicago, IL',
#   'email': 'mollylbs@gmail.com',
#   'hireable': '',
#   'bio': 'Staff Site Reliability Engineer at Netflix',
#   'public_repos': 44,
#   'followers': 237,
#   'following': 3,
#   'created_at': '2012-06-04T00:17:32Z'},
#  {'login': 'jberger',
#   'name': 'Joel Berger',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Ph.D. in Physics, polyglot programmer (Perl, Python, Node, etc), @mojolicious core developer',
#   'public_repos': 187,
#   'followers': 234,
#   'following': 66,
#   'created_at': '2011-04-18T03:42:17Z'},
#  {'login': 'brianboyer',
#   'name': 'Brian Boyer',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 12,
#   'followers': 233,
#   'following': 17,
#   'created_at': '2009-03-30T15:09:05Z'},
#  {'login': 'mikewesthad',
#   'name': 'Michael Hadley',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Developer, Artist & Educator\r\n–––\r\nSoftware Engineer at Replit',
#   'public_repos': 147,
#   'followers': 233,
#   'following': 28,
#   'created_at': '2011-10-16T19:28:53Z'},
#  {'login': 'brasic',
#   'name': 'Carl Brasic',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 61,
#   'followers': 232,
#   'following': 13,
#   'created_at': '2011-03-18T14:39:19Z'},
#  {'login': 'braintreeps',
#   'name': 'Braintree Open Source',
#   'company': 'BRAINTREE',
#   'location': 'Chicago, IL',
#   'email': 'code@getbraintree.com',
#   'hireable': '',
#   'bio': 'Tools for use by Braintree employees. These repositories receive no official support from Braintree.',
#   'public_repos': 47,
#   'followers': 232,
#   'following': 7,
#   'created_at': '2010-02-09T17:22:24Z'},
#  {'login': 'k4rtik',
#   'name': 'Kartik Singhal',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kartiksinghal@gmail.com',
#   'hireable': True,
#   'bio': 'Programming Languages, Quantum Computing, Systems, and more. In superposition with @qartik.',
#   'public_repos': 79,
#   'followers': 231,
#   'following': 190,
#   'created_at': '2010-08-24T07:50:15Z'},
#  {'login': 'MarcosX',
#   'name': 'Marcos Brizeno',
#   'company': 'THOUGHTWORKS',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 65,
#   'followers': 230,
#   'following': 18,
#   'created_at': '2011-06-17T12:17:24Z'},
#  {'login': 'jordanorelli',
#   'name': 'Jordan Orelli',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'infra engineer on the discovery team at Whatnot.  \r\n\r\nMy public git repos are now here:\r\nhttps://git.orel.li/jordan',
#   'public_repos': 84,
#   'followers': 229,
#   'following': 132,
#   'created_at': '2010-09-15T13:14:47Z'},
#  {'login': 'FormerLurker',
#   'name': 'FormerLurker',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': "I'm the creator of Octolapse, and hoping to create even more open source tools!  If you like what you see, consider becoming a sponsor.",
#   'public_repos': 13,
#   'followers': 228,
#   'following': 12,
# ...
#   'public_repos': 15,
#   'followers': 114,
#   'following': 9,
#   'created_at': '2014-06-09T17:32:45Z'},
#  {'login': 'noelrappin',
#   'name': 'Noel Rappin',
#   'company': '1DEBIT',
#   'location': 'Chicago',
#   'email': 'noelrap@noelrappin.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 58,
#   'followers': 114,
#   'following': '',
#   'created_at': '2008-04-07T20:19:01Z'},
#  {'login': 'kvnkho',
#   'name': 'Kevin Kho',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'kdykho@gmail.com',
#   'hireable': '',
#   'bio': 'Fugue Maintainer\r\n@fugue-project @datakind @orlmlds @Nixtla \r\nPrev @PrefectHQ',
#   'public_repos': 25,
#   'followers': 114,
#   'following': 3,
#   'created_at': '2017-10-04T02:56:14Z'},
#  {'login': 'ivanfemia',
#   'name': 'Ivan',
#   'company': 'GOOGLE',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 22,
#   'followers': 114,
#   'following': 19,
#   'created_at': '2013-01-05T16:37:51Z'},
#  {'login': 'SarahMAmann',
#   'name': 'Sarah Benson',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'software engineer ✌️',
#   'public_repos': 24,
#   'followers': 113,
#   'following': 5,
#   'created_at': '2018-04-22T00:30:19Z'},
#  {'login': 'zircote',
#   'name': 'Robert Allen',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'zircote@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 83,
#   'followers': 112,
#   'following': 1,
#   'created_at': '2010-06-17T19:19:32Z'},
#  {'login': 'sonamoo',
#   'name': 'Seho Lim',
#   'company': 'MONGODB',
#   'location': 'Chicago',
#   'email': 'limseho657424@gmail.com',
#   'hireable': True,
#   'bio': 'Software Developer at MongoDB\r\n',
#   'public_repos': 49,
#   'followers': 112,
#   'following': 34,
#   'created_at': '2015-10-24T18:09:06Z'},
#  {'login': 'sleventyeleven',
#   'name': 'Michael Contino',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Dad of Tinny Humans, Tech Nerd, CCDC/NCL/OSCP Mentor, Linux Security SME, Kubernetes Security, Random Project Starter: Linuxprivchecker, Kubernetes-Harvester',
#   'public_repos': 22,
#   'followers': 112,
#   'following': 5,
#   'created_at': '2013-06-05T19:21:14Z'},
#  {'login': 'loucyx',
#   'name': 'Lou ✨',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': True,
#   'bio': '⛧ Code Witch ⛧',
#   'public_repos': 5,
#   'followers': 111,
#   'following': 129,
#   'created_at': '2013-03-26T22:07:08Z'},
#  {'login': 'mgrygles',
#   'name': 'Mary Grygleski',
#   'company': 'CALLIBRITY',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'AI Practice Lead🤖@callibrity ::::::::::::\r\nTech Advocate🥑👩\u200d💻@tech-portico ::::\r\nJava Champion🏆https://javachampions.org',
#   'public_repos': 65,
#   'followers': 111,
#   'following': 46,
#   'created_at': '2014-03-11T18:50:55Z'},
#  {'login': 'rossb34',
#   'name': 'Ross Bennett',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 38,
#   'followers': 111,
#   'following': '',
#   'created_at': '2013-10-28T19:37:21Z'},
#  {'login': 'stamourv',
#   'name': 'Vincent St-Amour',
#   'company': 'PLT',
#   'location': 'Chicago, IL, USA',
#   'email': 'stamourv@racket-lang.org',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 112,
#   'followers': 111,
#   'following': '',
#   'created_at': '2011-06-16T15:59:34Z'},
#  {'login': 'alexlyp',
#   'name': 'Alex Yocom-Piatt',
#   'company': 'COMPANYZERO',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 48,
#   'followers': 110,
#   'following': '',
#   'created_at': '2013-05-09T16:01:09Z'},
#  {'login': 'deanrad',
#   'name': 'Dean Radcliffe',
#   'company': 'UNITED HEALTHCARE',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'Engineering Manager and Senior Full-Stack Engineer',
#   'public_repos': 248,
#   'followers': 110,
#   'following': 15,
#   'created_at': '2008-09-13T04:17:00Z'},
#  {'login': 'brianray',
#   'name': 'Brian Ray',
#   'company': 'MAVEN WAVE PARTNERS',
#   'location': 'Los Angeles | Chicago',
#   'email': 'brianhray@gmail.com',
#   'hireable': True,
#   'bio': 'Global Data Science Lead @brianray',
#   'public_repos': 59,
#   'followers': 110,
#   'following': 102,
#   'created_at': '2011-03-18T01:48:46Z'},
#  {'login': 'skirmer',
#   'name': 'Stephanie Kirmer',
#   'company': 'DATAGRAIL',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Data scientist. Python. I talk a lot.',
#   'public_repos': 45,
#   'followers': 110,
#   'following': 8,
#   'created_at': '2015-03-23T20:22:21Z'},
#  {'login': 'barelyknown',
#   'name': 'Sean Devine',
#   'company': 'XBE LLC',
#   'location': 'Chicago, IL',
#   'email': 'sean-devine@x-b-e.com',
#   'hireable': '',
#   'bio': 'Founder and CEO of XBE LLC. Our construction logistics platform is built primarily with Ruby (Rails) and JavaScript (Ember).',
#   'public_repos': 100,
#   'followers': 109,
#   'following': 5,
#   'created_at': '2011-03-27T18:07:49Z'},
#  {'login': 'rsutphin',
#   'name': 'Rhett Sutphin',
#   'company': 'HUMAN PRACTICE, INC.',
#   'location': 'Chicago, Illinois',
#   'email': 'rhett@detailedbalance.net',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 48,
#   'followers': 109,
#   'following': 47,
#   'created_at': '2008-03-07T15:24:26Z'},
#  {'login': 'agfor',
#   'name': 'Adam Forsyth',
#   'company': 'BRAINTREE',
#   'location': 'Chicago, IL',
#   'email': 'adam@adamforsyth.net',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 35,
#   'followers': 109,
#   'following': 1,
#   'created_at': '2011-08-07T03:51:02Z'},
#  {'login': 'ksolo',
#   'name': 'Kevin Solorio',
#   'company': 'PROVI',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 117,
#   'followers': 108,
#   'following': 73,
#   'created_at': '2009-07-11T05:17:10Z'},
#  {'login': 'snowgy',
#   'name': 'Yue Gong',
#   'company': '',
#   'location': 'Chicago, USA',
#   'email': 'yvetteyue1998@outlook.com',
#   'hireable': '',
#   'bio': 'PhD student @uchicago',
#   'public_repos': 30,
#   'followers': 108,
#   'following': 48,
#   'created_at': '2016-10-10T13:35:42Z'},
#  {'login': 'defaultxr',
#   'name': 'modula t.',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 78,
#   'followers': 108,
#   'following': 72,
#   'created_at': '2011-02-05T05:28:25Z'},
#  {'login': 'andymboyle',
#   'name': 'Andy Boyle',
#   'company': 'ENGINEERING LEADER @ STARTUPS',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': 'I write code and words for fun and profit.',
#   'public_repos': 36,
#   'followers': 108,
#   'following': 7,
#   'created_at': '2010-12-04T01:17:13Z'},
#  {'login': 'jdoss',
#   'name': 'Joe Doss',
#   'company': 'HTTPS://WWW.SMALLSTEP.COM/',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Fedora Linux user. Passionate about enabling others to improve their lives with FOSS. ',
#   'public_repos': 53,
#   'followers': 107,
#   'following': 86,
#   'created_at': '2008-04-22T18:11:24Z'},
#  {'login': 'SpezialK71',
#   'name': 'Kurt',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 21,
#   'followers': 107,
#   'following': 261,
#   'created_at': '2023-04-10T15:11:58Z'},
#  {'login': 'shonumi',
#   'name': 'D. S. Baxter',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'shonumi@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 10,
#   'followers': 107,
#   'following': 3,
#   'created_at': '2014-04-27T05:08:15Z'},
#  {'login': 'maggiewolff',
#   'name': 'Maggie Wolff',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Data Scientist Product Analytics',
#   'public_repos': 9,
#   'followers': 107,
#   'following': 29,
#   'created_at': '2018-06-07T21:41:28Z'},
#  {'login': 'stevepopovich',
#   'name': 'Steven Popovich',
#   'company': 'GITHUB',
#   'location': 'Chicago, IL',
#   'email': 'stevepopovich8@gmail.com',
#   'hireable': '',
#   'bio': 'Hubber. Developer. Teammate. Bread Acquirer. ',
#   'public_repos': 26,
#   'followers': 107,
#   'following': 47,
#   'created_at': '2013-01-12T14:59:50Z'},
#  {'login': 'anthonyleezhang',
#   'name': 'Anthony Lee Zhang',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'anthonyzhang0@gmail.com',
#   'hireable': '',
#   'bio': 'I study markets',
#   'public_repos': 7,
#   'followers': 107,
#   'following': 6,
#   'created_at': '2014-08-20T13:42:50Z'},
#  {'login': 'daisyUniverse',
#   'name': 'Daisy Universe',
#   'company': 'ELGIN COMMUNITY COLLEGE',
#   'location': 'Chicago, IL',
#   'email': 'mail@robinuniver.se',
#   'hireable': True,
#   'bio': '☆ Welcome to the department of fuck around and find out',
#   'public_repos': 58,
#   'followers': 107,
#   'following': 58,
#   'created_at': '2015-05-25T22:16:17Z'},
#  {'login': 'maxmiller413',
#   'name': 'Max Miller',
#   'company': 'FULL-STACK SOFTWARE ENGINEERING',
#   'location': 'Chicago, IL',
#   'email': 'maxmiller413@gmail.com',
#   'hireable': True,
#   'bio': 'Full-Stack Software Engineering',
#   'public_repos': 207,
#   'followers': 107,
#   'following': 547,
#   'created_at': '2020-11-21T17:15:31Z'},
#  {'login': 'glitchfur',
#   'name': 'Glitch',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 10,
#   'followers': 106,
#   'following': 85,
#   'created_at': '2015-09-06T08:57:40Z'},
#  {'login': 'meltingscales',
#   'name': 'meltingscales',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Grad of IIT, Chicagoan. Go buy @flexadecimal car parts.\r\nStrong self-taught/school prowess in Java, Python, SQL, Linux.',
#   'public_repos': 336,
#   'followers': 106,
#   'following': 301,
#   'created_at': '2013-01-10T15:39:20Z'},
#  {'login': 'wmurphyrd',
#   'name': 'Will Murphy',
#   'company': 'IMMERS-SPACE',
#   'location': 'Chicago, IL',
#   'email': 'william@immers.space',
#   'hireable': '',
#   'bio': 'WebXR dev. Frame & Hubs contributor. A syndic of Immers Space, a co-op making free software for a federated metaverse. Available for freelance work.',
#   'public_repos': 63,
#   'followers': 106,
#   'following': 26,
#   'created_at': '2014-12-01T18:18:13Z'},
#  {'login': 'CodyNicholson',
#   'name': 'Cody Nicholson',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'codynicholson96@gmail.com',
#   'hireable': True,
#   'bio': 'I am a Software Engineer and this is an encyclopedia of all my skills',
#   'public_repos': 158,
#   'followers': 106,
#   'following': 88,
#   'created_at': '2015-04-25T23:37:47Z'},
#  {'login': 'mgrover1',
#   'name': 'Max Grover',
#   'company': 'ARGONNE NATIONAL LABORATORY',
#   'location': 'Chicago, IL',
#   'email': 'mgroverwx@gmail.com',
#   'hireable': '',
#   'bio': 'Software Developer @ARM-DOE\r\n\r\nFormer @NCAR @Unidata',
#   'public_repos': 198,
#   'followers': 105,
#   'following': 74,
#   'created_at': '2017-03-24T20:10:53Z'},
#  {'login': 'KovasMcCann',
#   'name': 'Kovas McCann',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': True,
#   'bio': '31337 H4XØR',
#   'public_repos': 10,
#   'followers': 105,
#   'following': 9,
#   'created_at': '2018-10-18T23:03:38Z'},
#  {'login': 'csantiago132',
#   'name': 'Carlos Santiago',
#   'company': 'KUROCADO-STUDIO',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': '',
#   'public_repos': 23,
#   'followers': 104,
#   'following': 48,
#   'created_at': '2013-10-19T19:19:03Z'},
#  {'login': 'jaku',
#   'name': 'Matt Jakubowski',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'jaku@hax.by',
#   'hireable': '',
#   'bio': 'Neque dicas, quid neque.',
#   'public_repos': 49,
#   'followers': 104,
#   'following': '',
#   'created_at': '2009-07-06T16:21:59Z'},
#  {'login': 'AbrarSyed',
#   'name': 'Abrar Syed',
#   'company': '',
#   'location': 'Chicago, IL, USA',
#   'email': '',
#   'hireable': '',
#   'bio': 'Did lots of MineCraft mod development until around 2016',
#   'public_repos': 17,
#   'followers': 104,
#   'following': 3,
#   'created_at': '2010-12-15T01:32:02Z'},
#  {'login': 'juneau001',
#   'name': 'Josh Juneau',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 63,
#   'followers': 104,
#   'following': 12,
#   'created_at': '2009-08-30T01:37:46Z'},
#  {'login': 'alycit',
#   'name': 'Alyssa Diaz',
#   'company': '',
#   'location': 'Chicago, IL',
#   'email': 'alydiaz77@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 50,
#   'followers': 104,
#   'following': 25,
#   'created_at': '2010-10-14T21:09:28Z'},
#  {'login': 'mstratman',
#   'name': 'Mark A. Stratman',
#   'company': '',
#   'location': 'Chicago',
#   'email': 'stratman@gmail.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 65,
#   'followers': 103,
#   'following': '',
#   'created_at': '2010-06-29T16:08:38Z'},
#  {'login': 'CaryLandholt',
#   'name': 'Cary Landholt',
#   'company': 'STRIDEKICK',
#   'location': 'Chicago',
#   'email': 'cary@landholt.com',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 23,
#   'followers': 103,
#   'following': 7,
#   'created_at': '2011-06-07T00:26:37Z'},
#  {'login': 'knagaitsev',
#   'name': 'Kirill Nagaitsev',
#   'company': 'NORTHWESTERN UNIVERSITY',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'PhD student at Northwestern. Previously worked on funcX @uchicago. GSoC 2019 @webpack graduate and past webpack-dev-server maintainer. Web game dev enthusiast',
#   'public_repos': 86,
#   'followers': 103,
#   'following': 9,
#   'created_at': '2016-10-02T21:37:35Z'},
#  {'login': 'omargfh',
#   'name': 'Omar Ibrahim',
#   'company': 'UNIVERSITY OF CHICAGO',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': 'Software developer, UI designer, and tech hobbyist currently studying computer science and economics at The University of Chicago',
#   'public_repos': 54,
#   'followers': 103,
#   'following': 73,
#   'created_at': '2019-06-06T20:50:19Z'},
#  {'login': 'RonaldColyar',
#   'name': 'Ronald Colyar',
#   'company': '',
#   'location': 'Chicago, Illinois',
#   'email': '',
#   'hireable': '',
#   'bio': "Passionate Engineer. It's art!!",
#   'public_repos': 51,
#   'followers': 103,
#   'following': 83,
#   'created_at': '2018-01-08T01:52:23Z'},
#  {'login': 'erichilarysmithsr',
#   'name': 'Eric Hilary Smith',
#   'company': 'MATH 4 YOU BY US GROUP ILLINOIS',
#   'location': 'Chicago',
#   'email': 'erichilarysmithsr@gmail.com',
#   'hireable': True,
#   'bio': 'Hello, everyone welcome to Github.',
#   'public_repos': 579,
#   'followers': 102,
#   'following': 757,
#   'created_at': '2013-09-24T15:40:42Z'},
#  {'login': 'luoyuanlab',
#   'name': 'Luo Lab at Northwestern University',
#   'company': 'DEPARTMENT OF PREVENTIVE MEDICINE, DIVISION OF HEALTH & BIOMEDICAL INFORMATICS AT FEINBERG SCHOOL OF MEDICINE IN NORTHWESTERN UNIVERSITY',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Luo Lab at Northwestern University. Interests: machine learning, natural language processing, integrative genomics, computational phenotyping',
#   'public_repos': 21,
#   'followers': 102,
#   'following': '',
#   'created_at': '2011-07-01T15:09:05Z'},
#  {'login': 'jfnavarro21',
#   'name': 'John Navarro-DEN',
#   'company': 'MCKINSEY & COMPANY',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': True,
#   'bio': 'Data science consultant',
#   'public_repos': 26,
#   'followers': 102,
#   'following': 3,
#   'created_at': '2016-01-12T15:52:13Z'},
#  {'login': 'rlk',
#   'name': 'Robert Kooima',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 33,
#   'followers': 102,
#   'following': 10,
#   'created_at': '2009-05-26T14:10:05Z'},
#  {'login': '3CloudSolutions',
#   'name': '3Cloud',
#   'company': '',
#   'location': 'Chicago',
#   'email': '',
#   'hireable': '',
#   'bio': 'Make the cloud work for you with our Azure consulting services. With a 100% focus on Azure, our experts deliver to you the ultimate Azure experience.',
#   'public_repos': 6,
#   'followers': 102,
#   'following': '',
#   'created_at': '2017-03-07T22:32:47Z'},
#  {'login': 'scottferg',
#   'name': 'Scott Ferguson',
#   'company': 'NUMERATOR/INFOSCOUT',
#   'location': 'Chicago, IL',
#   'email': '',
#   'hireable': '',
#   'bio': '',
#   'public_repos': 66,
#   'followers': 101,
#   'following': 46,
#   'created_at': '2009-04-16T03:45:47Z'}]

# %% [markdown]
# ### export users data to CSV

# %%
import pandas as pd
users_df = pd.DataFrame(a)
users_df.to_csv("users.csv", index=False)

# %% [markdown]
# # GET REPOSITORIES DATA

# %%
page = 1
per_page = 100

# %%
repo_data = []

for user in chicago_users:
    repo_url = user['repos_url']
    repo_count = 0
    page = 1
    per_page = 100
    
    while True:
        paging = f'?page={page}&per_page={per_page}'
        url = repo_url + paging
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            repos = response.json()
            
            for repo in repos:
                repo_data.append({
                    "login": user['login'],
                    "full_name": repo.get("full_name") or "",
                    "created_at": repo.get("created_at") or "",
                    "stargazers_count": repo.get("stargazers_count") or 0,
                    "watchers_count": repo.get("watchers_count") or 0,
                    "language": repo.get("language") or "",
                    "has_projects": repo.get("has_projects") or False,
                    "has_wiki": repo.get("has_wiki") or False,
                    "license_name": repo["license"]["key"] if repo.get("license") else ""
                })
                
                repo_count += 1
                if repo_count >= 500:
                    break

            if 'Link' not in response.headers:
                break
            else:
                links = response.headers['Link']
                if 'rel="next"' not in links:
                    break
            page += 1
            
        else:
            print("Error:", response.status_code, response.json())
            break

# %%
repo_data
# Out:
# [{'login': 'cassidoo',
#   'full_name': 'cassidoo/accordion',
#   'created_at': '2020-01-23T13:19:32Z',
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/agagd',
#   'created_at': '2023-11-20T05:21:51Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ama',
#   'created_at': '2020-06-09T02:22:18Z',
#   'stargazers_count': 62,
#   'watchers_count': 62,
#   'language': '',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ASL2048',
#   'created_at': '2014-03-20T14:29:23Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro',
#   'created_at': '2021-09-14T06:35:07Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'other'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro-docs',
#   'created_at': '2021-07-06T20:04:04Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro-netlify-starter',
#   'created_at': '2021-07-06T20:16:41Z',
#   'stargazers_count': 68,
#   'watchers_count': 68,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro-react-vue-demo',
#   'created_at': '2021-06-24T22:26:44Z',
#   'stargazers_count': 49,
#   'watchers_count': 49,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro-redirects-example',
#   'created_at': '2023-01-01T00:47:59Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astro-vt-demo',
#   'created_at': '2024-03-30T18:21:43Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/astroship',
#   'created_at': '2023-02-14T17:56:56Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/avocado-labs-demo',
#   'created_at': '2020-06-30T16:57:43Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/awesome-newsletters',
#   'created_at': '2022-07-16T05:17:18Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/babel-plugin-root-import',
#   'created_at': '2019-01-15T18:53:02Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Balance',
#   'created_at': '2014-03-29T17:19:24Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/better-security-questions',
#   'created_at': '2022-06-20T04:57:39Z',
#   'stargazers_count': 142,
#   'watchers_count': 142,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': 'isc'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/blahg',
#   'created_at': '2022-08-24T05:27:50Z',
#   'stargazers_count': 240,
#   'watchers_count': 240,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/book-rating-demo',
#   'created_at': '2020-09-16T02:16:42Z',
#   'stargazers_count': 26,
#   'watchers_count': 26,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/brainstorm-buddy-extension',
#   'created_at': '2024-09-23T15:53:44Z',
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/calendso',
#   'created_at': '2021-09-20T05:56:02Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'TypeScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'other'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/call-it-what-it-is',
#   'created_at': '2019-07-15T22:16:41Z',
#   'stargazers_count': 42,
#   'watchers_count': 42,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/carbon-copy',
#   'created_at': '2016-12-02T05:17:09Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cardstock',
#   'created_at': '2021-10-22T16:53:27Z',
#   'stargazers_count': 98,
#   'watchers_count': 98,
#   'language': 'CSS',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cass.lol',
#   'created_at': '2020-11-28T05:59:23Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cass.run',
#   'created_at': '2021-01-28T23:09:23Z',
#   'stargazers_count': 163,
#   'watchers_count': 163,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cassidoo',
#   'created_at': '2020-07-09T00:24:41Z',
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cassidoo-v3',
#   'created_at': '2014-10-06T06:17:21Z',
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cassidoo-v4',
#   'created_at': '2016-04-11T16:48:40Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cassidoo-v5',
#   'created_at': '2016-08-30T04:26:27Z',
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cassidoo.github.io',
#   'created_at': '2014-02-20T23:20:04Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/chihuahua-or-muffin',
#   'created_at': '2016-03-10T22:41:11Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/clarifai-car-trainer',
#   'created_at': '2015-09-19T18:11:10Z',
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/clarifai-go-cli',
#   'created_at': '2016-02-07T23:23:49Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Go',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/clarifai-javascript-starter',
#   'created_at': '2016-01-24T05:41:59Z',
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Color-Detect',
#   'created_at': '2013-07-14T23:32:18Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/console-dot-fog',
#   'created_at': '2016-08-09T14:23:26Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/copy-mailto-plus',
#   'created_at': '2024-02-17T06:01:57Z',
#   'stargazers_count': 20,
#   'watchers_count': 20,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/course-info',
#   'created_at': '2014-01-20T04:32:12Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/cs-education-funding',
#   'created_at': '2016-07-05T06:33:25Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/CSS-Notes',
#   'created_at': '2013-07-14T23:09:07Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/curator',
#   'created_at': '2016-03-18T20:56:52Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/decentralized-news',
#   'created_at': '2023-12-07T20:36:20Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/desktop-lava',
#   'created_at': '2017-12-02T01:28:21Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/devex-utm-builder',
#   'created_at': '2021-01-12T03:14:56Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'bsd-3-clause'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/devtools-angels',
#   'created_at': '2023-03-01T03:29:38Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/dooodles',
#   'created_at': '2013-07-13T02:35:18Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Dots',
#   'created_at': '2013-07-14T23:00:13Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/effective-javascript',
#   'created_at': '2014-08-15T20:20:06Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/electron',
#   'created_at': '2017-12-02T01:12:50Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ErmergershScript',
#   'created_at': '2013-12-23T04:28:08Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/es6-party',
#   'created_at': '2015-07-29T02:15:47Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/fedc-share-pear',
#   'created_at': '2024-04-26T01:34:06Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/flapjack-fwop',
#   'created_at': '2018-12-29T18:58:41Z',
#   'stargazers_count': 32,
#   'watchers_count': 32,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/found',
#   'created_at': '2015-11-11T20:26:20Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/generate-stripe-coupons',
#   'created_at': '2023-08-21T21:02:06Z',
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': 'Python',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/getting-a-gig',
#   'created_at': '2014-12-27T23:20:32Z',
#   'stargazers_count': 7308,
#   'watchers_count': 7308,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/github-copilot-demo',
#   'created_at': '2021-07-01T21:15:37Z',
#   'stargazers_count': 32,
#   'watchers_count': 32,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/github-user-search',
#   'created_at': '2017-10-12T18:11:25Z',
#   'stargazers_count': 8,
#   'watchers_count': 8,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/hacklocate',
#   'created_at': '2014-04-27T16:55:29Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/help',
#   'created_at': '2022-03-27T06:24:09Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/hiring-without-whiteboards',
#   'created_at': '2022-01-11T19:06:22Z',
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/horses-are-cool',
#   'created_at': '2022-12-16T20:39:29Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/HTML-CSS-Tutorial',
#   'created_at': '2013-07-28T00:46:57Z',
#   'stargazers_count': 870,
#   'watchers_count': 870,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/hued',
#   'created_at': '2016-02-13T19:10:50Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ifyoucould',
#   'created_at': '2014-04-26T20:46:39Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/iris-keyboard-layout',
#   'created_at': '2019-01-13T09:13:19Z',
#   'stargazers_count': 24,
#   'watchers_count': 24,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/jasonipsum',
#   'created_at': '2021-03-12T16:03:30Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/javascript-pizza',
#   'created_at': '2015-07-05T18:20:44Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/jumblie',
#   'created_at': '2023-10-02T04:00:23Z',
#   'stargazers_count': 49,
#   'watchers_count': 49,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mpl-2.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Learn-Morse',
#   'created_at': '2015-01-27T04:44:21Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/learn-pi',
#   'created_at': '2014-03-12T06:32:16Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/link-in-bio-generator',
#   'created_at': '2021-06-17T04:08:36Z',
#   'stargazers_count': 34,
#   'watchers_count': 34,
#   'language': 'Vue',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/link-in-bio-template',
#   'created_at': '2021-06-16T20:26:01Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Magic-8',
#   'created_at': '2013-08-09T23:00:29Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Objective-C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/markdown.tips',
#   'created_at': '2024-02-08T04:42:50Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/material-ui',
#   'created_at': '2022-12-16T23:47:39Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/members-only',
#   'created_at': '2020-06-24T06:49:42Z',
#   'stargazers_count': 12,
#   'watchers_count': 12,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/menubar',
#   'created_at': '2024-01-22T01:04:39Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'bsd-2-clause'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/morsemoji',
#   'created_at': '2021-05-06T22:23:45Z',
#   'stargazers_count': 51,
#   'watchers_count': 51,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Music-Filename-Changer',
#   'created_at': '2013-07-07T18:17:55Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Perl',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/my-next-project',
#   'created_at': '2020-11-11T05:53:12Z',
#   'stargazers_count': 8,
#   'watchers_count': 8,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-adventure',
#   'created_at': '2020-10-20T16:54:14Z',
#   'stargazers_count': 225,
#   'watchers_count': 225,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-beastie-demo',
#   'created_at': '2020-06-18T16:19:39Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-contentful-birthday-card',
#   'created_at': '2021-02-16T15:58:31Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-contentful-starter',
#   'created_at': '2020-07-30T18:28:12Z',
#   'stargazers_count': 80,
#   'watchers_count': 80,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-context-example',
#   'created_at': '2021-03-18T20:50:23Z',
#   'stargazers_count': 23,
#   'watchers_count': 23,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-nasa-demo',
#   'created_at': '2020-12-16T06:36:35Z',
#   'stargazers_count': 22,
#   'watchers_count': 22,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-netlify-blog-starter',
#   'created_at': '2020-04-28T06:56:55Z',
#   'stargazers_count': 200,
#   'watchers_count': 200,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-netlify-portfolio-starter',
#   'created_at': '2020-05-19T21:55:13Z',
#   'stargazers_count': 29,
#   'watchers_count': 29,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-netlify-starter',
#   'created_at': '2020-05-15T04:34:20Z',
#   'stargazers_count': 411,
#   'watchers_count': 411,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-netlify-starter-1',
#   'created_at': '2023-03-12T06:47:48Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-prankz',
#   'created_at': '2020-09-24T00:11:04Z',
#   'stargazers_count': 60,
#   'watchers_count': 60,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-prismic-starter',
#   'created_at': '2020-08-03T06:29:44Z',
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next-storyblok-starter',
#   'created_at': '2020-08-30T06:12:57Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/next.js',
#   'created_at': '2023-07-20T20:34:21Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/NFACML4K',
#   'created_at': '2013-08-31T20:20:42Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/obsidian-hidden-characters',
#   'created_at': '2023-03-12T05:58:30Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/obsidian-releases',
#   'created_at': '2021-10-25T00:52:36Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/OfflineNapper',
#   'created_at': '2014-01-16T04:53:06Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/online-go.com',
#   'created_at': '2022-10-14T16:08:02Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TypeScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'agpl-3.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/open-source-alternatives',
#   'created_at': '2023-06-07T01:02:41Z',
#   'stargazers_count': 26,
#   'watchers_count': 26,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/parsesize',
#   'created_at': '2019-09-04T07:03:01Z',
#   'stargazers_count': 24,
#   'watchers_count': 24,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/PebbleInsultGenerator',
#   'created_at': '2014-02-22T04:03:38Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/personalsit.es',
#   'created_at': '2023-11-06T04:59:49Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/pic2trip',
#   'created_at': '2016-06-16T16:45:14Z',
#   'stargazers_count': 30,
#   'watchers_count': 30,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/pokemon-feature-flags',
#   'created_at': '2021-05-18T01:37:06Z',
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/pretzelai',
#   'created_at': '2024-03-27T16:37:42Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'apache-2.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ProgressBar',
#   'created_at': '2014-01-07T21:40:49Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/project-pickle',
#   'created_at': '2021-02-05T20:26:37Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/protected-uploader',
#   'created_at': '2016-01-22T00:02:17Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Python',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/qmkbuilder',
#   'created_at': '2018-02-17T02:23:13Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/react-hooks-codemirror',
#   'created_at': '2019-10-06T05:14:05Z',
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/react-hooks-workshop-2020',
#   'created_at': '2020-05-28T08:45:15Z',
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/react-router',
#   'created_at': '2023-01-12T06:42:01Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/react-tailwind-tabs',
#   'created_at': '2023-09-26T19:01:03Z',
#   'stargazers_count': 20,
#   'watchers_count': 20,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/reading-challenge-2015',
#   'created_at': '2015-01-25T00:22:38Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/reading-challenge-webinar',
#   'created_at': '2020-04-16T07:23:47Z',
#   'stargazers_count': 40,
#   'watchers_count': 40,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/remember',
#   'created_at': '2014-02-28T06:29:27Z',
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/remix-demo',
#   'created_at': '2021-10-01T01:06:17Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/remove-gmail-categories',
#   'created_at': '2024-08-27T05:26:41Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/resources',
#   'created_at': '2023-10-24T21:49:57Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/saaskit',
#   'created_at': '2024-05-19T05:19:54Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/scheme-exercises',
#   'created_at': '2014-08-13T03:50:55Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Racket',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/scrapers',
#   'created_at': '2016-04-18T20:41:55Z',
#   'stargazers_count': 617,
#   'watchers_count': 617,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/screenshot-demo',
#   'created_at': '2024-03-12T14:52:05Z',
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/search-nasa',
#   'created_at': '2017-05-24T21:00:24Z',
#   'stargazers_count': 33,
#   'watchers_count': 33,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/semaphore-library',
#   'created_at': '2014-04-30T06:47:45Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/ShakespeareInsults',
#   'created_at': '2014-01-02T01:54:51Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/shopify-next-netlify',
#   'created_at': '2021-07-19T14:54:29Z',
#   'stargazers_count': 47,
#   'watchers_count': 47,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/shopify-react-astro',
#   'created_at': '2021-06-25T19:40:29Z',
#   'stargazers_count': 122,
#   'watchers_count': 122,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/snapchat-dashboard',
#   'created_at': '2014-10-02T21:24:07Z',
#   'stargazers_count': 24,
#   'watchers_count': 24,
#   'language': 'Python',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/solid-pi-guesser',
#   'created_at': '2022-03-10T22:36:12Z',
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/sonnet-18',
#   'created_at': '2020-05-31T05:36:26Z',
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/spendee-styles',
#   'created_at': '2016-05-12T17:33:43Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/splash',
#   'created_at': '2013-10-19T14:45:27Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Ruby',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/split-testing-demo',
#   'created_at': '2021-02-02T19:19:57Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Star-Catcher',
#   'created_at': '2013-07-07T20:04:34Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/stream-hooks-demo',
#   'created_at': '2020-08-08T04:16:01Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/talks',
#   'created_at': '2014-08-07T18:02:31Z',
#   'stargazers_count': 669,
#   'watchers_count': 669,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/team-dory',
#   'created_at': '2013-07-11T20:50:34Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/test-bio',
#   'created_at': '2021-06-17T05:15:12Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/testaroni',
#   'created_at': '2021-09-14T06:29:24Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/TextToArray',
#   'created_at': '2014-01-02T02:05:34Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/TextToTable',
#   'created_at': '2013-10-30T19:51:05Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Python',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/thejam-markdown-share-pear',
#   'created_at': '2024-01-24T19:14:13Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/thejam-share-pear',
#   'created_at': '2024-01-24T18:16:11Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/thirteen-potions',
#   'created_at': '2023-09-11T03:41:26Z',
#   'stargazers_count': 24,
#   'watchers_count': 24,
#   'language': 'HTML',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/tina.io',
#   'created_at': '2023-10-19T04:25:38Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TypeScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/tinacms',
#   'created_at': '2023-10-30T01:24:10Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'apache-2.0'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/todometer',
#   'created_at': '2017-04-29T05:44:13Z',
#   'stargazers_count': 1982,
#   'watchers_count': 1982,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/tue-due-vue',
#   'created_at': '2021-01-21T23:03:01Z',
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': 'Vue',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/TwerkyBird',
#   'created_at': '2014-02-08T18:37:52Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/TwitterBotPractice',
#   'created_at': '2014-03-12T06:09:08Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/typing-game',
#   'created_at': '2020-06-26T20:22:30Z',
#   'stargazers_count': 31,
#   'watchers_count': 31,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/V4WP',
#   'created_at': '2013-09-28T18:56:16Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C#',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/vim-up',
#   'created_at': '2016-11-30T19:54:47Z',
#   'stargazers_count': 355,
#   'watchers_count': 355,
#   'language': 'Vim Script',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/vscode-astro-stream',
#   'created_at': '2023-01-19T15:45:44Z',
#   'stargazers_count': 8,
#   'watchers_count': 8,
#   'language': 'Astro',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/vveather',
#   'created_at': '2016-10-11T00:11:57Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/w9-crafter',
#   'created_at': '2024-01-14T07:01:33Z',
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': 'JavaScript',
#   'has_projects': False,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/Web-Synthesizer',
#   'created_at': '2014-04-19T02:32:43Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/WebGLPractice',
#   'created_at': '2014-03-12T07:12:31Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/website',
#   'created_at': '2019-01-15T20:56:05Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/whitney-api',
#   'created_at': '2015-07-18T03:03:17Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Python',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/write-away',
#   'created_at': '2014-05-02T04:39:41Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'cassidoo',
#   'full_name': 'cassidoo/zapthegnome',
#   'created_at': '2014-09-03T14:15:51Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/amplify_starter',
#   'created_at': '2022-07-06T14:51:53Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/atlas',
#   'created_at': '2020-03-30T18:41:17Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/awesome-flutter',
#   'created_at': '2018-12-09T14:50:23Z',
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/benchmarks',
#   'created_at': '2020-06-15T04:48:52Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc',
#   'created_at': '2018-10-07T19:32:59Z',
#   'stargazers_count': 11811,
#   'watchers_count': 11811,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc-close-sinks-bug',
#   'created_at': '2019-10-18T14:59:34Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc.js',
#   'created_at': '2019-08-11T05:01:32Z',
#   'stargazers_count': 190,
#   'watchers_count': 190,
#   'language': 'TypeScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc_didchangedependencies',
#   'created_at': '2021-03-02T05:11:24Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc_library_basics_and_beyond',
#   'created_at': '2020-01-18T23:58:48Z',
#   'stargazers_count': 29,
#   'watchers_count': 29,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/bloc_todos',
#   'created_at': '2020-04-30T07:44:37Z',
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/brain.js',
#   'created_at': '2018-11-12T23:51:35Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/broadcast_bloc',
#   'created_at': '2022-12-16T06:14:26Z',
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/build_verify',
#   'created_at': '2020-08-27T14:47:43Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/codemagic_bloc_unit_tests',
#   'created_at': '2019-11-13T03:53:48Z',
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/cool_counter',
#   'created_at': '2020-10-06T02:52:38Z',
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/crossfader',
#   'created_at': '2016-09-17T08:42:25Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/csv-to-sql',
#   'created_at': '2017-03-09T05:45:34Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/cubit',
#   'created_at': '2020-06-04T05:17:27Z',
#   'stargazers_count': 596,
#   'watchers_count': 596,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/cubit_and_beyond',
#   'created_at': '2020-11-19T04:28:59Z',
#   'stargazers_count': 22,
#   'watchers_count': 22,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/Dart-Code',
#   'created_at': '2019-07-24T05:09:45Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'TypeScript',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dart-neats',
#   'created_at': '2021-07-13T05:43:55Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'apache-2.0'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dart-pad',
#   'created_at': '2020-04-23T02:52:40Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'bsd-3-clause'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dart-services',
#   'created_at': '2020-04-23T02:54:00Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'bsd-3-clause'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dartdevc_exception_bug',
#   'created_at': '2019-12-27T00:58:25Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/dart_edge',
#   'created_at': '2023-02-03T22:37:21Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'apache-2.0'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dart_sealed_unions',
#   'created_at': '2019-07-27T22:10:24Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'apache-2.0'},
#  {'login': 'felangel',
#   'full_name': 'felangel/data_class',
#   'created_at': '2024-05-16T04:55:39Z',
#   'stargazers_count': 292,
#   'watchers_count': 292,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/devtools',
#   'created_at': '2019-09-13T02:52:36Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'bsd-3-clause'},
#  {'login': 'felangel',
#   'full_name': 'felangel/dio',
#   'created_at': '2019-06-05T16:50:33Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Dart',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'felangel',
#   'full_name': 'felangel/discord-open-source',
#   'created_at': '2021-02-09T01:24:49Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'felangel',
#   'full_name': 'felangel/docsify',
# ...
#   'created_at': '2021-04-26T13:04:28Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bh',
#   'created_at': '2014-01-01T18:06:12Z',
#   'stargazers_count': 84,
#   'watchers_count': 84,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/biglasso',
#   'created_at': '2021-06-10T18:18:36Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bigmemory',
#   'created_at': '2015-10-21T01:39:16Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bigtabulate',
#   'created_at': '2015-10-22T11:40:31Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/binb',
#   'created_at': '2018-09-15T14:02:02Z',
#   'stargazers_count': 189,
#   'watchers_count': 189,
#   'language': 'TeX',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bioc-api-package',
#   'created_at': '2022-06-16T20:22:06Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/BiocNeighbors',
#   'created_at': '2020-11-10T23:08:33Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bit',
#   'created_at': '2020-07-20T13:02:29Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/biwavelet',
#   'created_at': '2021-04-27T12:56:27Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/blatent',
#   'created_at': '2021-04-27T21:30:12Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/blog_source',
#   'created_at': '2017-08-20T21:33:58Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/BNPMIXcluster',
#   'created_at': '2022-09-04T22:21:03Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/book',
#   'created_at': '2018-05-08T16:07:35Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'CSS',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'cc0-1.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bp',
#   'created_at': '2014-10-29T02:49:58Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/BreakoutDetection',
#   'created_at': '2014-10-24T19:48:55Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'gpl-2.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bspm',
#   'created_at': '2020-07-12T12:37:11Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/bti',
#   'created_at': '2014-01-15T12:32:36Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Perl',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-2.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/CAR-LASSO',
#   'created_at': '2021-07-25T14:35:00Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cccp',
#   'created_at': '2022-09-04T22:36:37Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cda',
#   'created_at': '2015-12-06T15:09:20Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cellxgene-census',
#   'created_at': '2023-08-06T15:24:59Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'mit'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/chanzuckerberg.r-universe.dev',
#   'created_at': '2023-05-18T12:25:24Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/checkmate',
#   'created_at': '2017-10-11T20:06:35Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': False,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/chshli',
#   'created_at': '2020-05-28T01:06:05Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/circumplex',
#   'created_at': '2021-04-28T13:05:04Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/CiteSource',
#   'created_at': '2024-05-26T13:23:55Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/ciw',
#   'created_at': '2024-02-29T01:11:02Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/collapse',
#   'created_at': '2021-04-29T12:08:49Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/colourvalues',
#   'created_at': '2022-12-20T01:42:15Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/compass',
#   'created_at': '2021-04-29T12:30:29Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cook-county-tax-model',
#   'created_at': '2019-09-16T00:10:59Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/corels',
#   'created_at': '2019-11-06T14:26:19Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/covid-19-the-economist-global-excess-deaths-model',
#   'created_at': '2021-11-22T15:13:33Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cpptoml',
#   'created_at': '2015-04-22T12:27:48Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mit'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/cpuaff',
#   'created_at': '2015-01-31T15:23:25Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'bsd-3-clause'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/crandep',
#   'created_at': '2020-05-16T12:19:11Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/crc32c',
#   'created_at': '2023-05-04T21:52:28Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/crp',
#   'created_at': '2013-09-11T02:42:35Z',
#   'stargazers_count': 84,
#   'watchers_count': 84,
#   'language': 'HTML',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-2.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/ctv-finance',
#   'created_at': '2014-11-29T01:57:16Z',
#   'stargazers_count': 56,
#   'watchers_count': 56,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/ctv-hpc',
#   'created_at': '2014-11-29T02:04:54Z',
#   'stargazers_count': 38,
#   'watchers_count': 38,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/curse',
#   'created_at': '2021-03-10T00:16:02Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/curse_fork',
#   'created_at': '2021-03-05T21:02:28Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/dang',
#   'created_at': '2020-08-17T22:05:45Z',
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/data-examples',
#   'created_at': '2018-05-12T19:41:09Z',
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/data.table',
#   'created_at': '2019-11-10T14:09:42Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'mpl-2.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/deepboost',
#   'created_at': '2016-03-01T23:02:28Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/deepdep',
#   'created_at': '2021-12-07T21:29:40Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/delaunay',
#   'created_at': '2022-07-09T17:39:19Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'gpl-3.0'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/demo-tldbsm',
#   'created_at': '2024-04-05T14:48:17Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/demovalgrindnonfail',
#   'created_at': '2022-03-06T16:51:19Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/DGM',
#   'created_at': '2021-06-10T19:26:38Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/dieharder',
#   'created_at': '2020-07-25T13:51:25Z',
#   'stargazers_count': 13,
#   'watchers_count': 13,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/dieharder-rgb',
#   'created_at': '2015-11-07T23:49:09Z',
#   'stargazers_count': 8,
#   'watchers_count': 8,
#   'language': 'C',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/digest',
#   'created_at': '2013-12-04T01:48:12Z',
#   'stargazers_count': 111,
#   'watchers_count': 111,
#   'language': 'C++',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-clang-format-10',
#   'created_at': '2023-09-08T22:39:58Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-clang-format-14',
#   'created_at': '2024-03-27T17:22:35Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-clang-format-16',
#   'created_at': '2023-10-06T20:08:29Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-clang-format-9',
#   'created_at': '2022-07-30T17:08:04Z',
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-debian-r',
#   'created_at': '2014-06-14T19:36:20Z',
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-lintian',
#   'created_at': '2018-04-09T17:17:16Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-swc',
#   'created_at': '2014-08-10T14:30:04Z',
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-ubuntu-r',
#   'created_at': '2014-06-14T19:28:10Z',
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Shell',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docker-why',
#   'created_at': '2017-09-30T12:48:38Z',
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': '',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': ''},
#  {'login': 'eddelbuettel',
#   'full_name': 'eddelbuettel/docopt.R',
#   'created_at': '2015-05-03T18:42:17Z',
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'R',
#   'has_projects': True,
#   'has_wiki': True,
#   'license_name': 'other'},
#  ...]

# %% [markdown]
# ### export to CSV

# %%
repos_df = pd.DataFrame(repo_data)
repos_df.to_csv("repositories.csv", index=False)
